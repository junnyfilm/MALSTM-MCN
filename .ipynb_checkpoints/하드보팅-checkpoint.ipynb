# %%
import pickle
import pandas

# %%
with open('hardvote11.pickle', 'rb') as f:
    hardvote11 = pickle.load(f)
with open('hardvote21.pickle', 'rb') as f:
    hardvote21 = pickle.load(f)
with open('hardvote31.pickle', 'rb') as f:
    hardvote31 = pickle.load(f)
with open('hardvote41.pickle', 'rb') as f:
    hardvote41 = pickle.load(f)
with open('hardvote51.pickle', 'rb') as f:
    hardvote51 = pickle.load(f)
    
with open('hardvote12.pickle', 'rb') as f:
    hardvote12 = pickle.load(f)
with open('hardvote22.pickle', 'rb') as f:
    hardvote22 = pickle.load(f)
with open('hardvote32.pickle', 'rb') as f:
    hardvote32 = pickle.load(f)
with open('hardvote42.pickle', 'rb') as f:
    hardvote42 = pickle.load(f)
with open('hardvote52.pickle', 'rb') as f:
    hardvote52 = pickle.load(f)

# %%
hardvote21
# Out:
# [[array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
#  [array(0), array(0), array(0), array(0), array(0)],
# ...

# %%
hardvote11[0]
# Out:
# [array(3), array(3), array(3), array(3), array(3)]

# %%
hardvote11[0][0].item()
# Out:
# 3

# %%
def writing(lists, num):
    a=pd.DataFrame(lists)
    a.to_excel('{}.xlsx'.format(num))
    print(str(num) + " file: list to excel file completed")

# %%
writing(hardvote11,11)
writing(hardvote21,21)
writing(hardvote31,31)
writing(hardvote41,41)
writing(hardvote51,51)
writing(hardvote12,12)
writing(hardvote22,22)
writing(hardvote32,32)
writing(hardvote42,42)
writing(hardvote52,52)
# Out:
# 11 file: list to excel file completed
# 21 file: list to excel file completed
# 31 file: list to excel file completed
# 41 file: list to excel file completed
# 51 file: list to excel file completed
# 12 file: list to excel file completed
# 22 file: list to excel file completed
# 32 file: list to excel file completed
# 42 file: list to excel file completed
# 52 file: list to excel file completed
