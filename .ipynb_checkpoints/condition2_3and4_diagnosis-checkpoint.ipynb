# %%
import os
import glob
import numpy as np
import pandas as pd
from pathlib import Path
from numpy import inf
from numpy import array
from numpy import argmax
import pickle
import argparse, sys, os
import time
from collections import Counter

from torch.utils.data import DataLoader,Dataset
import torchvision.transforms as transforms
from torchvision import models
import torch.nn as nn
import torch
from torch.autograd import Variable
from torchsummary import summary
import torchvision.transforms.functional as Fv
from torch.optim import lr_scheduler
import torchvision
import torch.optim as optim
import torch.nn.functional as F
import torch.nn.init as init
from torchvision import datasets, transforms


from sklearn.manifold import TSNE
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn import metrics
from tqdm import tqdm
import matplotlib.pyplot as plt
import random
from torchsummary import summary
from torch.optim import lr_scheduler
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init

print(torch.__version__)
print(torch.cuda.is_available())
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.nn.parameter import Parameter
from torch import topk
from tqdm.notebook import tqdm # 프로세스 바
from matplotlib import pyplot as plt
import matplotlib
# matplotlib.use('agg')
# device = torch.device("cuda:%d" % 0 if torch.cuda.is_available() else "cpu")
import numpy as np
# from dataloader_hilbert_att import DataLoader
import os
from torch.autograd import Variable


# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# 1.12.1
# True

# %%
import os

path = "../data"
file_list = os.listdir(path)
print(file_list)
# Out:
# ['gt_1500_10.npy', 'gt_2700_25.npy', 'testset', 'x_1500_10.npy', 'x_2700_25.npy', 'y_1500_10.npy', 'y_2700_25.npy', 'z_1500_10.npy', 'z_2700_25.npy']

# %%
gt_2700_25=np.load("../data/"+file_list[1])
x_2700_25=np.load("../data/"+file_list[4])
y_2700_25=np.load("../data/"+file_list[6])
z_2700_25=np.load("../data/"+file_list[8])

# %%
def rms(x): # RMS 함수 정의
    return np.sqrt(np.mean(x**2))

# %%
data_2700=np.concatenate((np.expand_dims(x_2700_25, axis=1),np.expand_dims(y_2700_25, axis=1),np.expand_dims(z_2700_25, axis=1)),axis=1)
label_2700=gt_2700_25

# %%
data=[]
label=[]
for i in range(len(data_2700)):
    if label_2700[i]==3:
        data.append(data_2700[i])
        label.append(0)
    if label_2700[i]==4:
        data.append(data_2700[i])
        label.append(1)

# %%
data=np.array(data)
label=np.array(label)

# %%
data.shape
# Out:
# (20000, 3, 200)

# %%
#depthwise version
class customdataset(Dataset):
    def __init__(self, data, label): 
        super().__init__()
        self.data=torch.tensor(data)
        self.label=torch.tensor(label)
        
    def __len__(self):
        return len(self.label)
  
    def __getitem__(self, idx):
        x = self.data[idx]
        label = self.label[idx] 
                
        return  x.to(device).float(), label.to(device).long()
train_set, valid_set, train_label, valid_label = train_test_split(data, label, train_size=0.8, random_state=1)
traindataset = customdataset(train_set, train_label)
validdataset = customdataset(valid_set, valid_label)

traindataloader = DataLoader(traindataset, batch_size=32, shuffle=True, drop_last=True )
validdataloader = DataLoader(validdataset, batch_size=32, shuffle=True, drop_last=True )

# %%
class SELayer(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1)
        return x * y.expand_as(x)

# %%
class Dilated_Module(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Dilated_Module,self).__init__()
        self.conv1=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5)//2), dilation=1, bias=False)        
        self.conv2=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*2)//2), dilation=3, bias=False)        
        self.conv3=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*4)//2), dilation=5, bias=False)
        self.conv4=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*6)//2), dilation=7, bias=False)
        
    def forward(self,x):
        ''' input x should be in size [B,F,T], where 
            B = Batch size
            F = features
            T = Time samples
        '''
        x1=self.conv1(x)
        x2=self.conv2(x)
        x3=self.conv3(x)
        x4=self.conv4(x)
        
        y=torch.cat([x1,x2,x3,x4],dim=1)
        
        return y

# %%
class MLSTMfcn_MSN(nn.Module):
    def __init__(self, *, num_classes, num_features,
                 num_lstm_out, num_lstm_layers=1, 
                 conv1_nf=128, conv2_nf=256, conv3_nf=128,
                 lstm_drop_p=0.8, fc_drop_p=0.3):
        super(MLSTMfcn_MSN, self).__init__()

        self.num_classes = num_classes
        self.num_features = num_features

        self.num_lstm_out = num_lstm_out
        self.num_lstm_layers = num_lstm_layers

        
        self.conv1_nf = conv1_nf
        self.conv2_nf = conv2_nf
        self.conv3_nf = conv3_nf

        self.dilated_1=Dilated_Module(self.num_features, self.conv1_nf)
        self.dilated_2=Dilated_Module(self.conv1_nf, self.conv2_nf)
        self.dilated_3=Dilated_Module(self.conv2_nf, self.conv3_nf)

        self.lstm_drop_p = lstm_drop_p
        self.fc_drop_p = fc_drop_p

        self.lstm = nn.LSTM(input_size=self.num_features, 
                            hidden_size=self.num_lstm_out,
                            num_layers=self.num_lstm_layers,
                            batch_first=True)
        
        self.bn1 = nn.BatchNorm1d(self.conv1_nf)
        self.bn2 = nn.BatchNorm1d(self.conv2_nf)
        self.bn3 = nn.BatchNorm1d(self.conv3_nf)

        self.se1 = SELayer(self.conv1_nf)  # ex 128
        self.se2 = SELayer(self.conv2_nf)  # ex 256

        self.relu = nn.ReLU()
        self.lstmDrop = nn.Dropout(self.lstm_drop_p)
        self.convDrop = nn.Dropout(self.fc_drop_p)

        self.fc = nn.Linear(self.conv3_nf+self.num_lstm_out, self.num_classes)
    
    def forward(self, x):
        ''' input x should be in size [B,T,F], where 
            B = Batch size
            T = Time samples
            F = features
        '''
        x=x.transpose(2,1)
        ''' input x should be in size [B,T,F], where 
            B = Batch size
            T = Time samples
            F = features
        '''       
        # x1 = nn.utils.rnn.pack_padded_sequence(x, seq_lens, 
        #                                        batch_first=True, 
        #                                        enforce_sorted=False)
        x1, (ht,ct) = self.lstm(x)
        x1 = self.lstmDrop(x1)
        # x1, _ = nn.utils.rnn.pad_packed_sequence(x1, batch_first=True, 
        #                                          padding_value=0.0)
        # print(x1.size())
        x1 = x1[:,-1,:]
        
        x2 = x.transpose(2,1)
        x2 = self.convDrop(self.relu(self.bn1(self.dilated_1(x2))))
        # print(x2.size())
        x2 = self.se1(x2)
        x2 = self.convDrop(self.relu(self.bn2(self.dilated_2(x2))))
        # print(x2.size())
        x2 = self.se2(x2)
        x2 = self.convDrop(self.relu(self.bn3(self.dilated_3(x2))))
        # print(x2.size())
        x2 = torch.mean(x2,2)
        
        x_all = torch.cat((x1,x2),dim=1)
        x_out = self.fc(x_all)
        x_out = F.log_softmax(x_out, dim=1)

        return x_out,x_all

# %%
def validation(model, testloader, criterion):
    accuracy = 0
    test_loss = 0
    for inputs, labels in testloader:
        inputs = inputs.float()
        inputs, labels = inputs.to(device), labels.to(device)

        output,_ = model.forward(inputs)
        test_loss += criterion(output, labels).item()

        ## Calculating the accuracy 
        # Model's output is log-softmax, take exponential to get the probabilities
        ps = torch.exp(output)
        # Class with highest probability is our predicted class, compare with true label
        equality = (labels.data == ps.max(1)[1])
        # Accuracy is number of correct predictions divided by all predictions, just take the mean
        accuracy += equality.type_as(torch.FloatTensor()).mean()

    return test_loss,accuracy

# %%
def test(classifier, dataloader,PATH):
    # setup the network
    predlist=[]
    real=[]    
    classifier.load_state_dict(PATH)

    classifier.eval()
    correct = 0.0
    
    max_tr_score = 0
    max_val_score = 0
    for batch_idx, (data) in enumerate(dataloader):
    
        signal1,label = data
        signal1,label = Variable(signal1.cuda()),Variable(label.cuda().long())
        out,_ = classifier(signal1)   

        pred = out.data.max(1, keepdim= True)[1]
        predlist.append(pred.cpu().detach().numpy().squeeze())
        real.append(label)        
        correct += pred.eq(label.data.view_as(pred)).cpu().sum()

        # predlist.append(pred)
    print('\nAccuracy: {}/{} ({:.4f}%)\n'.format(
        correct, len(dataloader.dataset), 100. * float(correct) / len(dataloader.dataset)))
    acc=100. * float(correct) / len(dataloader.dataset)
    return acc,predlist,real

# %%
import seaborn as sn
def confusionmatrix(y_pred1, y_test1, column=['class0','class1','class2','class3','class4']):
    # y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    # _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)
    a=[]
    b=[]
    for i in range(len(y_test1)):
        a.append(y_test1[i].detach().cpu().item())
        b.append(y_pred1[i].item())
    y_test=a
    y_pred=b
    df_cm = pd.DataFrame(confusion_matrix(y_test,y_pred))
    df_cm.index=column
    df_cm.columns=column
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    b, t = plt.ylim() 
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t)
    

    df_cm =df_cm / df_cm.astype(np.float).sum(axis=1)
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    b, t = plt.ylim() 
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t)
from sklearn.metrics import confusion_matrix

# %%
from sklearn.model_selection import ParameterGrid
# 하이퍼파라미터 그리드 설정
param_grid = {
    'lr': [0.001, 0.0005, 0.0001],
    'batch_size': [32, 64, 128],
    'hidden_size': [8, 64, 128],
    'optimizer': ['Adam', 'RMSprop', 'SGD']
}

# %%
def final(modelname,train_loader, valid_loader):


    valid_loss_min = np.Inf # track change in validation loss
    criterion = nn.NLLLoss().to(device)
    epochs=500
    print_every=1000

    # 0.001 32 8 Adam
    lr = param_grid['lr'][0]
    batch_size = param_grid['batch_size'][0]
    num_lstm_out = param_grid['hidden_size'][0]
    optimizer_name = param_grid['optimizer'][0]

    model =modelname.to(device)


    # 옵티마이저 설정
    if optimizer_name == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_name == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=lr)
    elif optimizer_name == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=lr)



    #train
    steps = 0

    for e in tqdm(range(epochs)):
        train_loss = 0.0
        valid_loss = 0.0

        model.train()
        for inputs, labels in train_loader:
            steps += 1

            inputs = inputs.float()
            inputs, labels = inputs.to(device),labels.to(device)

            optimizer.zero_grad()
            # print(inputs.shape)
            # print(model.forward(inputs).shape)
            output,_ = model.forward(inputs)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            if steps % print_every == 0:
                model.eval()

                with torch.no_grad():
                    valid_loss, accuracy = validation(model, valid_loader, criterion)

                print("Epoch: {}/{}.. ".format(e+1, epochs),
                      "Training Loss: {:.6f}.. ".format(train_loss/print_every),
                      "Val Loss: {:.6f}.. ".format(valid_loss/len(valid_loader)),
                      "Val Accuracy: {:.2f}%".format(accuracy/len(valid_loader)*100))

                # save model if validation loss has decreased
                if valid_loss <= valid_loss_min:
                    print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
                    valid_loss_min,
                    valid_loss))
                    torch.save(model.state_dict(),  './malstm_msn_cv_cond_2_esb_3_4.pt')
                    valid_loss_min = valid_loss
                    bestmodel=model

                train_loss = 0

                model.train()
    return bestmodel

# %%
from sklearn.model_selection import ParameterGrid
# 하이퍼파라미터 그리드 설정
param_grid = {
    'lr': [0.001, 0.0005, 0.0001],
    'batch_size': [32, 64, 128],
    'hidden_size': [8, 64, 128],
    'optimizer': ['Adam', 'RMSprop', 'SGD']
}
lr = param_grid['lr'][0]
batch_size = param_grid['batch_size'][0]
num_lstm_out = param_grid['hidden_size'][0]
optimizer_name = param_grid['optimizer'][0]

# %%
def test(classifier, dataloader):
    # setup the network
    predlist=[]
    real=[]    

    classifier.eval()
    correct = 0.0
    
    max_tr_score = 0
    max_val_score = 0
    for batch_idx, data in enumerate(dataloader):
    
        signal1 = data
        signal1 = Variable(signal1.cuda())
        
        
        out1,_ = classifier(signal1)
        

        
        
        pred = out1.data.max(1, keepdim= True)[1]
        predlist.append(pred.cpu().detach().numpy().squeeze())

    
    return predlist

# %% [markdown]
# ## cross val 1

# %%
modelll = MLSTMfcn_MSN(num_classes=2, 
                           num_features=3,
                           num_lstm_out=num_lstm_out).to(device)

# %%
model1=final(modelll,traindataloader,validdataloader)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch: 2/500..  Training Loss: 0.033403..  Val Loss: 0.124263..  Val Accuracy: 94.70%
# Validation loss decreased (inf --> 15.532890).  Saving model ...
# Epoch: 4/500..  Training Loss: 0.024937..  Val Loss: 0.096896..  Val Accuracy: 95.72%
# Validation loss decreased (15.532890 --> 12.112040).  Saving model ...
# Epoch: 6/500..  Training Loss: 0.020544..  Val Loss: 0.031981..  Val Accuracy: 98.03%
# Validation loss decreased (12.112040 --> 3.997612).  Saving model ...
# Epoch: 8/500..  Training Loss: 0.019421..  Val Loss: 0.031802..  Val Accuracy: 98.40%
# Validation loss decreased (3.997612 --> 3.975289).  Saving model ...
# Epoch: 10/500..  Training Loss: 0.017073..  Val Loss: 0.113937..  Val Accuracy: 95.10%
# Epoch: 12/500..  Training Loss: 0.016793..  Val Loss: 0.024224..  Val Accuracy: 98.70%
# Validation loss decreased (3.975289 --> 3.027944).  Saving model ...
# Epoch: 14/500..  Training Loss: 0.013183..  Val Loss: 0.020661..  Val Accuracy: 99.18%
# Validation loss decreased (3.027944 --> 2.582582).  Saving model ...
# Epoch: 16/500..  Training Loss: 0.012475..  Val Loss: 0.031415..  Val Accuracy: 98.47%
# Epoch: 18/500..  Training Loss: 0.011045..  Val Loss: 0.017310..  Val Accuracy: 99.15%
# Validation loss decreased (2.582582 --> 2.163736).  Saving model ...
# Epoch: 20/500..  Training Loss: 0.009074..  Val Loss: 0.016396..  Val Accuracy: 99.23%
# Validation loss decreased (2.163736 --> 2.049517).  Saving model ...
# Epoch: 22/500..  Training Loss: 0.009904..  Val Loss: 0.014346..  Val Accuracy: 99.28%
# Validation loss decreased (2.049517 --> 1.793251).  Saving model ...
# Epoch: 24/500..  Training Loss: 0.008040..  Val Loss: 0.013935..  Val Accuracy: 99.25%
# Validation loss decreased (1.793251 --> 1.741836).  Saving model ...
# Epoch: 26/500..  Training Loss: 0.007321..  Val Loss: 0.013592..  Val Accuracy: 99.30%
# Validation loss decreased (1.741836 --> 1.699045).  Saving model ...
# Epoch: 28/500..  Training Loss: 0.004888..  Val Loss: 0.007624..  Val Accuracy: 99.68%
# Validation loss decreased (1.699045 --> 0.952968).  Saving model ...
# Epoch: 30/500..  Training Loss: 0.005584..  Val Loss: 0.005703..  Val Accuracy: 99.82%
# Validation loss decreased (0.952968 --> 0.712896).  Saving model ...
# Epoch: 32/500..  Training Loss: 0.005455..  Val Loss: 0.008481..  Val Accuracy: 99.65%
# Epoch: 34/500..  Training Loss: 0.005100..  Val Loss: 0.004303..  Val Accuracy: 99.90%
# Validation loss decreased (0.712896 --> 0.537937).  Saving model ...
# Epoch: 36/500..  Training Loss: 0.003518..  Val Loss: 0.019757..  Val Accuracy: 99.43%
# Epoch: 38/500..  Training Loss: 0.004405..  Val Loss: 0.004209..  Val Accuracy: 99.85%
# Validation loss decreased (0.537937 --> 0.526070).  Saving model ...
# Epoch: 40/500..  Training Loss: 0.002813..  Val Loss: 0.025476..  Val Accuracy: 99.12%
# Epoch: 42/500..  Training Loss: 0.002943..  Val Loss: 0.003005..  Val Accuracy: 99.93%
# Validation loss decreased (0.526070 --> 0.375569).  Saving model ...
# Epoch: 44/500..  Training Loss: 0.002305..  Val Loss: 0.002398..  Val Accuracy: 99.93%
# Validation loss decreased (0.375569 --> 0.299704).  Saving model ...
# Epoch: 46/500..  Training Loss: 0.003898..  Val Loss: 0.002935..  Val Accuracy: 99.90%
# Epoch: 48/500..  Training Loss: 0.002257..  Val Loss: 0.002464..  Val Accuracy: 99.97%
# Epoch: 50/500..  Training Loss: 0.002307..  Val Loss: 0.002742..  Val Accuracy: 99.90%
# Epoch: 52/500..  Training Loss: 0.002188..  Val Loss: 0.002179..  Val Accuracy: 99.95%
# Validation loss decreased (0.299704 --> 0.272421).  Saving model ...
# Epoch: 54/500..  Training Loss: 0.001820..  Val Loss: 0.001961..  Val Accuracy: 99.97%
# Validation loss decreased (0.272421 --> 0.245104).  Saving model ...
# Epoch: 56/500..  Training Loss: 0.003264..  Val Loss: 0.001823..  Val Accuracy: 99.93%
# Validation loss decreased (0.245104 --> 0.227890).  Saving model ...
# Epoch: 58/500..  Training Loss: 0.002523..  Val Loss: 0.003784..  Val Accuracy: 99.90%
# Epoch: 60/500..  Training Loss: 0.001918..  Val Loss: 0.001421..  Val Accuracy: 99.97%
# Validation loss decreased (0.227890 --> 0.177581).  Saving model ...
# Epoch: 62/500..  Training Loss: 0.002966..  Val Loss: 0.020086..  Val Accuracy: 99.43%
# Epoch: 64/500..  Training Loss: 0.002656..  Val Loss: 0.002194..  Val Accuracy: 99.95%
# Epoch: 66/500..  Training Loss: 0.001951..  Val Loss: 0.002121..  Val Accuracy: 99.97%
# Epoch: 68/500..  Training Loss: 0.001783..  Val Loss: 0.002046..  Val Accuracy: 99.95%
# Epoch: 70/500..  Training Loss: 0.002087..  Val Loss: 0.001848..  Val Accuracy: 99.95%
# Epoch: 72/500..  Training Loss: 0.001902..  Val Loss: 0.001854..  Val Accuracy: 99.95%
# Epoch: 74/500..  Training Loss: 0.001605..  Val Loss: 0.003476..  Val Accuracy: 99.90%
# Epoch: 76/500..  Training Loss: 0.002503..  Val Loss: 0.005795..  Val Accuracy: 99.88%
# Epoch: 78/500..  Training Loss: 0.002267..  Val Loss: 0.005721..  Val Accuracy: 99.65%
# Epoch: 80/500..  Training Loss: 0.001485..  Val Loss: 0.002520..  Val Accuracy: 99.90%
# Epoch: 82/500..  Training Loss: 0.001358..  Val Loss: 0.001754..  Val Accuracy: 99.97%
# Epoch: 84/500..  Training Loss: 0.001316..  Val Loss: 0.001426..  Val Accuracy: 99.97%
# Epoch: 86/500..  Training Loss: 0.001035..  Val Loss: 0.003753..  Val Accuracy: 99.80%
# Epoch: 88/500..  Training Loss: 0.002085..  Val Loss: 0.004863..  Val Accuracy: 99.78%
# Epoch: 90/500..  Training Loss: 0.001475..  Val Loss: 0.006568..  Val Accuracy: 99.70%
# Epoch: 92/500..  Training Loss: 0.001704..  Val Loss: 0.009283..  Val Accuracy: 99.70%
# Epoch: 94/500..  Training Loss: 0.001476..  Val Loss: 0.001806..  Val Accuracy: 100.00%
# Epoch: 96/500..  Training Loss: 0.001105..  Val Loss: 0.000955..  Val Accuracy: 100.00%
# Validation loss decreased (0.177581 --> 0.119398).  Saving model ...
# Epoch: 98/500..  Training Loss: 0.001968..  Val Loss: 0.005979..  Val Accuracy: 99.82%
# Epoch: 100/500..  Training Loss: 0.001345..  Val Loss: 0.002077..  Val Accuracy: 99.95%
# Epoch: 102/500..  Training Loss: 0.001434..  Val Loss: 0.001960..  Val Accuracy: 99.93%
# Epoch: 104/500..  Training Loss: 0.001037..  Val Loss: 0.001541..  Val Accuracy: 99.97%
# Epoch: 106/500..  Training Loss: 0.001574..  Val Loss: 0.001561..  Val Accuracy: 100.00%
# Epoch: 108/500..  Training Loss: 0.002391..  Val Loss: 0.000963..  Val Accuracy: 100.00%
# Epoch: 110/500..  Training Loss: 0.001341..  Val Loss: 0.001456..  Val Accuracy: 99.95%
# Epoch: 112/500..  Training Loss: 0.000799..  Val Loss: 0.000852..  Val Accuracy: 100.00%
# Validation loss decreased (0.119398 --> 0.106529).  Saving model ...
# Epoch: 114/500..  Training Loss: 0.000743..  Val Loss: 0.000911..  Val Accuracy: 99.97%
# Epoch: 116/500..  Training Loss: 0.001273..  Val Loss: 0.001729..  Val Accuracy: 100.00%
# Epoch: 118/500..  Training Loss: 0.001448..  Val Loss: 0.005441..  Val Accuracy: 99.75%
# Epoch: 120/500..  Training Loss: 0.000728..  Val Loss: 0.001326..  Val Accuracy: 99.95%
# Epoch: 122/500..  Training Loss: 0.001619..  Val Loss: 0.003310..  Val Accuracy: 99.93%
# Epoch: 124/500..  Training Loss: 0.000972..  Val Loss: 0.001263..  Val Accuracy: 99.97%
# Epoch: 126/500..  Training Loss: 0.001608..  Val Loss: 0.001346..  Val Accuracy: 99.97%
# Epoch: 128/500..  Training Loss: 0.000908..  Val Loss: 0.001731..  Val Accuracy: 99.97%
# Epoch: 130/500..  Training Loss: 0.000964..  Val Loss: 0.002358..  Val Accuracy: 99.90%
# Epoch: 132/500..  Training Loss: 0.001200..  Val Loss: 0.001233..  Val Accuracy: 99.95%
# Epoch: 134/500..  Training Loss: 0.000730..  Val Loss: 0.003521..  Val Accuracy: 99.97%
# Epoch: 136/500..  Training Loss: 0.000855..  Val Loss: 0.001728..  Val Accuracy: 99.97%
# Epoch: 138/500..  Training Loss: 0.000873..  Val Loss: 0.002600..  Val Accuracy: 99.88%
# Epoch: 140/500..  Training Loss: 0.001195..  Val Loss: 0.002973..  Val Accuracy: 99.95%
# Epoch: 142/500..  Training Loss: 0.000549..  Val Loss: 0.005417..  Val Accuracy: 99.82%
# Epoch: 144/500..  Training Loss: 0.001881..  Val Loss: 0.005128..  Val Accuracy: 99.75%
# Epoch: 146/500..  Training Loss: 0.000735..  Val Loss: 0.001622..  Val Accuracy: 99.93%
# Epoch: 148/500..  Training Loss: 0.000486..  Val Loss: 0.000892..  Val Accuracy: 99.97%
# Epoch: 150/500..  Training Loss: 0.000996..  Val Loss: 0.001052..  Val Accuracy: 99.95%
# Epoch: 152/500..  Training Loss: 0.000787..  Val Loss: 0.001173..  Val Accuracy: 99.97%
# Epoch: 154/500..  Training Loss: 0.001064..  Val Loss: 0.004832..  Val Accuracy: 99.85%
# Epoch: 156/500..  Training Loss: 0.000742..  Val Loss: 0.000977..  Val Accuracy: 99.97%
# Epoch: 158/500..  Training Loss: 0.000849..  Val Loss: 0.001829..  Val Accuracy: 99.97%
# Epoch: 160/500..  Training Loss: 0.000708..  Val Loss: 0.003144..  Val Accuracy: 99.90%
# Epoch: 162/500..  Training Loss: 0.000359..  Val Loss: 0.001566..  Val Accuracy: 99.95%
# Epoch: 164/500..  Training Loss: 0.000318..  Val Loss: 0.002049..  Val Accuracy: 99.93%
# Epoch: 166/500..  Training Loss: 0.000636..  Val Loss: 0.005085..  Val Accuracy: 99.82%
# Epoch: 168/500..  Training Loss: 0.000906..  Val Loss: 0.001221..  Val Accuracy: 99.95%
# Epoch: 170/500..  Training Loss: 0.001573..  Val Loss: 0.005487..  Val Accuracy: 99.80%
# Epoch: 172/500..  Training Loss: 0.000604..  Val Loss: 0.000548..  Val Accuracy: 99.97%
# Validation loss decreased (0.106529 --> 0.068457).  Saving model ...
# Epoch: 174/500..  Training Loss: 0.000592..  Val Loss: 0.001111..  Val Accuracy: 99.93%
# Epoch: 176/500..  Training Loss: 0.000748..  Val Loss: 0.001190..  Val Accuracy: 99.97%
# Epoch: 178/500..  Training Loss: 0.000475..  Val Loss: 0.001808..  Val Accuracy: 99.95%
# Epoch: 180/500..  Training Loss: 0.000586..  Val Loss: 0.000688..  Val Accuracy: 99.97%
# Epoch: 182/500..  Training Loss: 0.000658..  Val Loss: 0.000282..  Val Accuracy: 100.00%
# Validation loss decreased (0.068457 --> 0.035298).  Saving model ...
# Epoch: 184/500..  Training Loss: 0.000324..  Val Loss: 0.000882..  Val Accuracy: 99.97%
# Epoch: 186/500..  Training Loss: 0.000352..  Val Loss: 0.001231..  Val Accuracy: 99.93%
# Epoch: 188/500..  Training Loss: 0.000525..  Val Loss: 0.000697..  Val Accuracy: 99.95%
# Epoch: 190/500..  Training Loss: 0.000257..  Val Loss: 0.004868..  Val Accuracy: 99.78%
# Epoch: 192/500..  Training Loss: 0.001767..  Val Loss: 0.001552..  Val Accuracy: 99.95%
# Epoch: 194/500..  Training Loss: 0.000710..  Val Loss: 0.000329..  Val Accuracy: 100.00%
# Epoch: 196/500..  Training Loss: 0.000367..  Val Loss: 0.000997..  Val Accuracy: 99.95%
# Epoch: 198/500..  Training Loss: 0.000661..  Val Loss: 0.000771..  Val Accuracy: 100.00%
# Epoch: 200/500..  Training Loss: 0.001209..  Val Loss: 0.000421..  Val Accuracy: 100.00%
# Epoch: 202/500..  Training Loss: 0.000572..  Val Loss: 0.000264..  Val Accuracy: 100.00%
# Validation loss decreased (0.035298 --> 0.033061).  Saving model ...
# Epoch: 204/500..  Training Loss: 0.001181..  Val Loss: 0.000388..  Val Accuracy: 100.00%
# Epoch: 206/500..  Training Loss: 0.000587..  Val Loss: 0.000618..  Val Accuracy: 99.97%
# Epoch: 208/500..  Training Loss: 0.000818..  Val Loss: 0.000530..  Val Accuracy: 99.97%
# Epoch: 210/500..  Training Loss: 0.000468..  Val Loss: 0.000624..  Val Accuracy: 99.95%
# Epoch: 212/500..  Training Loss: 0.001331..  Val Loss: 0.001189..  Val Accuracy: 99.95%
# Epoch: 214/500..  Training Loss: 0.000643..  Val Loss: 0.001919..  Val Accuracy: 99.93%
# Epoch: 216/500..  Training Loss: 0.000597..  Val Loss: 0.000830..  Val Accuracy: 99.97%
# Epoch: 218/500..  Training Loss: 0.000585..  Val Loss: 0.000685..  Val Accuracy: 99.97%
# Epoch: 220/500..  Training Loss: 0.000308..  Val Loss: 0.000179..  Val Accuracy: 100.00%
# Validation loss decreased (0.033061 --> 0.022355).  Saving model ...
# Epoch: 222/500..  Training Loss: 0.002131..  Val Loss: 0.000572..  Val Accuracy: 100.00%
# Epoch: 224/500..  Training Loss: 0.000252..  Val Loss: 0.000530..  Val Accuracy: 99.97%
# Epoch: 226/500..  Training Loss: 0.000378..  Val Loss: 0.001686..  Val Accuracy: 99.93%
# Epoch: 228/500..  Training Loss: 0.000271..  Val Loss: 0.000760..  Val Accuracy: 99.95%
# Epoch: 230/500..  Training Loss: 0.000307..  Val Loss: 0.001891..  Val Accuracy: 99.95%
# Epoch: 232/500..  Training Loss: 0.000460..  Val Loss: 0.000417..  Val Accuracy: 100.00%
# Epoch: 234/500..  Training Loss: 0.001198..  Val Loss: 0.002074..  Val Accuracy: 99.97%
# Epoch: 236/500..  Training Loss: 0.000674..  Val Loss: 0.000753..  Val Accuracy: 99.95%
# Epoch: 238/500..  Training Loss: 0.000429..  Val Loss: 0.000981..  Val Accuracy: 99.97%
# Epoch: 240/500..  Training Loss: 0.000253..  Val Loss: 0.000987..  Val Accuracy: 99.97%
# Epoch: 242/500..  Training Loss: 0.000712..  Val Loss: 0.001706..  Val Accuracy: 99.90%
# Epoch: 244/500..  Training Loss: 0.000473..  Val Loss: 0.002381..  Val Accuracy: 99.93%
# Epoch: 246/500..  Training Loss: 0.000381..  Val Loss: 0.000332..  Val Accuracy: 100.00%
# Epoch: 248/500..  Training Loss: 0.000392..  Val Loss: 0.001179..  Val Accuracy: 99.97%
# Epoch: 250/500..  Training Loss: 0.000572..  Val Loss: 0.000719..  Val Accuracy: 99.95%
# Epoch: 252/500..  Training Loss: 0.000432..  Val Loss: 0.000440..  Val Accuracy: 99.97%
# Epoch: 254/500..  Training Loss: 0.000560..  Val Loss: 0.000442..  Val Accuracy: 100.00%
# Epoch: 256/500..  Training Loss: 0.000542..  Val Loss: 0.001913..  Val Accuracy: 99.97%
# Epoch: 258/500..  Training Loss: 0.000513..  Val Loss: 0.000619..  Val Accuracy: 99.95%
# Epoch: 260/500..  Training Loss: 0.000278..  Val Loss: 0.001197..  Val Accuracy: 99.97%
# Epoch: 262/500..  Training Loss: 0.000433..  Val Loss: 0.000673..  Val Accuracy: 100.00%
# Epoch: 264/500..  Training Loss: 0.000288..  Val Loss: 0.000513..  Val Accuracy: 99.95%
# Epoch: 266/500..  Training Loss: 0.000224..  Val Loss: 0.000313..  Val Accuracy: 99.97%
# Epoch: 268/500..  Training Loss: 0.000370..  Val Loss: 0.001496..  Val Accuracy: 99.93%
# Epoch: 270/500..  Training Loss: 0.001024..  Val Loss: 0.000540..  Val Accuracy: 99.97%
# Epoch: 272/500..  Training Loss: 0.000285..  Val Loss: 0.002137..  Val Accuracy: 99.95%
# Epoch: 274/500..  Training Loss: 0.000132..  Val Loss: 0.000394..  Val Accuracy: 100.00%
# Epoch: 276/500..  Training Loss: 0.000590..  Val Loss: 0.000301..  Val Accuracy: 100.00%
# Epoch: 278/500..  Training Loss: 0.000786..  Val Loss: 0.000328..  Val Accuracy: 100.00%
# Epoch: 280/500..  Training Loss: 0.000407..  Val Loss: 0.001415..  Val Accuracy: 99.97%
# Epoch: 282/500..  Training Loss: 0.000960..  Val Loss: 0.000760..  Val Accuracy: 99.95%
# Epoch: 284/500..  Training Loss: 0.001226..  Val Loss: 0.000851..  Val Accuracy: 99.97%
# Epoch: 286/500..  Training Loss: 0.000435..  Val Loss: 0.000987..  Val Accuracy: 99.93%
# Epoch: 288/500..  Training Loss: 0.000116..  Val Loss: 0.000495..  Val Accuracy: 99.97%
# Epoch: 290/500..  Training Loss: 0.000916..  Val Loss: 0.002419..  Val Accuracy: 99.95%
# Epoch: 292/500..  Training Loss: 0.000199..  Val Loss: 0.000164..  Val Accuracy: 100.00%
# Validation loss decreased (0.022355 --> 0.020473).  Saving model ...
# Epoch: 294/500..  Training Loss: 0.000263..  Val Loss: 0.000383..  Val Accuracy: 99.97%
# Epoch: 296/500..  Training Loss: 0.000825..  Val Loss: 0.001061..  Val Accuracy: 99.97%
# Epoch: 298/500..  Training Loss: 0.000599..  Val Loss: 0.001120..  Val Accuracy: 99.97%
# Epoch: 300/500..  Training Loss: 0.000306..  Val Loss: 0.000596..  Val Accuracy: 99.97%
# Epoch: 302/500..  Training Loss: 0.000240..  Val Loss: 0.001289..  Val Accuracy: 99.95%
# Epoch: 304/500..  Training Loss: 0.000704..  Val Loss: 0.000936..  Val Accuracy: 99.95%
# Epoch: 306/500..  Training Loss: 0.000354..  Val Loss: 0.001089..  Val Accuracy: 99.97%
# Epoch: 308/500..  Training Loss: 0.000319..  Val Loss: 0.000470..  Val Accuracy: 99.97%
# Epoch: 310/500..  Training Loss: 0.000765..  Val Loss: 0.001666..  Val Accuracy: 99.95%
# Epoch: 312/500..  Training Loss: 0.000961..  Val Loss: 0.000513..  Val Accuracy: 99.97%
# Epoch: 314/500..  Training Loss: 0.000214..  Val Loss: 0.000863..  Val Accuracy: 99.97%
# Epoch: 316/500..  Training Loss: 0.000127..  Val Loss: 0.000343..  Val Accuracy: 99.97%
# Epoch: 318/500..  Training Loss: 0.000403..  Val Loss: 0.000287..  Val Accuracy: 100.00%
# Epoch: 320/500..  Training Loss: 0.000091..  Val Loss: 0.000137..  Val Accuracy: 100.00%
# Validation loss decreased (0.020473 --> 0.017126).  Saving model ...
# Epoch: 322/500..  Training Loss: 0.000385..  Val Loss: 0.001901..  Val Accuracy: 99.93%
# Epoch: 324/500..  Training Loss: 0.000811..  Val Loss: 0.000881..  Val Accuracy: 99.97%
# Epoch: 326/500..  Training Loss: 0.000226..  Val Loss: 0.000068..  Val Accuracy: 100.00%
# Validation loss decreased (0.017126 --> 0.008520).  Saving model ...
# Epoch: 328/500..  Training Loss: 0.000276..  Val Loss: 0.000668..  Val Accuracy: 100.00%
# Epoch: 330/500..  Training Loss: 0.001995..  Val Loss: 0.000865..  Val Accuracy: 99.97%
# Epoch: 332/500..  Training Loss: 0.000183..  Val Loss: 0.000496..  Val Accuracy: 100.00%
# Epoch: 334/500..  Training Loss: 0.000331..  Val Loss: 0.000729..  Val Accuracy: 99.95%
# Epoch: 336/500..  Training Loss: 0.000882..  Val Loss: 0.001737..  Val Accuracy: 99.95%
# Epoch: 338/500..  Training Loss: 0.000064..  Val Loss: 0.000320..  Val Accuracy: 100.00%
# Epoch: 340/500..  Training Loss: 0.000074..  Val Loss: 0.000107..  Val Accuracy: 100.00%
# Epoch: 342/500..  Training Loss: 0.000350..  Val Loss: 0.003045..  Val Accuracy: 99.88%
# Epoch: 344/500..  Training Loss: 0.000247..  Val Loss: 0.000858..  Val Accuracy: 99.97%
# Epoch: 346/500..  Training Loss: 0.000393..  Val Loss: 0.000079..  Val Accuracy: 100.00%
# Epoch: 348/500..  Training Loss: 0.000081..  Val Loss: 0.000081..  Val Accuracy: 100.00%
# Epoch: 350/500..  Training Loss: 0.000235..  Val Loss: 0.000140..  Val Accuracy: 100.00%
# Epoch: 352/500..  Training Loss: 0.000157..  Val Loss: 0.000064..  Val Accuracy: 100.00%
# Validation loss decreased (0.008520 --> 0.008010).  Saving model ...
# Epoch: 354/500..  Training Loss: 0.001454..  Val Loss: 0.003590..  Val Accuracy: 99.88%
# Epoch: 356/500..  Training Loss: 0.000238..  Val Loss: 0.000191..  Val Accuracy: 100.00%
# Epoch: 358/500..  Training Loss: 0.000121..  Val Loss: 0.000171..  Val Accuracy: 100.00%
# Epoch: 360/500..  Training Loss: 0.000145..  Val Loss: 0.000807..  Val Accuracy: 99.97%
# Epoch: 362/500..  Training Loss: 0.000045..  Val Loss: 0.000056..  Val Accuracy: 100.00%
# Validation loss decreased (0.008010 --> 0.007005).  Saving model ...
# Epoch: 364/500..  Training Loss: 0.001183..  Val Loss: 0.000713..  Val Accuracy: 99.97%
# Epoch: 366/500..  Training Loss: 0.000092..  Val Loss: 0.000757..  Val Accuracy: 99.97%
# Epoch: 368/500..  Training Loss: 0.000505..  Val Loss: 0.008642..  Val Accuracy: 99.82%
# Epoch: 370/500..  Training Loss: 0.000063..  Val Loss: 0.000374..  Val Accuracy: 100.00%
# Epoch: 372/500..  Training Loss: 0.001148..  Val Loss: 0.000666..  Val Accuracy: 99.97%
# Epoch: 374/500..  Training Loss: 0.000396..  Val Loss: 0.000617..  Val Accuracy: 100.00%
# Epoch: 376/500..  Training Loss: 0.000069..  Val Loss: 0.000158..  Val Accuracy: 100.00%
# Epoch: 378/500..  Training Loss: 0.000671..  Val Loss: 0.000051..  Val Accuracy: 100.00%
# Validation loss decreased (0.007005 --> 0.006331).  Saving model ...
# Epoch: 380/500..  Training Loss: 0.000031..  Val Loss: 0.000142..  Val Accuracy: 100.00%
# Epoch: 382/500..  Training Loss: 0.000516..  Val Loss: 0.000543..  Val Accuracy: 99.97%
# Epoch: 384/500..  Training Loss: 0.000035..  Val Loss: 0.000045..  Val Accuracy: 100.00%
# Validation loss decreased (0.006331 --> 0.005673).  Saving model ...
# Epoch: 386/500..  Training Loss: 0.000378..  Val Loss: 0.000636..  Val Accuracy: 99.97%
# Epoch: 388/500..  Training Loss: 0.000151..  Val Loss: 0.001943..  Val Accuracy: 99.95%
# Epoch: 390/500..  Training Loss: 0.000921..  Val Loss: 0.000482..  Val Accuracy: 99.97%
# Epoch: 392/500..  Training Loss: 0.000170..  Val Loss: 0.000178..  Val Accuracy: 100.00%
# Epoch: 394/500..  Training Loss: 0.000155..  Val Loss: 0.000174..  Val Accuracy: 100.00%
# Epoch: 396/500..  Training Loss: 0.000042..  Val Loss: 0.000820..  Val Accuracy: 99.97%
# Epoch: 398/500..  Training Loss: 0.000161..  Val Loss: 0.000596..  Val Accuracy: 99.95%
# Epoch: 400/500..  Training Loss: 0.000070..  Val Loss: 0.000184..  Val Accuracy: 100.00%
# Epoch: 402/500..  Training Loss: 0.000075..  Val Loss: 0.000098..  Val Accuracy: 100.00%
# Epoch: 404/500..  Training Loss: 0.000014..  Val Loss: 0.000029..  Val Accuracy: 100.00%
# Validation loss decreased (0.005673 --> 0.003590).  Saving model ...
# Epoch: 406/500..  Training Loss: 0.000091..  Val Loss: 0.002618..  Val Accuracy: 99.97%
# Epoch: 408/500..  Training Loss: 0.000340..  Val Loss: 0.013093..  Val Accuracy: 99.53%
# Epoch: 410/500..  Training Loss: 0.000132..  Val Loss: 0.001173..  Val Accuracy: 99.95%
# Epoch: 412/500..  Training Loss: 0.000090..  Val Loss: 0.000127..  Val Accuracy: 100.00%
# Epoch: 414/500..  Training Loss: 0.000480..  Val Loss: 0.003298..  Val Accuracy: 99.93%
# Epoch: 416/500..  Training Loss: 0.000168..  Val Loss: 0.009017..  Val Accuracy: 99.78%
# Epoch: 418/500..  Training Loss: 0.000591..  Val Loss: 0.000194..  Val Accuracy: 100.00%
# Epoch: 420/500..  Training Loss: 0.000127..  Val Loss: 0.000501..  Val Accuracy: 99.97%
# Epoch: 422/500..  Training Loss: 0.000112..  Val Loss: 0.000271..  Val Accuracy: 100.00%
# Epoch: 424/500..  Training Loss: 0.000112..  Val Loss: 0.000155..  Val Accuracy: 100.00%
# Epoch: 426/500..  Training Loss: 0.000388..  Val Loss: 0.000487..  Val Accuracy: 99.97%
# Epoch: 428/500..  Training Loss: 0.000218..  Val Loss: 0.000324..  Val Accuracy: 99.97%
# Epoch: 430/500..  Training Loss: 0.001007..  Val Loss: 0.001021..  Val Accuracy: 99.97%
# Epoch: 432/500..  Training Loss: 0.000068..  Val Loss: 0.000148..  Val Accuracy: 100.00%
# Epoch: 434/500..  Training Loss: 0.000036..  Val Loss: 0.000070..  Val Accuracy: 100.00%
# Epoch: 436/500..  Training Loss: 0.000919..  Val Loss: 0.000275..  Val Accuracy: 100.00%
# Epoch: 438/500..  Training Loss: 0.000085..  Val Loss: 0.000146..  Val Accuracy: 100.00%
# Epoch: 440/500..  Training Loss: 0.000245..  Val Loss: 0.000943..  Val Accuracy: 99.97%
# Epoch: 442/500..  Training Loss: 0.000165..  Val Loss: 0.001558..  Val Accuracy: 99.93%
# Epoch: 444/500..  Training Loss: 0.000186..  Val Loss: 0.000376..  Val Accuracy: 99.97%
# Epoch: 446/500..  Training Loss: 0.000202..  Val Loss: 0.000947..  Val Accuracy: 99.95%
# Epoch: 448/500..  Training Loss: 0.000688..  Val Loss: 0.000479..  Val Accuracy: 99.97%
# Epoch: 450/500..  Training Loss: 0.000699..  Val Loss: 0.000397..  Val Accuracy: 99.97%
# Epoch: 452/500..  Training Loss: 0.000342..  Val Loss: 0.000502..  Val Accuracy: 99.97%
# Epoch: 454/500..  Training Loss: 0.000441..  Val Loss: 0.002206..  Val Accuracy: 99.90%
# Epoch: 456/500..  Training Loss: 0.000138..  Val Loss: 0.000176..  Val Accuracy: 100.00%
# Epoch: 458/500..  Training Loss: 0.000020..  Val Loss: 0.000331..  Val Accuracy: 99.97%
# Epoch: 460/500..  Training Loss: 0.000488..  Val Loss: 0.000208..  Val Accuracy: 100.00%
# Epoch: 462/500..  Training Loss: 0.000407..  Val Loss: 0.000921..  Val Accuracy: 99.93%
# Epoch: 464/500..  Training Loss: 0.000542..  Val Loss: 0.000192..  Val Accuracy: 100.00%
# Epoch: 466/500..  Training Loss: 0.000016..  Val Loss: 0.000048..  Val Accuracy: 100.00%
# Epoch: 468/500..  Training Loss: 0.000128..  Val Loss: 0.000252..  Val Accuracy: 99.97%
# Epoch: 470/500..  Training Loss: 0.000907..  Val Loss: 0.001945..  Val Accuracy: 99.97%
# Epoch: 472/500..  Training Loss: 0.000122..  Val Loss: 0.000771..  Val Accuracy: 99.97%
# Epoch: 474/500..  Training Loss: 0.000327..  Val Loss: 0.001926..  Val Accuracy: 99.93%
# Epoch: 476/500..  Training Loss: 0.000117..  Val Loss: 0.000394..  Val Accuracy: 100.00%
# Epoch: 478/500..  Training Loss: 0.000229..  Val Loss: 0.000955..  Val Accuracy: 99.97%
# Epoch: 480/500..  Training Loss: 0.000470..  Val Loss: 0.000331..  Val Accuracy: 99.97%
# Epoch: 482/500..  Training Loss: 0.001225..  Val Loss: 0.001251..  Val Accuracy: 99.93%
# Epoch: 484/500..  Training Loss: 0.000079..  Val Loss: 0.000282..  Val Accuracy: 100.00%
# Epoch: 486/500..  Training Loss: 0.000101..  Val Loss: 0.000382..  Val Accuracy: 99.97%
# Epoch: 488/500..  Training Loss: 0.000067..  Val Loss: 0.000487..  Val Accuracy: 99.97%
# Epoch: 490/500..  Training Loss: 0.000288..  Val Loss: 0.000451..  Val Accuracy: 99.97%
# Epoch: 492/500..  Training Loss: 0.000031..  Val Loss: 0.000295..  Val Accuracy: 99.97%
# Epoch: 494/500..  Training Loss: 0.000088..  Val Loss: 0.000104..  Val Accuracy: 100.00%
# Epoch: 496/500..  Training Loss: 0.000041..  Val Loss: 0.000151..  Val Accuracy: 100.00%
# Epoch: 498/500..  Training Loss: 0.001013..  Val Loss: 0.000274..  Val Accuracy: 100.00%
# Epoch: 500/500..  Training Loss: 0.000246..  Val Loss: 0.002279..  Val Accuracy: 99.93%

# %%
path = "../data/testset"
file_list = os.listdir(path)
print(file_list)
# Out:
# ['x_test_1500_10.npy', 'x_test_2700_25.npy', 'y_test_1500_10.npy', 'y_test_2700_25.npy', 'z_test_1500_10.npy', 'z_test_2700_25.npy']

# %%
x_test_2700_25=np.load("../data/testset/"+file_list[1])
y_test_2700_25=np.load("../data/testset/"+file_list[3])
z_test_2700_25=np.load("../data/testset/"+file_list[5])

# %%
data_2700=np.concatenate((np.expand_dims(x_test_2700_25, axis=1),np.expand_dims(y_test_2700_25, axis=1),np.expand_dims(z_test_2700_25, axis=1)),axis=1)

# %%
#depthwise version
class customdataset2(Dataset):
    def __init__(self, data): 
        super().__init__()
        self.data=torch.tensor(data)
        
    def __len__(self):
        return len(self.data)
  
    def __getitem__(self, idx):
        x = self.data[idx]
                
        return  x.to(device).float()
testdataset_2700 = customdataset2(data_2700)
testdataloader_2700 = DataLoader(testdataset_2700, batch_size=1, shuffle=False, drop_last=False )

# %%
modelll.load_state_dict(torch.load('./malstm_msn_cv_cond_2_esb_3_4.pt'))
# Out:
# <All keys matched successfully>

# %%
pred2and4diagnosis=test(modelll,testdataloader_2700)

# %%
pred2and4diagnosis[6154]
# Out:
# array(0, dtype=int64)

# %%
pred2and4diagnosis[7092]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[10012]
# Out:
# array(0, dtype=int64)

# %%
pred2and4diagnosis[10844]
# Out:
# array(0, dtype=int64)

# %%
pred2and4diagnosis[11737]
# Out:
# array(0, dtype=int64)

# %%
pred2and4diagnosis[13693]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[14421]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[14516]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[15206]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[16611]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[16947]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[17059]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[17293]
# Out:
# array(1, dtype=int64)

# %%
pred2and4diagnosis[18497]
# Out:
# array(1, dtype=int64)

# %%
for i in pred2and4diagnosis:
    if i!=0:
        print("false")

# %%
pred2and4diagnosis
# Out:
# [array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  array(0, dtype=int64),
#  ...]
