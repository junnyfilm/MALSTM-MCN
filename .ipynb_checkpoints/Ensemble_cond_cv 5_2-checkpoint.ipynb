# %% [markdown]
# ## 앙상블 코드

# %% [markdown]
# - cv값이랑 cond값 지정해주세요 cv 5, cond 2 , 내부 앙상블 5개 => 총 50개 모델 필요

# %%
cv=5
cond=2

# %%
import os
import glob
import numpy as np
import pandas as pd
from pathlib import Path
from numpy import inf
from numpy import array
from numpy import argmax
import pickle
import argparse, sys, os
import time
from collections import Counter

from torch.utils.data import DataLoader,Dataset
import torchvision.transforms as transforms
from torchvision import models
import torch.nn as nn
import torch
from torch.autograd import Variable
from torchsummary import summary
import torchvision.transforms.functional as Fv
from torch.optim import lr_scheduler
import torchvision
import torch.optim as optim
import torch.nn.functional as F
import torch.nn.init as init
from torchvision import datasets, transforms


from sklearn.manifold import TSNE
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn import metrics
from tqdm import tqdm
import matplotlib.pyplot as plt
import random
from torchsummary import summary
from torch.optim import lr_scheduler
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init

print(torch.__version__)
print(torch.cuda.is_available())
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.nn.parameter import Parameter
from torch import topk
from tqdm.notebook import tqdm # 프로세스 바
from matplotlib import pyplot as plt
import matplotlib
# matplotlib.use('agg')
# device = torch.device("cuda:%d" % 0 if torch.cuda.is_available() else "cpu")
import numpy as np
# from dataloader_hilbert_att import DataLoader
import os
from torch.autograd import Variable


# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# 1.12.1
# True

# %%
path= "\\\\147.47.239.143\\SHRM-robotgear\\ICPHM2023\\pickle\\"

# %%
# # read data

with open(path+'cross_val_train_set_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_train_set = pickle.load(f)
with open(path+'cross_val_train_label_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_train_label = pickle.load(f)
with open(path+'cross_val_test_set_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_test_set = pickle.load(f)
with open(path+'cross_val_test_label_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_test_label = pickle.load(f)

# %%
#depthwise version
class customdataset(Dataset):
    def __init__(self, data, label): 
        super().__init__()
        self.data=torch.tensor(data)
        self.label=torch.tensor(label)
        
    def __len__(self):
        return len(self.label)
  
    def __getitem__(self, idx):
        x = self.data[idx]
        label = self.label[idx] 
                
        return  x.to(device).float(), label.to(device).long()

def loaders(tr_data,tr_label,ts_data,ts_label,random_state):
    train_set, valid_set, train_label, valid_label = train_test_split(tr_data, tr_label,random_state=random_state, train_size=0.75)
    
    traindataset = customdataset(train_set, train_label)
    validdataset = customdataset(valid_set, valid_label)
    testdataset = customdataset(ts_data, ts_label)
    
    traindataloader = DataLoader(traindataset, batch_size=32, shuffle=True, drop_last=True )
    validdataloader = DataLoader(validdataset, batch_size=32, shuffle=True, drop_last=True )
    testdataloader = DataLoader(testdataset, batch_size=1, shuffle=False, drop_last=False )
    
    return traindataloader,validdataloader,testdataloader

# %% [markdown]
# ### Models

# %%
savepath= '\\\\147.47.239.143\\SHRM-robotgear\\ICPHM2023\\형민\\2023 ICPHM\\앙상블모델\\'

# %% [markdown]
# #### 기본 Loss

# %%
class SELayer(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1)
        return x * y.expand_as(x)

# %%
class Dilated_Module(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Dilated_Module,self).__init__()
        self.conv1=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5)//2), dilation=1, bias=False)        
        self.conv2=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*2)//2), dilation=3, bias=False)        
        self.conv3=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*4)//2), dilation=5, bias=False)
        self.conv4=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*6)//2), dilation=7, bias=False)
        
    def forward(self,x):
        ''' input x should be in size [B,F,T], where 
            B = Batch size
            F = features
            T = Time samples
        '''
        x1=self.conv1(x)
        x2=self.conv2(x)
        x3=self.conv3(x)
        x4=self.conv4(x)
        
        y=torch.cat([x1,x2,x3,x4],dim=1)
        
        return y

# %%
class MLSTMfcn_MSN(nn.Module):
    def __init__(self, *, num_classes, num_features,
                 num_lstm_out, num_lstm_layers=1, 
                 conv1_nf=128, conv2_nf=256, conv3_nf=128,
                 lstm_drop_p=0.8, fc_drop_p=0.3):
        super(MLSTMfcn_MSN, self).__init__()

        self.num_classes = num_classes
        self.num_features = num_features

        self.num_lstm_out = num_lstm_out
        self.num_lstm_layers = num_lstm_layers

        
        self.conv1_nf = conv1_nf
        self.conv2_nf = conv2_nf
        self.conv3_nf = conv3_nf

        self.dilated_1=Dilated_Module(self.num_features, self.conv1_nf)
        self.dilated_2=Dilated_Module(self.conv1_nf, self.conv2_nf)
        self.dilated_3=Dilated_Module(self.conv2_nf, self.conv3_nf)

        self.lstm_drop_p = lstm_drop_p
        self.fc_drop_p = fc_drop_p

        self.lstm = nn.LSTM(input_size=self.num_features, 
                            hidden_size=self.num_lstm_out,
                            num_layers=self.num_lstm_layers,
                            batch_first=True)
        
        self.bn1 = nn.BatchNorm1d(self.conv1_nf)
        self.bn2 = nn.BatchNorm1d(self.conv2_nf)
        self.bn3 = nn.BatchNorm1d(self.conv3_nf)

        self.se1 = SELayer(self.conv1_nf)  # ex 128
        self.se2 = SELayer(self.conv2_nf)  # ex 256

        self.relu = nn.ReLU()
        self.lstmDrop = nn.Dropout(self.lstm_drop_p)
        self.convDrop = nn.Dropout(self.fc_drop_p)

        self.fc = nn.Linear(self.conv3_nf+self.num_lstm_out, self.num_classes)
    
    def forward(self, x):
        ''' input x should be in size [B,T,F], where 
            B = Batch size
            T = Time samples
            F = features
        '''
        x=x.transpose(2,1)
        ''' input x should be in size [B,T,F], where 
            B = Batch size
            T = Time samples
            F = features
        '''       
        # x1 = nn.utils.rnn.pack_padded_sequence(x, seq_lens, 
        #                                        batch_first=True, 
        #                                        enforce_sorted=False)
        x1, (ht,ct) = self.lstm(x)
        x1 = self.lstmDrop(x1)
        # x1, _ = nn.utils.rnn.pad_packed_sequence(x1, batch_first=True, 
        #                                          padding_value=0.0)
        # print(x1.size())
        x1 = x1[:,-1,:]
        
        x2 = x.transpose(2,1)
        x2 = self.convDrop(self.relu(self.bn1(self.dilated_1(x2))))
        # print(x2.size())
        x2 = self.se1(x2)
        x2 = self.convDrop(self.relu(self.bn2(self.dilated_2(x2))))
        # print(x2.size())
        x2 = self.se2(x2)
        x2 = self.convDrop(self.relu(self.bn3(self.dilated_3(x2))))
        # print(x2.size())
        x2 = torch.mean(x2,2)
        
        x_all = torch.cat((x1,x2),dim=1)
        x_out = self.fc(x_all)
        x_out = F.log_softmax(x_out, dim=1)

        return x_out,x_all

# %% [markdown]
# ### 공통실행

# %%
def validation(model, testloader, criterion):
    accuracy = 0
    test_loss = 0
    for inputs, labels in testloader:
        inputs = inputs.float()
        inputs, labels = inputs.to(device), labels.to(device)

        output,_ = model.forward(inputs)
        test_loss += criterion(output, labels).item()

        ## Calculating the accuracy 
        # Model's output is log-softmax, take exponential to get the probabilities
        ps = torch.exp(output)
        # Class with highest probability is our predicted class, compare with true label
        equality = (labels.data == ps.max(1)[1])
        # Accuracy is number of correct predictions divided by all predictions, just take the mean
        accuracy += equality.type_as(torch.FloatTensor()).mean()

    return test_loss,accuracy

# %%
def fail_index(pred, real, cross_val_num):
    failed=[]
    with open('test_fold_index_2.pickle', 'rb') as f:
        test_fold_index = pickle.load(f)
    
    for i in range(len(pred)):
        if pred[i].item()!=real[i].detach().cpu().item():
            failed.append(test_fold_index[cross_val_num-1][i])
    
    return failed

import seaborn as sn
def confusionmatrix(y_pred1, y_test1, column=['class0','class1','class2','class3','class4']):
    # y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    # _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)
    a=[]
    b=[]
    for i in range(len(y_test1)):
        a.append(y_test1[i].detach().cpu().item())
        b.append(y_pred1[i].item())
    y_test=a
    y_pred=b
    df_cm = pd.DataFrame(confusion_matrix(y_test,y_pred))
    df_cm.index=column
    df_cm.columns=column
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    b, t = plt.ylim() 
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t)
    

    df_cm =df_cm / df_cm.astype(np.float).sum(axis=1)
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    b, t = plt.ylim() 
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t)

    
def test(classifier, dataloader):
    # setup the network
    predlist=[]
    real=[]    

    classifier.eval()
    correct = 0.0
    
    max_tr_score = 0
    max_val_score = 0
    for batch_idx, (data) in enumerate(dataloader):
    
        signal1,label = data
        signal1,label = Variable(signal1.cuda()),Variable(label.cuda().long())
        out,_ = classifier(signal1)   

        pred = out.data.max(1, keepdim= True)[1]
        predlist.append(pred.cpu().detach().numpy().squeeze())
        real.append(label)        
        correct += pred.eq(label.data.view_as(pred)).cpu().sum()

        # predlist.append(pred)
    print('\nAccuracy: {}/{} ({:.4f}%)\n'.format(
        correct, len(dataloader.dataset), 100. * float(correct) / len(dataloader.dataset)))
    acc=100. * float(correct) / len(dataloader.dataset)
    return acc,predlist,real

# %%
from sklearn.model_selection import ParameterGrid
# 하이퍼파라미터 그리드 설정
param_grid = {
    'lr': [0.001, 0.0005, 0.0001],
    'batch_size': [32, 64, 128],
    'hidden_size': [8, 64, 128],
    'optimizer': ['Adam', 'RMSprop', 'SGD']
}

# %%
lr = param_grid['lr'][0]
batch_size = param_grid['batch_size'][0]
num_lstm_out = param_grid['hidden_size'][0]
optimizer_name = param_grid['optimizer'][0]

# %% [markdown]
# ### 학습

# %% [markdown]
# - 랜덤시드
#   - 4444(사랑하는사람이사랑하는사람에게)
#   - 2514(이세상에서오직하나뿐인사람)
#   - 4040(사랑사랑)
#   - 8282(빨리빨리)
#   - 1004(천사)

# %%
randomseedlist=[4444,2514,4040,8282,1004]

# %%
def final(modelname,train_set, train_label, test_set, test_label,esbnum):
    train_loader,valid_loader,test_loader=loaders(train_set, train_label,test_set,test_label,randomseedlist[esbnum])


    valid_loss_min = np.Inf # track change in validation loss
    criterion = nn.NLLLoss().to(device)
    epochs=500
    print_every=1000

    # 0.001 32 8 Adam
    lr = param_grid['lr'][0]
    batch_size = param_grid['batch_size'][0]
    num_lstm_out = param_grid['hidden_size'][0]
    optimizer_name = param_grid['optimizer'][0]

    model =modelname.to(device)


    # 옵티마이저 설정
    if optimizer_name == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_name == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=lr)
    elif optimizer_name == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=lr)



    #train
    steps = 0

    for e in tqdm(range(epochs)):
        train_loss = 0.0
        valid_loss = 0.0

        model.train()
        for inputs, labels in train_loader:
            steps += 1

            inputs = inputs.float()
            inputs, labels = inputs.to(device),labels.to(device)

            optimizer.zero_grad()
            # print(inputs.shape)
            # print(model.forward(inputs).shape)
            output,_ = model.forward(inputs)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            if steps % print_every == 0:
                model.eval()

                with torch.no_grad():
                    valid_loss, accuracy = validation(model, valid_loader, criterion)

                print("Epoch: {}/{}.. ".format(e+1, epochs),
                      "Training Loss: {:.6f}.. ".format(train_loss/print_every),
                      "Val Loss: {:.6f}.. ".format(valid_loss/len(valid_loader)),
                      "Val Accuracy: {:.2f}%".format(accuracy/len(valid_loader)*100))

                # save model if validation loss has decreased
                if valid_loss <= valid_loss_min:
                    print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
                    valid_loss_min,
                    valid_loss))
                    torch.save(model.state_dict(), savepath+ 'malstm_msn_cv_'+str(cv)+'_cond_'+str(cond)+'_esb_'+str(esbnum)+'.pt')
                    valid_loss_min = valid_loss

                train_loss = 0

                model.train()
    return model

# %% [markdown]
# ### ensemble1

# %%
ensemble1 = MLSTMfcn_MSN(num_classes=5, 
                           num_features=3,
                           num_lstm_out=num_lstm_out).to(device)

# %%
ensemble1_best=final(ensemble1,cross_val_train_set,cross_val_train_label,cross_val_test_set,cross_val_test_label,0)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch: 2/500..  Training Loss: 0.010118..  Val Loss: 0.789724..  Val Accuracy: 72.15%
# Validation loss decreased (inf --> 246.394004).  Saving model ...
# Epoch: 3/500..  Training Loss: 0.016143..  Val Loss: 0.753996..  Val Accuracy: 75.68%
# Validation loss decreased (246.394004 --> 235.246641).  Saving model ...
# Epoch: 4/500..  Training Loss: 0.019866..  Val Loss: 0.127534..  Val Accuracy: 94.43%
# Validation loss decreased (235.246641 --> 39.790502).  Saving model ...
# Epoch: 5/500..  Training Loss: 0.024559..  Val Loss: 0.119926..  Val Accuracy: 94.85%
# Validation loss decreased (39.790502 --> 37.416963).  Saving model ...
# Epoch: 6/500..  Training Loss: 0.026129..  Val Loss: 0.072029..  Val Accuracy: 97.08%
# Validation loss decreased (37.416963 --> 22.473111).  Saving model ...
# Epoch: 7/500..  Training Loss: 0.031156..  Val Loss: 0.158807..  Val Accuracy: 93.83%
# Epoch: 8/500..  Training Loss: 0.036380..  Val Loss: 0.076650..  Val Accuracy: 96.81%
# Epoch: 9/500..  Training Loss: 0.038810..  Val Loss: 0.102304..  Val Accuracy: 95.91%
# Epoch: 10/500..  Training Loss: 0.038481..  Val Loss: 0.054150..  Val Accuracy: 97.89%
# Validation loss decreased (22.473111 --> 16.894690).  Saving model ...
# Epoch: 11/500..  Training Loss: 0.039740..  Val Loss: 0.051632..  Val Accuracy: 97.78%
# Validation loss decreased (16.894690 --> 16.109186).  Saving model ...
# Epoch: 12/500..  Training Loss: 0.040671..  Val Loss: 0.053222..  Val Accuracy: 97.71%
# Epoch: 13/500..  Training Loss: 0.041401..  Val Loss: 0.067881..  Val Accuracy: 97.13%
# Epoch: 14/500..  Training Loss: 0.041422..  Val Loss: 0.048352..  Val Accuracy: 97.96%
# Validation loss decreased (16.109186 --> 15.085711).  Saving model ...
# Epoch: 15/500..  Training Loss: 0.041992..  Val Loss: 0.043753..  Val Accuracy: 98.29%
# Validation loss decreased (15.085711 --> 13.650839).  Saving model ...
# Epoch: 17/500..  Training Loss: 0.000166..  Val Loss: 0.050364..  Val Accuracy: 97.97%
# Epoch: 18/500..  Training Loss: 0.003225..  Val Loss: 0.033829..  Val Accuracy: 98.55%
# Validation loss decreased (13.650839 --> 10.554775).  Saving model ...
# Epoch: 19/500..  Training Loss: 0.004798..  Val Loss: 0.050042..  Val Accuracy: 98.08%
# Epoch: 20/500..  Training Loss: 0.007508..  Val Loss: 0.043709..  Val Accuracy: 98.30%
# Epoch: 21/500..  Training Loss: 0.008162..  Val Loss: 0.038524..  Val Accuracy: 98.36%
# Epoch: 22/500..  Training Loss: 0.010981..  Val Loss: 0.051554..  Val Accuracy: 97.88%
# Epoch: 23/500..  Training Loss: 0.012209..  Val Loss: 0.031723..  Val Accuracy: 98.64%
# Validation loss decreased (10.554775 --> 9.897724).  Saving model ...
# Epoch: 24/500..  Training Loss: 0.014373..  Val Loss: 0.029485..  Val Accuracy: 98.82%
# Validation loss decreased (9.897724 --> 9.199197).  Saving model ...
# Epoch: 25/500..  Training Loss: 0.015319..  Val Loss: 0.029336..  Val Accuracy: 98.75%
# Validation loss decreased (9.199197 --> 9.152679).  Saving model ...
# Epoch: 26/500..  Training Loss: 0.017708..  Val Loss: 0.032919..  Val Accuracy: 98.74%
# Epoch: 27/500..  Training Loss: 0.018090..  Val Loss: 0.032400..  Val Accuracy: 98.84%
# Epoch: 28/500..  Training Loss: 0.018361..  Val Loss: 0.034935..  Val Accuracy: 98.59%
# Epoch: 29/500..  Training Loss: 0.021255..  Val Loss: 0.025748..  Val Accuracy: 99.06%
# Validation loss decreased (9.152679 --> 8.033446).  Saving model ...
# Epoch: 30/500..  Training Loss: 0.022381..  Val Loss: 0.024602..  Val Accuracy: 99.08%
# Validation loss decreased (8.033446 --> 7.675691).  Saving model ...
# Epoch: 31/500..  Training Loss: 0.021981..  Val Loss: 0.037611..  Val Accuracy: 98.53%
# Epoch: 33/500..  Training Loss: 0.000164..  Val Loss: 0.028909..  Val Accuracy: 98.83%
# Epoch: 34/500..  Training Loss: 0.002022..  Val Loss: 0.029824..  Val Accuracy: 98.75%
# Epoch: 35/500..  Training Loss: 0.003123..  Val Loss: 0.026520..  Val Accuracy: 98.93%
# Epoch: 36/500..  Training Loss: 0.004400..  Val Loss: 0.039278..  Val Accuracy: 98.53%
# Epoch: 37/500..  Training Loss: 0.004414..  Val Loss: 0.022579..  Val Accuracy: 99.05%
# Validation loss decreased (7.675691 --> 7.044768).  Saving model ...
# Epoch: 38/500..  Training Loss: 0.007616..  Val Loss: 0.022667..  Val Accuracy: 99.03%
# Epoch: 39/500..  Training Loss: 0.007913..  Val Loss: 0.044983..  Val Accuracy: 98.40%
# Epoch: 40/500..  Training Loss: 0.009383..  Val Loss: 0.024481..  Val Accuracy: 99.05%
# Epoch: 41/500..  Training Loss: 0.009684..  Val Loss: 0.038327..  Val Accuracy: 98.49%
# Epoch: 42/500..  Training Loss: 0.010190..  Val Loss: 0.032607..  Val Accuracy: 98.79%
# Epoch: 43/500..  Training Loss: 0.012433..  Val Loss: 0.025165..  Val Accuracy: 99.05%
# Epoch: 44/500..  Training Loss: 0.013735..  Val Loss: 0.030088..  Val Accuracy: 98.89%
# Epoch: 45/500..  Training Loss: 0.014897..  Val Loss: 0.028655..  Val Accuracy: 98.91%
# Epoch: 46/500..  Training Loss: 0.014064..  Val Loss: 0.044755..  Val Accuracy: 98.29%
# Epoch: 47/500..  Training Loss: 0.014985..  Val Loss: 0.029188..  Val Accuracy: 98.98%
# Epoch: 49/500..  Training Loss: 0.000455..  Val Loss: 0.022036..  Val Accuracy: 99.25%
# Validation loss decreased (7.044768 --> 6.875127).  Saving model ...
# Epoch: 50/500..  Training Loss: 0.001202..  Val Loss: 0.027249..  Val Accuracy: 98.90%
# Epoch: 51/500..  Training Loss: 0.002258..  Val Loss: 0.031580..  Val Accuracy: 98.93%
# Epoch: 52/500..  Training Loss: 0.003201..  Val Loss: 0.020917..  Val Accuracy: 99.31%
# Validation loss decreased (6.875127 --> 6.526072).  Saving model ...
# Epoch: 53/500..  Training Loss: 0.004386..  Val Loss: 0.022604..  Val Accuracy: 99.11%
# Epoch: 54/500..  Training Loss: 0.006487..  Val Loss: 0.025380..  Val Accuracy: 99.02%
# Epoch: 55/500..  Training Loss: 0.005976..  Val Loss: 0.028296..  Val Accuracy: 98.85%
# Epoch: 56/500..  Training Loss: 0.006379..  Val Loss: 0.026127..  Val Accuracy: 99.03%
# Epoch: 57/500..  Training Loss: 0.008040..  Val Loss: 0.028925..  Val Accuracy: 98.98%
# Epoch: 58/500..  Training Loss: 0.009314..  Val Loss: 0.022002..  Val Accuracy: 99.21%
# Epoch: 59/500..  Training Loss: 0.008856..  Val Loss: 0.021008..  Val Accuracy: 99.24%
# Epoch: 60/500..  Training Loss: 0.010555..  Val Loss: 0.023095..  Val Accuracy: 99.05%
# Epoch: 61/500..  Training Loss: 0.011401..  Val Loss: 0.021842..  Val Accuracy: 99.25%
# Epoch: 62/500..  Training Loss: 0.012123..  Val Loss: 0.026315..  Val Accuracy: 98.96%
# Epoch: 63/500..  Training Loss: 0.011741..  Val Loss: 0.021039..  Val Accuracy: 99.21%
# Epoch: 65/500..  Training Loss: 0.000369..  Val Loss: 0.021756..  Val Accuracy: 99.21%
# Epoch: 66/500..  Training Loss: 0.001589..  Val Loss: 0.024794..  Val Accuracy: 99.15%
# Epoch: 67/500..  Training Loss: 0.001849..  Val Loss: 0.025716..  Val Accuracy: 99.04%
# Epoch: 68/500..  Training Loss: 0.002814..  Val Loss: 0.037199..  Val Accuracy: 98.76%
# Epoch: 69/500..  Training Loss: 0.003216..  Val Loss: 0.029646..  Val Accuracy: 98.95%
# Epoch: 70/500..  Training Loss: 0.004512..  Val Loss: 0.017948..  Val Accuracy: 99.28%
# Validation loss decreased (6.526072 --> 5.599749).  Saving model ...
# Epoch: 71/500..  Training Loss: 0.005161..  Val Loss: 0.029212..  Val Accuracy: 98.81%
# Epoch: 72/500..  Training Loss: 0.006465..  Val Loss: 0.018471..  Val Accuracy: 99.35%
# Epoch: 73/500..  Training Loss: 0.007580..  Val Loss: 0.031467..  Val Accuracy: 98.90%
# Epoch: 74/500..  Training Loss: 0.006997..  Val Loss: 0.019447..  Val Accuracy: 99.20%
# Epoch: 75/500..  Training Loss: 0.007030..  Val Loss: 0.032412..  Val Accuracy: 98.89%
# Epoch: 76/500..  Training Loss: 0.009792..  Val Loss: 0.018148..  Val Accuracy: 99.31%
# Epoch: 77/500..  Training Loss: 0.010736..  Val Loss: 0.020394..  Val Accuracy: 99.26%
# Epoch: 78/500..  Training Loss: 0.010682..  Val Loss: 0.049574..  Val Accuracy: 98.31%
# Epoch: 79/500..  Training Loss: 0.010556..  Val Loss: 0.021078..  Val Accuracy: 99.25%
# Epoch: 81/500..  Training Loss: 0.000525..  Val Loss: 0.023433..  Val Accuracy: 99.05%
# Epoch: 82/500..  Training Loss: 0.000769..  Val Loss: 0.021199..  Val Accuracy: 99.23%
# Epoch: 83/500..  Training Loss: 0.001488..  Val Loss: 0.021295..  Val Accuracy: 99.27%
# Epoch: 84/500..  Training Loss: 0.001930..  Val Loss: 0.028229..  Val Accuracy: 99.12%
# Epoch: 85/500..  Training Loss: 0.003712..  Val Loss: 0.020278..  Val Accuracy: 99.12%
# Epoch: 86/500..  Training Loss: 0.003371..  Val Loss: 0.020793..  Val Accuracy: 99.23%
# Epoch: 87/500..  Training Loss: 0.003873..  Val Loss: 0.021423..  Val Accuracy: 99.18%
# Epoch: 88/500..  Training Loss: 0.005651..  Val Loss: 0.020137..  Val Accuracy: 99.22%
# Epoch: 89/500..  Training Loss: 0.005851..  Val Loss: 0.024874..  Val Accuracy: 99.07%
# Epoch: 90/500..  Training Loss: 0.007216..  Val Loss: 0.022977..  Val Accuracy: 99.17%
# Epoch: 91/500..  Training Loss: 0.008242..  Val Loss: 0.023540..  Val Accuracy: 99.17%
# Epoch: 92/500..  Training Loss: 0.009650..  Val Loss: 0.021445..  Val Accuracy: 99.20%
# Epoch: 93/500..  Training Loss: 0.008080..  Val Loss: 0.018552..  Val Accuracy: 99.28%
# Epoch: 94/500..  Training Loss: 0.014321..  Val Loss: 0.025477..  Val Accuracy: 98.98%
# Epoch: 95/500..  Training Loss: 0.009853..  Val Loss: 0.025171..  Val Accuracy: 99.15%
# Epoch: 97/500..  Training Loss: 0.000797..  Val Loss: 0.021496..  Val Accuracy: 99.15%
# Epoch: 98/500..  Training Loss: 0.001551..  Val Loss: 0.036057..  Val Accuracy: 98.91%
# Epoch: 99/500..  Training Loss: 0.002430..  Val Loss: 0.037230..  Val Accuracy: 98.80%
# Epoch: 100/500..  Training Loss: 0.002692..  Val Loss: 0.020288..  Val Accuracy: 99.21%
# Epoch: 101/500..  Training Loss: 0.003111..  Val Loss: 0.020361..  Val Accuracy: 99.24%
# Epoch: 102/500..  Training Loss: 0.004055..  Val Loss: 0.033199..  Val Accuracy: 98.97%
# Epoch: 103/500..  Training Loss: 0.003111..  Val Loss: 0.018459..  Val Accuracy: 99.35%
# Epoch: 104/500..  Training Loss: 0.005949..  Val Loss: 0.025974..  Val Accuracy: 99.05%
# Epoch: 105/500..  Training Loss: 0.004704..  Val Loss: 0.023557..  Val Accuracy: 99.15%
# Epoch: 106/500..  Training Loss: 0.007482..  Val Loss: 0.019069..  Val Accuracy: 99.32%
# Epoch: 107/500..  Training Loss: 0.006216..  Val Loss: 0.030816..  Val Accuracy: 98.92%
# Epoch: 108/500..  Training Loss: 0.007992..  Val Loss: 0.044476..  Val Accuracy: 98.61%
# Epoch: 109/500..  Training Loss: 0.008814..  Val Loss: 0.018276..  Val Accuracy: 99.34%
# Epoch: 110/500..  Training Loss: 0.007809..  Val Loss: 0.016720..  Val Accuracy: 99.40%
# Validation loss decreased (5.599749 --> 5.216726).  Saving model ...
# Epoch: 111/500..  Training Loss: 0.007892..  Val Loss: 0.040527..  Val Accuracy: 98.84%
# Epoch: 113/500..  Training Loss: 0.000471..  Val Loss: 0.024351..  Val Accuracy: 99.03%
# Epoch: 114/500..  Training Loss: 0.001852..  Val Loss: 0.025483..  Val Accuracy: 99.02%
# Epoch: 115/500..  Training Loss: 0.001485..  Val Loss: 0.039379..  Val Accuracy: 98.94%
# Epoch: 116/500..  Training Loss: 0.001935..  Val Loss: 0.017990..  Val Accuracy: 99.32%
# Epoch: 117/500..  Training Loss: 0.002716..  Val Loss: 0.041999..  Val Accuracy: 98.63%
# Epoch: 118/500..  Training Loss: 0.002468..  Val Loss: 0.018384..  Val Accuracy: 99.34%
# Epoch: 119/500..  Training Loss: 0.003253..  Val Loss: 0.018482..  Val Accuracy: 99.33%
# Epoch: 120/500..  Training Loss: 0.004275..  Val Loss: 0.029715..  Val Accuracy: 99.16%
# Epoch: 121/500..  Training Loss: 0.005916..  Val Loss: 0.042109..  Val Accuracy: 98.73%
# Epoch: 122/500..  Training Loss: 0.004871..  Val Loss: 0.028231..  Val Accuracy: 99.03%
# Epoch: 123/500..  Training Loss: 0.005443..  Val Loss: 0.052210..  Val Accuracy: 98.28%
# Epoch: 124/500..  Training Loss: 0.008333..  Val Loss: 0.017905..  Val Accuracy: 99.34%
# Epoch: 125/500..  Training Loss: 0.006088..  Val Loss: 0.026045..  Val Accuracy: 99.03%
# Epoch: 126/500..  Training Loss: 0.007299..  Val Loss: 0.025863..  Val Accuracy: 99.05%
# Epoch: 128/500..  Training Loss: 0.000000..  Val Loss: 0.024953..  Val Accuracy: 99.24%
# Epoch: 129/500..  Training Loss: 0.000593..  Val Loss: 0.021200..  Val Accuracy: 99.27%
# Epoch: 130/500..  Training Loss: 0.000921..  Val Loss: 0.018096..  Val Accuracy: 99.40%
# Epoch: 131/500..  Training Loss: 0.001201..  Val Loss: 0.023512..  Val Accuracy: 99.20%
# Epoch: 132/500..  Training Loss: 0.002050..  Val Loss: 0.027487..  Val Accuracy: 99.19%
# Epoch: 133/500..  Training Loss: 0.001933..  Val Loss: 0.021860..  Val Accuracy: 99.23%
# Epoch: 134/500..  Training Loss: 0.003094..  Val Loss: 0.030181..  Val Accuracy: 98.98%
# Epoch: 135/500..  Training Loss: 0.003302..  Val Loss: 0.021337..  Val Accuracy: 99.27%
# Epoch: 136/500..  Training Loss: 0.003907..  Val Loss: 0.019130..  Val Accuracy: 99.29%
# Epoch: 137/500..  Training Loss: 0.003576..  Val Loss: 0.020605..  Val Accuracy: 99.21%
# Epoch: 138/500..  Training Loss: 0.004645..  Val Loss: 0.025039..  Val Accuracy: 99.28%
# Epoch: 139/500..  Training Loss: 0.005505..  Val Loss: 0.028720..  Val Accuracy: 99.14%
# Epoch: 140/500..  Training Loss: 0.005433..  Val Loss: 0.035968..  Val Accuracy: 98.93%
# Epoch: 141/500..  Training Loss: 0.006266..  Val Loss: 0.024344..  Val Accuracy: 99.26%
# Epoch: 142/500..  Training Loss: 0.007632..  Val Loss: 0.020794..  Val Accuracy: 99.28%
# Epoch: 144/500..  Training Loss: 0.000018..  Val Loss: 0.028680..  Val Accuracy: 98.89%
# Epoch: 145/500..  Training Loss: 0.000406..  Val Loss: 0.021203..  Val Accuracy: 99.25%
# Epoch: 146/500..  Training Loss: 0.001565..  Val Loss: 0.020505..  Val Accuracy: 99.15%
# Epoch: 147/500..  Training Loss: 0.000933..  Val Loss: 0.026681..  Val Accuracy: 99.22%
# Epoch: 148/500..  Training Loss: 0.002112..  Val Loss: 0.019924..  Val Accuracy: 99.26%
# Epoch: 149/500..  Training Loss: 0.003137..  Val Loss: 0.028391..  Val Accuracy: 99.11%
# Epoch: 150/500..  Training Loss: 0.003064..  Val Loss: 0.017050..  Val Accuracy: 99.38%
# Epoch: 151/500..  Training Loss: 0.003901..  Val Loss: 0.024649..  Val Accuracy: 99.17%
# Epoch: 152/500..  Training Loss: 0.003353..  Val Loss: 0.023518..  Val Accuracy: 99.28%
# Epoch: 153/500..  Training Loss: 0.003851..  Val Loss: 0.019803..  Val Accuracy: 99.39%
# Epoch: 154/500..  Training Loss: 0.004527..  Val Loss: 0.019521..  Val Accuracy: 99.35%
# Epoch: 155/500..  Training Loss: 0.005138..  Val Loss: 0.021341..  Val Accuracy: 99.31%
# Epoch: 156/500..  Training Loss: 0.005601..  Val Loss: 0.020176..  Val Accuracy: 99.38%
# Epoch: 157/500..  Training Loss: 0.005368..  Val Loss: 0.020836..  Val Accuracy: 99.30%
# Epoch: 158/500..  Training Loss: 0.005042..  Val Loss: 0.017765..  Val Accuracy: 99.33%
# Epoch: 160/500..  Training Loss: 0.000097..  Val Loss: 0.024650..  Val Accuracy: 99.21%
# Epoch: 161/500..  Training Loss: 0.000306..  Val Loss: 0.024397..  Val Accuracy: 99.20%
# Epoch: 162/500..  Training Loss: 0.000543..  Val Loss: 0.020007..  Val Accuracy: 99.40%
# Epoch: 163/500..  Training Loss: 0.000977..  Val Loss: 0.021407..  Val Accuracy: 99.34%
# Epoch: 164/500..  Training Loss: 0.001584..  Val Loss: 0.017882..  Val Accuracy: 99.35%
# Epoch: 165/500..  Training Loss: 0.002134..  Val Loss: 0.023997..  Val Accuracy: 99.28%
# Epoch: 166/500..  Training Loss: 0.002163..  Val Loss: 0.019914..  Val Accuracy: 99.31%
# Epoch: 167/500..  Training Loss: 0.004631..  Val Loss: 0.017020..  Val Accuracy: 99.40%
# Epoch: 168/500..  Training Loss: 0.003961..  Val Loss: 0.019940..  Val Accuracy: 99.31%
# Epoch: 169/500..  Training Loss: 0.003221..  Val Loss: 0.038856..  Val Accuracy: 99.10%
# Epoch: 170/500..  Training Loss: 0.003706..  Val Loss: 0.018129..  Val Accuracy: 99.28%
# Epoch: 171/500..  Training Loss: 0.005068..  Val Loss: 0.019489..  Val Accuracy: 99.30%
# Epoch: 172/500..  Training Loss: 0.004891..  Val Loss: 0.028907..  Val Accuracy: 99.14%
# Epoch: 173/500..  Training Loss: 0.004782..  Val Loss: 0.019781..  Val Accuracy: 99.32%
# Epoch: 174/500..  Training Loss: 0.005831..  Val Loss: 0.024710..  Val Accuracy: 99.17%
# Epoch: 176/500..  Training Loss: 0.000124..  Val Loss: 0.024502..  Val Accuracy: 99.27%
# Epoch: 177/500..  Training Loss: 0.000305..  Val Loss: 0.024577..  Val Accuracy: 99.25%
# Epoch: 178/500..  Training Loss: 0.001629..  Val Loss: 0.021322..  Val Accuracy: 99.30%
# Epoch: 179/500..  Training Loss: 0.001179..  Val Loss: 0.018549..  Val Accuracy: 99.35%
# Epoch: 180/500..  Training Loss: 0.001682..  Val Loss: 0.026124..  Val Accuracy: 99.17%
# Epoch: 181/500..  Training Loss: 0.002701..  Val Loss: 0.021014..  Val Accuracy: 99.32%
# Epoch: 182/500..  Training Loss: 0.002445..  Val Loss: 0.022436..  Val Accuracy: 99.33%
# Epoch: 183/500..  Training Loss: 0.001928..  Val Loss: 0.018923..  Val Accuracy: 99.40%
# Epoch: 184/500..  Training Loss: 0.002802..  Val Loss: 0.023850..  Val Accuracy: 99.31%
# Epoch: 185/500..  Training Loss: 0.003910..  Val Loss: 0.018274..  Val Accuracy: 99.27%
# Epoch: 186/500..  Training Loss: 0.004575..  Val Loss: 0.049172..  Val Accuracy: 98.75%
# Epoch: 187/500..  Training Loss: 0.004638..  Val Loss: 0.032313..  Val Accuracy: 99.14%
# Epoch: 188/500..  Training Loss: 0.003824..  Val Loss: 0.024553..  Val Accuracy: 99.13%
# Epoch: 189/500..  Training Loss: 0.006224..  Val Loss: 0.033074..  Val Accuracy: 99.13%
# Epoch: 190/500..  Training Loss: 0.004654..  Val Loss: 0.019231..  Val Accuracy: 99.29%
# Epoch: 192/500..  Training Loss: 0.000172..  Val Loss: 0.021449..  Val Accuracy: 99.32%
# Epoch: 193/500..  Training Loss: 0.000752..  Val Loss: 0.021630..  Val Accuracy: 99.28%
# Epoch: 194/500..  Training Loss: 0.000570..  Val Loss: 0.021477..  Val Accuracy: 99.46%
# Epoch: 195/500..  Training Loss: 0.001482..  Val Loss: 0.038911..  Val Accuracy: 98.94%
# Epoch: 196/500..  Training Loss: 0.000979..  Val Loss: 0.020517..  Val Accuracy: 99.39%
# Epoch: 197/500..  Training Loss: 0.002040..  Val Loss: 0.020347..  Val Accuracy: 99.40%
# Epoch: 198/500..  Training Loss: 0.002587..  Val Loss: 0.026661..  Val Accuracy: 99.24%
# Epoch: 199/500..  Training Loss: 0.003791..  Val Loss: 0.027202..  Val Accuracy: 99.16%
# Epoch: 200/500..  Training Loss: 0.003279..  Val Loss: 0.019623..  Val Accuracy: 99.32%
# Epoch: 201/500..  Training Loss: 0.003339..  Val Loss: 0.016081..  Val Accuracy: 99.42%
# Validation loss decreased (5.216726 --> 5.017327).  Saving model ...
# Epoch: 202/500..  Training Loss: 0.002944..  Val Loss: 0.020081..  Val Accuracy: 99.35%
# Epoch: 203/500..  Training Loss: 0.003667..  Val Loss: 0.024040..  Val Accuracy: 99.40%
# Epoch: 204/500..  Training Loss: 0.004320..  Val Loss: 0.017931..  Val Accuracy: 99.36%
# Epoch: 205/500..  Training Loss: 0.004060..  Val Loss: 0.021619..  Val Accuracy: 99.30%
# Epoch: 206/500..  Training Loss: 0.005696..  Val Loss: 0.016769..  Val Accuracy: 99.38%
# Epoch: 208/500..  Training Loss: 0.000128..  Val Loss: 0.019738..  Val Accuracy: 99.35%
# Epoch: 209/500..  Training Loss: 0.000621..  Val Loss: 0.019713..  Val Accuracy: 99.35%
# Epoch: 210/500..  Training Loss: 0.001519..  Val Loss: 0.022601..  Val Accuracy: 99.19%
# Epoch: 211/500..  Training Loss: 0.001711..  Val Loss: 0.045554..  Val Accuracy: 98.94%
# Epoch: 212/500..  Training Loss: 0.001368..  Val Loss: 0.022260..  Val Accuracy: 99.24%
# Epoch: 213/500..  Training Loss: 0.001234..  Val Loss: 0.019778..  Val Accuracy: 99.36%
# Epoch: 214/500..  Training Loss: 0.002633..  Val Loss: 0.021939..  Val Accuracy: 99.27%
# Epoch: 215/500..  Training Loss: 0.002031..  Val Loss: 0.020683..  Val Accuracy: 99.35%
# Epoch: 216/500..  Training Loss: 0.002486..  Val Loss: 0.018645..  Val Accuracy: 99.32%
# Epoch: 217/500..  Training Loss: 0.003505..  Val Loss: 0.019090..  Val Accuracy: 99.30%
# Epoch: 218/500..  Training Loss: 0.002922..  Val Loss: 0.018208..  Val Accuracy: 99.36%
# Epoch: 219/500..  Training Loss: 0.004944..  Val Loss: 0.028119..  Val Accuracy: 99.03%
# Epoch: 220/500..  Training Loss: 0.004322..  Val Loss: 0.023532..  Val Accuracy: 99.28%
# Epoch: 221/500..  Training Loss: 0.004007..  Val Loss: 0.018134..  Val Accuracy: 99.36%
# Epoch: 222/500..  Training Loss: 0.003881..  Val Loss: 0.017864..  Val Accuracy: 99.48%
# Epoch: 224/500..  Training Loss: 0.000050..  Val Loss: 0.016357..  Val Accuracy: 99.45%
# Epoch: 225/500..  Training Loss: 0.000825..  Val Loss: 0.031674..  Val Accuracy: 99.03%
# Epoch: 226/500..  Training Loss: 0.000845..  Val Loss: 0.021060..  Val Accuracy: 99.33%
# Epoch: 227/500..  Training Loss: 0.001280..  Val Loss: 0.028738..  Val Accuracy: 99.13%
# Epoch: 228/500..  Training Loss: 0.002344..  Val Loss: 0.018899..  Val Accuracy: 99.27%
# Epoch: 229/500..  Training Loss: 0.001837..  Val Loss: 0.022310..  Val Accuracy: 99.33%
# Epoch: 230/500..  Training Loss: 0.003095..  Val Loss: 0.028072..  Val Accuracy: 99.27%
# Epoch: 231/500..  Training Loss: 0.002718..  Val Loss: 0.020332..  Val Accuracy: 99.38%
# Epoch: 232/500..  Training Loss: 0.003669..  Val Loss: 0.028058..  Val Accuracy: 99.22%
# Epoch: 233/500..  Training Loss: 0.002932..  Val Loss: 0.019472..  Val Accuracy: 99.35%
# Epoch: 234/500..  Training Loss: 0.003425..  Val Loss: 0.017958..  Val Accuracy: 99.47%
# Epoch: 235/500..  Training Loss: 0.004492..  Val Loss: 0.020032..  Val Accuracy: 99.28%
# Epoch: 236/500..  Training Loss: 0.003954..  Val Loss: 0.028875..  Val Accuracy: 99.23%
# Epoch: 237/500..  Training Loss: 0.003670..  Val Loss: 0.016717..  Val Accuracy: 99.35%
# Epoch: 238/500..  Training Loss: 0.005563..  Val Loss: 0.018710..  Val Accuracy: 99.36%
# Epoch: 240/500..  Training Loss: 0.000365..  Val Loss: 0.021431..  Val Accuracy: 99.32%
# Epoch: 241/500..  Training Loss: 0.000623..  Val Loss: 0.029618..  Val Accuracy: 99.33%
# Epoch: 242/500..  Training Loss: 0.000750..  Val Loss: 0.024028..  Val Accuracy: 99.28%
# Epoch: 243/500..  Training Loss: 0.000912..  Val Loss: 0.015887..  Val Accuracy: 99.30%
# Validation loss decreased (5.017327 --> 4.956756).  Saving model ...
# Epoch: 244/500..  Training Loss: 0.001262..  Val Loss: 0.022851..  Val Accuracy: 99.36%
# Epoch: 245/500..  Training Loss: 0.001349..  Val Loss: 0.033288..  Val Accuracy: 99.07%
# Epoch: 246/500..  Training Loss: 0.002151..  Val Loss: 0.025451..  Val Accuracy: 99.19%
# Epoch: 247/500..  Training Loss: 0.001972..  Val Loss: 0.019572..  Val Accuracy: 99.38%
# Epoch: 248/500..  Training Loss: 0.002610..  Val Loss: 0.018824..  Val Accuracy: 99.43%
# Epoch: 249/500..  Training Loss: 0.002773..  Val Loss: 0.017190..  Val Accuracy: 99.42%
# Epoch: 250/500..  Training Loss: 0.003615..  Val Loss: 0.023342..  Val Accuracy: 99.29%
# Epoch: 251/500..  Training Loss: 0.002705..  Val Loss: 0.017380..  Val Accuracy: 99.25%
# Epoch: 252/500..  Training Loss: 0.004739..  Val Loss: 0.022580..  Val Accuracy: 99.25%
# Epoch: 253/500..  Training Loss: 0.003065..  Val Loss: 0.026681..  Val Accuracy: 99.33%
# Epoch: 255/500..  Training Loss: 0.000000..  Val Loss: 0.016851..  Val Accuracy: 99.47%
# Epoch: 256/500..  Training Loss: 0.000369..  Val Loss: 0.018321..  Val Accuracy: 99.41%
# Epoch: 257/500..  Training Loss: 0.000919..  Val Loss: 0.017864..  Val Accuracy: 99.39%
# Epoch: 258/500..  Training Loss: 0.001352..  Val Loss: 0.019678..  Val Accuracy: 99.38%
# Epoch: 259/500..  Training Loss: 0.001620..  Val Loss: 0.035737..  Val Accuracy: 98.84%
# Epoch: 260/500..  Training Loss: 0.001371..  Val Loss: 0.016211..  Val Accuracy: 99.38%
# Epoch: 261/500..  Training Loss: 0.002244..  Val Loss: 0.019169..  Val Accuracy: 99.42%
# Epoch: 262/500..  Training Loss: 0.001559..  Val Loss: 0.019533..  Val Accuracy: 99.42%
# Epoch: 263/500..  Training Loss: 0.002556..  Val Loss: 0.020356..  Val Accuracy: 99.38%
# Epoch: 264/500..  Training Loss: 0.001527..  Val Loss: 0.024471..  Val Accuracy: 99.26%
# Epoch: 265/500..  Training Loss: 0.002262..  Val Loss: 0.023837..  Val Accuracy: 99.29%
# Epoch: 266/500..  Training Loss: 0.003870..  Val Loss: 0.019627..  Val Accuracy: 99.39%
# Epoch: 267/500..  Training Loss: 0.003233..  Val Loss: 0.034572..  Val Accuracy: 98.98%
# Epoch: 268/500..  Training Loss: 0.004056..  Val Loss: 0.016220..  Val Accuracy: 99.47%
# Epoch: 269/500..  Training Loss: 0.003670..  Val Loss: 0.029921..  Val Accuracy: 99.14%
# Epoch: 271/500..  Training Loss: 0.000097..  Val Loss: 0.033339..  Val Accuracy: 99.17%
# Epoch: 272/500..  Training Loss: 0.000376..  Val Loss: 0.027252..  Val Accuracy: 99.24%
# Epoch: 273/500..  Training Loss: 0.000711..  Val Loss: 0.020706..  Val Accuracy: 99.37%
# Epoch: 274/500..  Training Loss: 0.001312..  Val Loss: 0.018142..  Val Accuracy: 99.44%
# Epoch: 275/500..  Training Loss: 0.001873..  Val Loss: 0.021658..  Val Accuracy: 99.28%
# Epoch: 276/500..  Training Loss: 0.000930..  Val Loss: 0.016213..  Val Accuracy: 99.49%
# Epoch: 277/500..  Training Loss: 0.001935..  Val Loss: 0.016622..  Val Accuracy: 99.44%
# Epoch: 278/500..  Training Loss: 0.001655..  Val Loss: 0.017189..  Val Accuracy: 99.44%
# Epoch: 279/500..  Training Loss: 0.001832..  Val Loss: 0.022767..  Val Accuracy: 99.38%
# Epoch: 280/500..  Training Loss: 0.001844..  Val Loss: 0.023886..  Val Accuracy: 99.37%
# Epoch: 281/500..  Training Loss: 0.002616..  Val Loss: 0.027475..  Val Accuracy: 99.21%
# Epoch: 282/500..  Training Loss: 0.002888..  Val Loss: 0.022751..  Val Accuracy: 99.30%
# Epoch: 283/500..  Training Loss: 0.002920..  Val Loss: 0.020891..  Val Accuracy: 99.41%
# Epoch: 284/500..  Training Loss: 0.004446..  Val Loss: 0.024884..  Val Accuracy: 99.28%
# Epoch: 285/500..  Training Loss: 0.005503..  Val Loss: 0.021376..  Val Accuracy: 99.38%
# Epoch: 287/500..  Training Loss: 0.000006..  Val Loss: 0.021214..  Val Accuracy: 99.33%
# Epoch: 288/500..  Training Loss: 0.000613..  Val Loss: 0.027930..  Val Accuracy: 99.17%
# Epoch: 289/500..  Training Loss: 0.000515..  Val Loss: 0.023579..  Val Accuracy: 99.38%
# Epoch: 290/500..  Training Loss: 0.001468..  Val Loss: 0.019320..  Val Accuracy: 99.35%
# Epoch: 291/500..  Training Loss: 0.000801..  Val Loss: 0.017697..  Val Accuracy: 99.43%
# Epoch: 292/500..  Training Loss: 0.001901..  Val Loss: 0.028586..  Val Accuracy: 99.15%
# Epoch: 293/500..  Training Loss: 0.001264..  Val Loss: 0.021302..  Val Accuracy: 99.36%
# Epoch: 294/500..  Training Loss: 0.002464..  Val Loss: 0.022098..  Val Accuracy: 99.39%
# Epoch: 295/500..  Training Loss: 0.002005..  Val Loss: 0.042510..  Val Accuracy: 99.11%
# Epoch: 296/500..  Training Loss: 0.002330..  Val Loss: 0.020202..  Val Accuracy: 99.39%
# Epoch: 297/500..  Training Loss: 0.003000..  Val Loss: 0.032775..  Val Accuracy: 99.21%
# Epoch: 298/500..  Training Loss: 0.003370..  Val Loss: 0.020740..  Val Accuracy: 99.37%
# Epoch: 299/500..  Training Loss: 0.003837..  Val Loss: 0.022921..  Val Accuracy: 99.41%
# Epoch: 300/500..  Training Loss: 0.002337..  Val Loss: 0.032847..  Val Accuracy: 99.19%
# Epoch: 301/500..  Training Loss: 0.004732..  Val Loss: 0.039834..  Val Accuracy: 99.13%
# Epoch: 303/500..  Training Loss: 0.000228..  Val Loss: 0.032375..  Val Accuracy: 99.27%
# Epoch: 304/500..  Training Loss: 0.000775..  Val Loss: 0.023712..  Val Accuracy: 99.30%
# Epoch: 305/500..  Training Loss: 0.000805..  Val Loss: 0.020322..  Val Accuracy: 99.35%
# Epoch: 306/500..  Training Loss: 0.000615..  Val Loss: 0.015527..  Val Accuracy: 99.41%
# Validation loss decreased (4.956756 --> 4.844369).  Saving model ...
# Epoch: 307/500..  Training Loss: 0.002359..  Val Loss: 0.031113..  Val Accuracy: 99.05%
# Epoch: 308/500..  Training Loss: 0.001493..  Val Loss: 0.015401..  Val Accuracy: 99.48%
# Validation loss decreased (4.844369 --> 4.805008).  Saving model ...
# Epoch: 309/500..  Training Loss: 0.001377..  Val Loss: 0.021473..  Val Accuracy: 99.39%
# Epoch: 310/500..  Training Loss: 0.002352..  Val Loss: 0.022222..  Val Accuracy: 99.36%
# Epoch: 311/500..  Training Loss: 0.002554..  Val Loss: 0.026885..  Val Accuracy: 99.36%
# Epoch: 312/500..  Training Loss: 0.002616..  Val Loss: 0.027702..  Val Accuracy: 99.33%
# Epoch: 313/500..  Training Loss: 0.002977..  Val Loss: 0.026847..  Val Accuracy: 99.39%
# Epoch: 314/500..  Training Loss: 0.002160..  Val Loss: 0.021588..  Val Accuracy: 99.39%
# Epoch: 315/500..  Training Loss: 0.003690..  Val Loss: 0.020007..  Val Accuracy: 99.38%
# Epoch: 316/500..  Training Loss: 0.003419..  Val Loss: 0.023176..  Val Accuracy: 99.32%
# Epoch: 317/500..  Training Loss: 0.003994..  Val Loss: 0.021631..  Val Accuracy: 99.35%
# Epoch: 319/500..  Training Loss: 0.000243..  Val Loss: 0.022495..  Val Accuracy: 99.31%
# Epoch: 320/500..  Training Loss: 0.000407..  Val Loss: 0.034634..  Val Accuracy: 98.90%
# Epoch: 321/500..  Training Loss: 0.000508..  Val Loss: 0.018128..  Val Accuracy: 99.40%
# Epoch: 322/500..  Training Loss: 0.001243..  Val Loss: 0.020693..  Val Accuracy: 99.33%
# Epoch: 323/500..  Training Loss: 0.000738..  Val Loss: 0.026031..  Val Accuracy: 99.32%
# Epoch: 324/500..  Training Loss: 0.001640..  Val Loss: 0.021958..  Val Accuracy: 99.38%
# Epoch: 325/500..  Training Loss: 0.002107..  Val Loss: 0.028155..  Val Accuracy: 99.32%
# Epoch: 326/500..  Training Loss: 0.001450..  Val Loss: 0.023642..  Val Accuracy: 99.38%
# Epoch: 327/500..  Training Loss: 0.002612..  Val Loss: 0.016952..  Val Accuracy: 99.48%
# Epoch: 328/500..  Training Loss: 0.002228..  Val Loss: 0.016046..  Val Accuracy: 99.45%
# Epoch: 329/500..  Training Loss: 0.001885..  Val Loss: 0.021376..  Val Accuracy: 99.40%
# Epoch: 330/500..  Training Loss: 0.002560..  Val Loss: 0.022577..  Val Accuracy: 99.36%
# Epoch: 331/500..  Training Loss: 0.002551..  Val Loss: 0.026648..  Val Accuracy: 99.19%
# Epoch: 332/500..  Training Loss: 0.004337..  Val Loss: 0.018331..  Val Accuracy: 99.36%
# Epoch: 333/500..  Training Loss: 0.003101..  Val Loss: 0.021170..  Val Accuracy: 99.34%
# Epoch: 335/500..  Training Loss: 0.000132..  Val Loss: 0.016501..  Val Accuracy: 99.37%
# Epoch: 336/500..  Training Loss: 0.000294..  Val Loss: 0.027378..  Val Accuracy: 99.33%
# Epoch: 337/500..  Training Loss: 0.000732..  Val Loss: 0.017452..  Val Accuracy: 99.42%
# Epoch: 338/500..  Training Loss: 0.000863..  Val Loss: 0.018086..  Val Accuracy: 99.41%
# Epoch: 339/500..  Training Loss: 0.001295..  Val Loss: 0.021449..  Val Accuracy: 99.34%
# Epoch: 340/500..  Training Loss: 0.000997..  Val Loss: 0.023240..  Val Accuracy: 99.39%
# Epoch: 341/500..  Training Loss: 0.001981..  Val Loss: 0.050769..  Val Accuracy: 98.89%
# Epoch: 342/500..  Training Loss: 0.001283..  Val Loss: 0.016058..  Val Accuracy: 99.43%
# Epoch: 343/500..  Training Loss: 0.002573..  Val Loss: 0.017998..  Val Accuracy: 99.48%
# Epoch: 344/500..  Training Loss: 0.002548..  Val Loss: 0.020735..  Val Accuracy: 99.41%
# Epoch: 345/500..  Training Loss: 0.002496..  Val Loss: 0.020930..  Val Accuracy: 99.33%
# Epoch: 346/500..  Training Loss: 0.002943..  Val Loss: 0.023494..  Val Accuracy: 99.35%
# Epoch: 347/500..  Training Loss: 0.002430..  Val Loss: 0.025048..  Val Accuracy: 99.31%
# Epoch: 348/500..  Training Loss: 0.003697..  Val Loss: 0.023509..  Val Accuracy: 99.39%
# Epoch: 349/500..  Training Loss: 0.002978..  Val Loss: 0.021192..  Val Accuracy: 99.36%
# Epoch: 351/500..  Training Loss: 0.000398..  Val Loss: 0.023470..  Val Accuracy: 99.25%
# Epoch: 352/500..  Training Loss: 0.000507..  Val Loss: 0.016824..  Val Accuracy: 99.45%
# Epoch: 353/500..  Training Loss: 0.000315..  Val Loss: 0.017906..  Val Accuracy: 99.51%
# Epoch: 354/500..  Training Loss: 0.000657..  Val Loss: 0.022009..  Val Accuracy: 99.29%
# Epoch: 355/500..  Training Loss: 0.000625..  Val Loss: 0.017711..  Val Accuracy: 99.41%
# Epoch: 356/500..  Training Loss: 0.001314..  Val Loss: 0.019593..  Val Accuracy: 99.46%
# Epoch: 357/500..  Training Loss: 0.001525..  Val Loss: 0.027824..  Val Accuracy: 99.30%
# Epoch: 358/500..  Training Loss: 0.002190..  Val Loss: 0.017119..  Val Accuracy: 99.51%
# Epoch: 359/500..  Training Loss: 0.002249..  Val Loss: 0.025907..  Val Accuracy: 99.28%
# Epoch: 360/500..  Training Loss: 0.001631..  Val Loss: 0.028644..  Val Accuracy: 99.37%
# Epoch: 361/500..  Training Loss: 0.003391..  Val Loss: 0.021831..  Val Accuracy: 99.39%
# Epoch: 362/500..  Training Loss: 0.002459..  Val Loss: 0.021514..  Val Accuracy: 99.35%
# Epoch: 363/500..  Training Loss: 0.003963..  Val Loss: 0.016488..  Val Accuracy: 99.41%
# Epoch: 364/500..  Training Loss: 0.003100..  Val Loss: 0.020070..  Val Accuracy: 99.34%
# Epoch: 365/500..  Training Loss: 0.002208..  Val Loss: 0.018591..  Val Accuracy: 99.43%
# Epoch: 367/500..  Training Loss: 0.000131..  Val Loss: 0.021054..  Val Accuracy: 99.38%
# Epoch: 368/500..  Training Loss: 0.000284..  Val Loss: 0.016821..  Val Accuracy: 99.43%
# Epoch: 369/500..  Training Loss: 0.000566..  Val Loss: 0.020918..  Val Accuracy: 99.42%
# Epoch: 370/500..  Training Loss: 0.000842..  Val Loss: 0.018324..  Val Accuracy: 99.40%
# Epoch: 371/500..  Training Loss: 0.000888..  Val Loss: 0.014430..  Val Accuracy: 99.50%
# Validation loss decreased (4.805008 --> 4.502110).  Saving model ...
# Epoch: 372/500..  Training Loss: 0.001637..  Val Loss: 0.016893..  Val Accuracy: 99.30%
# Epoch: 373/500..  Training Loss: 0.001197..  Val Loss: 0.016485..  Val Accuracy: 99.42%
# Epoch: 374/500..  Training Loss: 0.001113..  Val Loss: 0.020215..  Val Accuracy: 99.43%
# Epoch: 375/500..  Training Loss: 0.003343..  Val Loss: 0.019972..  Val Accuracy: 99.38%
# Epoch: 376/500..  Training Loss: 0.002502..  Val Loss: 0.017888..  Val Accuracy: 99.47%
# Epoch: 377/500..  Training Loss: 0.002184..  Val Loss: 0.023302..  Val Accuracy: 99.27%
# Epoch: 378/500..  Training Loss: 0.004297..  Val Loss: 0.019676..  Val Accuracy: 99.32%
# Epoch: 379/500..  Training Loss: 0.002342..  Val Loss: 0.018792..  Val Accuracy: 99.37%
# Epoch: 380/500..  Training Loss: 0.002928..  Val Loss: 0.019137..  Val Accuracy: 99.42%
# Epoch: 382/500..  Training Loss: 0.000056..  Val Loss: 0.040839..  Val Accuracy: 98.86%
# Epoch: 383/500..  Training Loss: 0.000158..  Val Loss: 0.017465..  Val Accuracy: 99.39%
# Epoch: 384/500..  Training Loss: 0.000179..  Val Loss: 0.015048..  Val Accuracy: 99.44%
# Epoch: 385/500..  Training Loss: 0.000261..  Val Loss: 0.016664..  Val Accuracy: 99.48%
# Epoch: 386/500..  Training Loss: 0.000852..  Val Loss: 0.017588..  Val Accuracy: 99.40%
# Epoch: 387/500..  Training Loss: 0.001150..  Val Loss: 0.017465..  Val Accuracy: 99.41%
# Epoch: 388/500..  Training Loss: 0.001641..  Val Loss: 0.019915..  Val Accuracy: 99.41%
# Epoch: 389/500..  Training Loss: 0.000844..  Val Loss: 0.019252..  Val Accuracy: 99.41%
# Epoch: 390/500..  Training Loss: 0.003451..  Val Loss: 0.017659..  Val Accuracy: 99.41%
# Epoch: 391/500..  Training Loss: 0.002691..  Val Loss: 0.020789..  Val Accuracy: 99.40%
# Epoch: 392/500..  Training Loss: 0.002343..  Val Loss: 0.016446..  Val Accuracy: 99.40%
# Epoch: 393/500..  Training Loss: 0.002331..  Val Loss: 0.020913..  Val Accuracy: 99.39%
# Epoch: 394/500..  Training Loss: 0.001730..  Val Loss: 0.021362..  Val Accuracy: 99.37%
# Epoch: 395/500..  Training Loss: 0.002726..  Val Loss: 0.024536..  Val Accuracy: 99.22%
# Epoch: 396/500..  Training Loss: 0.003835..  Val Loss: 0.026815..  Val Accuracy: 99.14%
# Epoch: 398/500..  Training Loss: 0.000004..  Val Loss: 0.025237..  Val Accuracy: 99.27%
# Epoch: 399/500..  Training Loss: 0.000280..  Val Loss: 0.020934..  Val Accuracy: 99.41%
# Epoch: 400/500..  Training Loss: 0.000195..  Val Loss: 0.022623..  Val Accuracy: 99.39%
# Epoch: 401/500..  Training Loss: 0.000337..  Val Loss: 0.021400..  Val Accuracy: 99.39%
# Epoch: 402/500..  Training Loss: 0.001275..  Val Loss: 0.022727..  Val Accuracy: 99.34%
# Epoch: 403/500..  Training Loss: 0.000866..  Val Loss: 0.018910..  Val Accuracy: 99.46%
# Epoch: 404/500..  Training Loss: 0.001167..  Val Loss: 0.021805..  Val Accuracy: 99.38%
# Epoch: 405/500..  Training Loss: 0.001122..  Val Loss: 0.019281..  Val Accuracy: 99.40%
# Epoch: 406/500..  Training Loss: 0.001229..  Val Loss: 0.018268..  Val Accuracy: 99.47%
# Epoch: 407/500..  Training Loss: 0.002164..  Val Loss: 0.021800..  Val Accuracy: 99.33%
# Epoch: 408/500..  Training Loss: 0.001714..  Val Loss: 0.030790..  Val Accuracy: 99.16%
# Epoch: 409/500..  Training Loss: 0.001853..  Val Loss: 0.020858..  Val Accuracy: 99.38%
# Epoch: 410/500..  Training Loss: 0.003606..  Val Loss: 0.017924..  Val Accuracy: 99.41%
# Epoch: 411/500..  Training Loss: 0.002057..  Val Loss: 0.019256..  Val Accuracy: 99.53%
# Epoch: 412/500..  Training Loss: 0.002772..  Val Loss: 0.022261..  Val Accuracy: 99.34%
# Epoch: 414/500..  Training Loss: 0.000009..  Val Loss: 0.020980..  Val Accuracy: 99.34%
# Epoch: 415/500..  Training Loss: 0.000367..  Val Loss: 0.017987..  Val Accuracy: 99.38%
# Epoch: 416/500..  Training Loss: 0.000861..  Val Loss: 0.014590..  Val Accuracy: 99.44%
# Epoch: 417/500..  Training Loss: 0.000672..  Val Loss: 0.018392..  Val Accuracy: 99.47%
# Epoch: 418/500..  Training Loss: 0.000910..  Val Loss: 0.018208..  Val Accuracy: 99.35%
# Epoch: 419/500..  Training Loss: 0.000915..  Val Loss: 0.021638..  Val Accuracy: 99.38%
# Epoch: 420/500..  Training Loss: 0.001562..  Val Loss: 0.016803..  Val Accuracy: 99.44%
# Epoch: 421/500..  Training Loss: 0.001285..  Val Loss: 0.031205..  Val Accuracy: 99.35%
# Epoch: 422/500..  Training Loss: 0.001145..  Val Loss: 0.020971..  Val Accuracy: 99.40%
# Epoch: 423/500..  Training Loss: 0.001356..  Val Loss: 0.019226..  Val Accuracy: 99.41%
# Epoch: 424/500..  Training Loss: 0.002741..  Val Loss: 0.014560..  Val Accuracy: 99.50%
# Epoch: 425/500..  Training Loss: 0.002260..  Val Loss: 0.019954..  Val Accuracy: 99.45%
# Epoch: 426/500..  Training Loss: 0.003327..  Val Loss: 0.021627..  Val Accuracy: 99.33%
# Epoch: 427/500..  Training Loss: 0.003996..  Val Loss: 0.015979..  Val Accuracy: 99.42%
# Epoch: 428/500..  Training Loss: 0.003374..  Val Loss: 0.027431..  Val Accuracy: 99.10%
# Epoch: 430/500..  Training Loss: 0.000012..  Val Loss: 0.017773..  Val Accuracy: 99.43%
# Epoch: 431/500..  Training Loss: 0.000319..  Val Loss: 0.024962..  Val Accuracy: 99.36%
# Epoch: 432/500..  Training Loss: 0.001062..  Val Loss: 0.020141..  Val Accuracy: 99.41%
# Epoch: 433/500..  Training Loss: 0.000691..  Val Loss: 0.016273..  Val Accuracy: 99.41%
# Epoch: 434/500..  Training Loss: 0.000693..  Val Loss: 0.014988..  Val Accuracy: 99.51%
# Epoch: 435/500..  Training Loss: 0.001301..  Val Loss: 0.020147..  Val Accuracy: 99.41%
# Epoch: 436/500..  Training Loss: 0.000945..  Val Loss: 0.018362..  Val Accuracy: 99.43%
# Epoch: 437/500..  Training Loss: 0.001398..  Val Loss: 0.021829..  Val Accuracy: 99.34%
# Epoch: 438/500..  Training Loss: 0.001377..  Val Loss: 0.019038..  Val Accuracy: 99.42%
# Epoch: 439/500..  Training Loss: 0.002279..  Val Loss: 0.027637..  Val Accuracy: 99.32%
# Epoch: 440/500..  Training Loss: 0.002831..  Val Loss: 0.022282..  Val Accuracy: 99.27%
# Epoch: 441/500..  Training Loss: 0.001724..  Val Loss: 0.020652..  Val Accuracy: 99.42%
# Epoch: 442/500..  Training Loss: 0.002870..  Val Loss: 0.020078..  Val Accuracy: 99.41%
# Epoch: 443/500..  Training Loss: 0.002193..  Val Loss: 0.032210..  Val Accuracy: 99.26%
# Epoch: 444/500..  Training Loss: 0.002594..  Val Loss: 0.020879..  Val Accuracy: 99.43%
# Epoch: 446/500..  Training Loss: 0.000211..  Val Loss: 0.015642..  Val Accuracy: 99.53%
# Epoch: 447/500..  Training Loss: 0.000347..  Val Loss: 0.022029..  Val Accuracy: 99.26%
# Epoch: 448/500..  Training Loss: 0.000774..  Val Loss: 0.030212..  Val Accuracy: 99.20%
# Epoch: 449/500..  Training Loss: 0.001268..  Val Loss: 0.023661..  Val Accuracy: 99.40%
# Epoch: 450/500..  Training Loss: 0.001431..  Val Loss: 0.018924..  Val Accuracy: 99.37%
# Epoch: 451/500..  Training Loss: 0.001292..  Val Loss: 0.020161..  Val Accuracy: 99.43%
# Epoch: 452/500..  Training Loss: 0.001657..  Val Loss: 0.018635..  Val Accuracy: 99.42%
# Epoch: 453/500..  Training Loss: 0.002102..  Val Loss: 0.021622..  Val Accuracy: 99.45%
# Epoch: 454/500..  Training Loss: 0.001123..  Val Loss: 0.023425..  Val Accuracy: 99.36%
# Epoch: 455/500..  Training Loss: 0.002357..  Val Loss: 0.017890..  Val Accuracy: 99.39%
# Epoch: 456/500..  Training Loss: 0.001559..  Val Loss: 0.016698..  Val Accuracy: 99.51%
# Epoch: 457/500..  Training Loss: 0.003233..  Val Loss: 0.018018..  Val Accuracy: 99.41%
# Epoch: 458/500..  Training Loss: 0.003372..  Val Loss: 0.020081..  Val Accuracy: 99.41%
# Epoch: 459/500..  Training Loss: 0.001797..  Val Loss: 0.022860..  Val Accuracy: 99.40%
# Epoch: 460/500..  Training Loss: 0.003359..  Val Loss: 0.021263..  Val Accuracy: 99.29%
# Epoch: 462/500..  Training Loss: 0.000104..  Val Loss: 0.018413..  Val Accuracy: 99.40%
# Epoch: 463/500..  Training Loss: 0.000381..  Val Loss: 0.021972..  Val Accuracy: 99.46%
# Epoch: 464/500..  Training Loss: 0.000730..  Val Loss: 0.020038..  Val Accuracy: 99.31%
# Epoch: 465/500..  Training Loss: 0.000657..  Val Loss: 0.027199..  Val Accuracy: 99.29%
# Epoch: 466/500..  Training Loss: 0.000338..  Val Loss: 0.026999..  Val Accuracy: 99.33%
# Epoch: 467/500..  Training Loss: 0.001193..  Val Loss: 0.048105..  Val Accuracy: 99.00%
# Epoch: 468/500..  Training Loss: 0.000673..  Val Loss: 0.023989..  Val Accuracy: 99.34%
# Epoch: 469/500..  Training Loss: 0.002028..  Val Loss: 0.020615..  Val Accuracy: 99.36%
# Epoch: 470/500..  Training Loss: 0.002236..  Val Loss: 0.019817..  Val Accuracy: 99.33%
# Epoch: 471/500..  Training Loss: 0.001955..  Val Loss: 0.019730..  Val Accuracy: 99.38%
# Epoch: 472/500..  Training Loss: 0.001790..  Val Loss: 0.027059..  Val Accuracy: 99.36%
# Epoch: 473/500..  Training Loss: 0.002194..  Val Loss: 0.024154..  Val Accuracy: 99.23%
# Epoch: 474/500..  Training Loss: 0.002350..  Val Loss: 0.028348..  Val Accuracy: 99.23%
# Epoch: 475/500..  Training Loss: 0.002495..  Val Loss: 0.028238..  Val Accuracy: 99.25%
# Epoch: 476/500..  Training Loss: 0.002605..  Val Loss: 0.021206..  Val Accuracy: 99.49%
# Epoch: 478/500..  Training Loss: 0.000089..  Val Loss: 0.021398..  Val Accuracy: 99.42%
# Epoch: 479/500..  Training Loss: 0.000904..  Val Loss: 0.020891..  Val Accuracy: 99.37%
# Epoch: 480/500..  Training Loss: 0.000490..  Val Loss: 0.023728..  Val Accuracy: 99.35%
# Epoch: 481/500..  Training Loss: 0.000475..  Val Loss: 0.020876..  Val Accuracy: 99.45%
# Epoch: 482/500..  Training Loss: 0.000755..  Val Loss: 0.017650..  Val Accuracy: 99.50%
# Epoch: 483/500..  Training Loss: 0.001849..  Val Loss: 0.017758..  Val Accuracy: 99.39%
# Epoch: 484/500..  Training Loss: 0.001075..  Val Loss: 0.018715..  Val Accuracy: 99.45%
# Epoch: 485/500..  Training Loss: 0.001715..  Val Loss: 0.026558..  Val Accuracy: 99.35%
# Epoch: 486/500..  Training Loss: 0.002162..  Val Loss: 0.018051..  Val Accuracy: 99.41%
# Epoch: 487/500..  Training Loss: 0.001468..  Val Loss: 0.020910..  Val Accuracy: 99.33%
# Epoch: 488/500..  Training Loss: 0.002069..  Val Loss: 0.019330..  Val Accuracy: 99.42%
# Epoch: 489/500..  Training Loss: 0.003760..  Val Loss: 0.026781..  Val Accuracy: 99.28%
# Epoch: 490/500..  Training Loss: 0.003051..  Val Loss: 0.023568..  Val Accuracy: 99.36%
# Epoch: 491/500..  Training Loss: 0.002489..  Val Loss: 0.022807..  Val Accuracy: 99.31%
# Epoch: 492/500..  Training Loss: 0.002621..  Val Loss: 0.022529..  Val Accuracy: 99.35%
# Epoch: 494/500..  Training Loss: 0.000262..  Val Loss: 0.022028..  Val Accuracy: 99.33%
# Epoch: 495/500..  Training Loss: 0.000161..  Val Loss: 0.027814..  Val Accuracy: 99.36%
# Epoch: 496/500..  Training Loss: 0.000700..  Val Loss: 0.022427..  Val Accuracy: 99.20%
# Epoch: 497/500..  Training Loss: 0.000540..  Val Loss: 0.020517..  Val Accuracy: 99.40%
# Epoch: 498/500..  Training Loss: 0.000561..  Val Loss: 0.019905..  Val Accuracy: 99.45%
# Epoch: 499/500..  Training Loss: 0.001536..  Val Loss: 0.035452..  Val Accuracy: 99.12%
# Epoch: 500/500..  Training Loss: 0.000831..  Val Loss: 0.027077..  Val Accuracy: 99.37%

# %% [markdown]
# ### 테스트

# %%
from sklearn.metrics import confusion_matrix

# %%
def test(classifier1,classifier2,classifier3,classifier4,classifier5, dataloader):
    # setup the network
    predlist=[]
    real=[]    

    classifier.eval()
    correct = 0.0
    
    max_tr_score = 0
    max_val_score = 0
    for batch_idx, (data) in enumerate(dataloader):
    
        signal1,label = data
        signal1,label = Variable(signal1.cuda()),Variable(label.cuda().long())
        
        
        out1,_ = classifier1(signal1)
        out2,_ = classifier2(signal1) 
        out3,_ = classifier3(signal1)
        out4,_ = classifier4(signal1)
        out5,_ = classifier5(signal1)

        
        out=(out1+out2+out3+out4+out5)/5
        
        pred = out.data.max(1, keepdim= True)[1]
        predlist.append(pred.cpu().detach().numpy().squeeze())
        real.append(label)        
        correct += pred.eq(label.data.view_as(pred)).cpu().sum()

        # predlist.append(pred)
    print('\nAccuracy: {}/{} ({:.4f}%)\n'.format(
        correct, len(dataloader.dataset), 100. * float(correct) / len(dataloader.dataset)))
    acc=100. * float(correct) / len(dataloader.dataset)
    return acc,predlist,real

# %% [markdown]
# #### 1번

# %%
train_loader,valid_loader,test_loader=loaders(cross_val_train_set_1,cross_val_train_label_1,cross_val_test_set_1,cross_val_test_label_1,1004)

# %%
acc,predlist,realist=test(ensemble1_best,ensemble2_best,ensemble3_best,ensemble4_best,ensemble5_best,test_loader)

# %%
confusionmatrix(predlist, realist)

# %% [markdown]
# ### Extra

# %%
def fail_index(pred, real, cross_val_num):
    failed=[]
    with open('test_fold_index.pickle', 'rb') as f:
        test_fold_index = pickle.load(f)
    
    for i in range(len(pred)):
        if pred[i].item()!=real[i].detach().cpu().item():
            failed.append(test_fold_index[cross_val_num-1][i])
    
    return failed

# %%
failed_index=fail_index(predlist,realist,1)

# %%
failed_index
# Out:
# [65,
#  186,
#  412,
#  440,
#  508,
#  516,
#  573,
#  579,
#  583,
#  655,
#  656,
#  795,
#  908,
#  951,
#  994,
#  1003,
#  1054,
#  1060,
#  1168,
#  1241,
#  1261,
#  1269,
#  1314,
#  1550,
#  1608,
#  1774,
#  1874,
#  1883,
#  1891,
#  2021,
#  2128,
#  2183,
#  2305,
#  2376,
#  2429,
#  2463,
#  2472,
#  2555,
#  2638,
#  2736,
#  2870,
#  2927,
#  2938,
#  3151,
#  3395,
#  3559,
#  3565,
#  3754,
#  3846,
#  3902,
#  3992,
#  4148,
#  4249,
#  4263,
#  4485,
#  4498,
#  4536,
#  4599,
#  4625,
#  4731,
#  5028,
#  5080,
#  5099,
#  5185,
#  5265,
#  5333,
#  5369,
#  5534,
#  5596,
#  5641,
#  5680,
#  6041,
#  6171,
#  6174,
#  6343,
#  6480,
#  6526,
#  6621,
#  6722,
#  6759,
#  6760,
#  7044,
#  7083,
#  7256,
#  7303,
#  7372,
#  7435,
#  7447,
#  7509,
#  7587,
#  7816,
#  7901,
#  8016,
#  8034,
#  8229,
#  8282,
#  8506,
#  8531,
#  8574,
#  8666,
#  8669,
#  8673,
#  8680,
#  8710,
#  8745,
#  8768,
#  8803,
#  8806,
#  8938,
#  9126,
#  9163,
#  9265,
#  9384,
#  9387,
#  9414,
#  9424,
#  9482,
#  9525,
#  9778,
#  9920,
#  10064,
#  10092,
#  10144,
#  10189,
#  10211,
#  10471,
#  10500,
#  10519,
#  10535,
#  10633,
#  10808,
#  10866,
#  10869,
#  10879,
#  10882,
#  11017,
#  11143,
#  11204,
#  11256,
#  11286,
#  11361,
#  11365,
#  11376,
#  11454,
#  11498,
#  11537,
#  11679,
#  11797,
#  11934,
#  12040,
#  12131,
#  12350,
#  12395,
#  12444,
#  12456,
#  12752,
#  12843,
#  12929,
#  12946,
#  13030,
#  13230,
#  13244,
#  13265,
#  13346,
#  13462,
#  13609,
#  13833,
#  13838,
#  13904,
#  14187,
#  14198,
#  14512,
#  14542,
#  14701,
#  14764,
#  14772,
#  14773,
#  14893,
#  14902,
#  14951,
#  15118,
#  15171,
#  15259,
#  15305,
#  15338,
#  15348,
#  15824,
#  16123,
#  16135,
#  16186,
#  16255,
#  16339,
#  16390,
#  16417,
#  16423,
#  16437,
#  16606,
#  16712,
#  16783,
#  16810,
#  16835,
#  16836,
#  17043,
#  17262,
#  17269,
#  17352,
#  17403,
#  17438,
#  17449,
#  17471,
#  17484,
#  17615,
#  17641,
#  17797,
#  17887,
#  17901,
#  17949,
#  18053,
#  18105,
#  18223,
#  18229,
#  18343,
#  18420,
#  18484,
#  18488,
#  18621,
#  18703,
#  18740,
#  18860,
#  18861,
#  19022,
#  19117,
#  19249,
#  19320,
#  19382,
#  19410,
#  19467,
#  19489,
#  19610,
#  19727,
#  19742,
#  19788,
#  19895,
#  19910,
#  20093,
#  20106]
