# %% [markdown]
# ## 앙상블 코드

# %% [markdown]
# - cv값이랑 cond값 지정해주세요 cv 5, cond 2 , 내부 앙상블 5개 => 총 50개 모델 필요

# %%
cv=4
cond=2

# %%
import os
import glob
import numpy as np
import pandas as pd
from pathlib import Path
from numpy import inf
from numpy import array
from numpy import argmax
import pickle
import argparse, sys, os
import time
from collections import Counter

from torch.utils.data import DataLoader,Dataset
import torchvision.transforms as transforms
from torchvision import models
import torch.nn as nn
import torch
from torch.autograd import Variable
from torchsummary import summary
import torchvision.transforms.functional as Fv
from torch.optim import lr_scheduler
import torchvision
import torch.optim as optim
import torch.nn.functional as F
import torch.nn.init as init
from torchvision import datasets, transforms


from sklearn.manifold import TSNE
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn import metrics
from tqdm import tqdm
import matplotlib.pyplot as plt
import random
from torchsummary import summary
from torch.optim import lr_scheduler
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init

print(torch.__version__)
print(torch.cuda.is_available())
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.nn.parameter import Parameter
from torch import topk
from tqdm.notebook import tqdm # 프로세스 바
from matplotlib import pyplot as plt
import matplotlib
# matplotlib.use('agg')
# device = torch.device("cuda:%d" % 0 if torch.cuda.is_available() else "cpu")
import numpy as np
# from dataloader_hilbert_att import DataLoader
import os
from torch.autograd import Variable


# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# 1.12.1
# True

# %%
path= "\\\\147.47.239.143\\SHRM-robotgear\\ICPHM2023\\pickle\\"

# %%
# # read data

with open(path+'cross_val_train_set_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_train_set = pickle.load(f)
with open(path+'cross_val_train_label_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_train_label = pickle.load(f)
with open(path+'cross_val_test_set_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_test_set = pickle.load(f)
with open(path+'cross_val_test_label_'+str(cv)+'_'+str(cond)+'.pickle', 'rb') as f:
    cross_val_test_label = pickle.load(f)

# %%
#depthwise version
class customdataset(Dataset):
    def __init__(self, data, label): 
        super().__init__()
        self.data=torch.tensor(data)
        self.label=torch.tensor(label)
        
    def __len__(self):
        return len(self.label)
  
    def __getitem__(self, idx):
        x = self.data[idx]
        label = self.label[idx] 
                
        return  x.to(device).float(), label.to(device).long()

def loaders(tr_data,tr_label,ts_data,ts_label,random_state):
    train_set, valid_set, train_label, valid_label = train_test_split(tr_data, tr_label,random_state=random_state, train_size=0.75)
    
    traindataset = customdataset(train_set, train_label)
    validdataset = customdataset(valid_set, valid_label)
    testdataset = customdataset(ts_data, ts_label)
    
    traindataloader = DataLoader(traindataset, batch_size=32, shuffle=True, drop_last=True )
    validdataloader = DataLoader(validdataset, batch_size=32, shuffle=True, drop_last=True )
    testdataloader = DataLoader(testdataset, batch_size=1, shuffle=False, drop_last=False )
    
    return traindataloader,validdataloader,testdataloader

# %% [markdown]
# ### Models

# %%
savepath= './'

# %% [markdown]
# #### 기본 Loss

# %%
class SELayer(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1)
        return x * y.expand_as(x)

# %%
class Dilated_Module(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Dilated_Module,self).__init__()
        self.conv1=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5)//2), dilation=1, bias=False)        
        self.conv2=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*2)//2), dilation=3, bias=False)        
        self.conv3=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*4)//2), dilation=5, bias=False)
        self.conv4=nn.Conv1d(in_channels, int(out_channels/4), kernel_size = 5, stride = 1, padding = ((5+4*6)//2), dilation=7, bias=False)
        
    def forward(self,x):
        ''' input x should be in size [B,F,T], where 
            B = Batch size
            F = features
            T = Time samples
        '''
        x1=self.conv1(x)
        x2=self.conv2(x)
        x3=self.conv3(x)
        x4=self.conv4(x)
        
        y=torch.cat([x1,x2,x3,x4],dim=1)
        
        return y

# %%
class MLSTMfcn_MSN(nn.Module):
    def __init__(self, *, num_classes, num_features,
                 num_lstm_out, num_lstm_layers=1, 
                 conv1_nf=128, conv2_nf=256, conv3_nf=128,
                 lstm_drop_p=0.8, fc_drop_p=0.3):
        super(MLSTMfcn_MSN, self).__init__()

        self.num_classes = num_classes
        self.num_features = num_features

        self.num_lstm_out = num_lstm_out
        self.num_lstm_layers = num_lstm_layers

        
        self.conv1_nf = conv1_nf
        self.conv2_nf = conv2_nf
        self.conv3_nf = conv3_nf

        self.dilated_1=Dilated_Module(self.num_features, self.conv1_nf)
        self.dilated_2=Dilated_Module(self.conv1_nf, self.conv2_nf)
        self.dilated_3=Dilated_Module(self.conv2_nf, self.conv3_nf)

        self.lstm_drop_p = lstm_drop_p
        self.fc_drop_p = fc_drop_p

        self.lstm = nn.LSTM(input_size=self.num_features, 
                            hidden_size=self.num_lstm_out,
                            num_layers=self.num_lstm_layers,
                            batch_first=True)
        
        self.bn1 = nn.BatchNorm1d(self.conv1_nf)
        self.bn2 = nn.BatchNorm1d(self.conv2_nf)
        self.bn3 = nn.BatchNorm1d(self.conv3_nf)

        self.se1 = SELayer(self.conv1_nf)  # ex 128
        self.se2 = SELayer(self.conv2_nf)  # ex 256

        self.relu = nn.ReLU()
        self.lstmDrop = nn.Dropout(self.lstm_drop_p)
        self.convDrop = nn.Dropout(self.fc_drop_p)

        self.fc = nn.Linear(self.conv3_nf+self.num_lstm_out, self.num_classes)
    
    def forward(self, x):
        ''' input x should be in size [B,T,F], where 
            B = Batch size
            T = Time samples
            F = features
        '''
        x=x.transpose(2,1)
        ''' input x should be in size [B,T,F], where 
            B = Batch size
            T = Time samples
            F = features
        '''       
        # x1 = nn.utils.rnn.pack_padded_sequence(x, seq_lens, 
        #                                        batch_first=True, 
        #                                        enforce_sorted=False)
        x1, (ht,ct) = self.lstm(x)
        x1 = self.lstmDrop(x1)
        # x1, _ = nn.utils.rnn.pad_packed_sequence(x1, batch_first=True, 
        #                                          padding_value=0.0)
        # print(x1.size())
        x1 = x1[:,-1,:]
        
        x2 = x.transpose(2,1)
        x2 = self.convDrop(self.relu(self.bn1(self.dilated_1(x2))))
        # print(x2.size())
        x2 = self.se1(x2)
        x2 = self.convDrop(self.relu(self.bn2(self.dilated_2(x2))))
        # print(x2.size())
        x2 = self.se2(x2)
        x2 = self.convDrop(self.relu(self.bn3(self.dilated_3(x2))))
        # print(x2.size())
        x2 = torch.mean(x2,2)
        
        x_all = torch.cat((x1,x2),dim=1)
        x_out = self.fc(x_all)
        x_out = F.log_softmax(x_out, dim=1)

        return x_out,x_all

# %% [markdown]
# ### 공통실행

# %%
def validation(model, testloader, criterion):
    accuracy = 0
    test_loss = 0
    for inputs, labels in testloader:
        inputs = inputs.float()
        inputs, labels = inputs.to(device), labels.to(device)

        output,_ = model.forward(inputs)
        test_loss += criterion(output, labels).item()

        ## Calculating the accuracy 
        # Model's output is log-softmax, take exponential to get the probabilities
        ps = torch.exp(output)
        # Class with highest probability is our predicted class, compare with true label
        equality = (labels.data == ps.max(1)[1])
        # Accuracy is number of correct predictions divided by all predictions, just take the mean
        accuracy += equality.type_as(torch.FloatTensor()).mean()

    return test_loss,accuracy

# %%
def fail_index(pred, real, cross_val_num):
    failed=[]
    with open('test_fold_index_2.pickle', 'rb') as f:
        test_fold_index = pickle.load(f)
    
    for i in range(len(pred)):
        if pred[i].item()!=real[i].detach().cpu().item():
            failed.append(test_fold_index[cross_val_num-1][i])
    
    return failed

import seaborn as sn
def confusionmatrix(y_pred1, y_test1, column=['class0','class1','class2','class3','class4']):
    # y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    # _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)
    a=[]
    b=[]
    for i in range(len(y_test1)):
        a.append(y_test1[i].detach().cpu().item())
        b.append(y_pred1[i].item())
    y_test=a
    y_pred=b
    df_cm = pd.DataFrame(confusion_matrix(y_test,y_pred))
    df_cm.index=column
    df_cm.columns=column
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    b, t = plt.ylim() 
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t)
    

    df_cm =df_cm / df_cm.astype(np.float).sum(axis=1)
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    b, t = plt.ylim() 
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t)

    
def test(classifier, dataloader):
    # setup the network
    predlist=[]
    real=[]    

    classifier.eval()
    correct = 0.0
    
    max_tr_score = 0
    max_val_score = 0
    for batch_idx, (data) in enumerate(dataloader):
    
        signal1,label = data
        signal1,label = Variable(signal1.cuda()),Variable(label.cuda().long())
        out,_ = classifier(signal1)   

        pred = out.data.max(1, keepdim= True)[1]
        predlist.append(pred.cpu().detach().numpy().squeeze())
        real.append(label)        
        correct += pred.eq(label.data.view_as(pred)).cpu().sum()

        # predlist.append(pred)
    print('\nAccuracy: {}/{} ({:.4f}%)\n'.format(
        correct, len(dataloader.dataset), 100. * float(correct) / len(dataloader.dataset)))
    acc=100. * float(correct) / len(dataloader.dataset)
    return acc,predlist,real

# %%
from sklearn.model_selection import ParameterGrid
# 하이퍼파라미터 그리드 설정
param_grid = {
    'lr': [0.001, 0.0005, 0.0001],
    'batch_size': [32, 64, 128],
    'hidden_size': [8, 64, 128],
    'optimizer': ['Adam', 'RMSprop', 'SGD']
}

# %%
lr = param_grid['lr'][0]
batch_size = param_grid['batch_size'][0]
num_lstm_out = param_grid['hidden_size'][0]
optimizer_name = param_grid['optimizer'][0]

# %% [markdown]
# ### 학습

# %% [markdown]
# - 랜덤시드
#   - 4444(사랑하는사람이사랑하는사람에게)
#   - 2514(이세상에서오직하나뿐인사람)
#   - 4040(사랑사랑)
#   - 8282(빨리빨리)
#   - 1004(천사)

# %%
randomseedlist=[4444,2514,4040,8282,1004]

# %%
def final(modelname,train_set, train_label, test_set, test_label,esbnum):
    train_loader,valid_loader,test_loader=loaders(train_set, train_label,test_set,test_label,randomseedlist[esbnum])


    valid_loss_min = np.Inf # track change in validation loss
    criterion = nn.NLLLoss().to(device)
    epochs=500
    print_every=1000

    # 0.001 32 8 Adam
    lr = param_grid['lr'][0]
    batch_size = param_grid['batch_size'][0]
    num_lstm_out = param_grid['hidden_size'][0]
    optimizer_name = param_grid['optimizer'][0]

    model =modelname.to(device)


    # 옵티마이저 설정
    if optimizer_name == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_name == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=lr)
    elif optimizer_name == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=lr)



    #train
    steps = 0

    for e in tqdm(range(epochs)):
        train_loss = 0.0
        valid_loss = 0.0

        model.train()
        for inputs, labels in train_loader:
            steps += 1

            inputs = inputs.float()
            inputs, labels = inputs.to(device),labels.to(device)

            optimizer.zero_grad()
            # print(inputs.shape)
            # print(model.forward(inputs).shape)
            output,_ = model.forward(inputs)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            if steps % print_every == 0:
                model.eval()

                with torch.no_grad():
                    valid_loss, accuracy = validation(model, valid_loader, criterion)

                print("Epoch: {}/{}.. ".format(e+1, epochs),
                      "Training Loss: {:.6f}.. ".format(train_loss/print_every),
                      "Val Loss: {:.6f}.. ".format(valid_loss/len(valid_loader)),
                      "Val Accuracy: {:.2f}%".format(accuracy/len(valid_loader)*100))

                # save model if validation loss has decreased
                if valid_loss <= valid_loss_min:
                    print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
                    valid_loss_min,
                    valid_loss))
                    torch.save(model.state_dict(), savepath+ 'malstm_msn_cv_'+str(cv)+'_cond_'+str(cond)+'_esb_'+str(esbnum)+'.pt')
                    valid_loss_min = valid_loss

                train_loss = 0

                model.train()
    return model

# %% [markdown]
# ### ensemble1

# %%
ensemble1 = MLSTMfcn_MSN(num_classes=5, 
                           num_features=3,
                           num_lstm_out=num_lstm_out).to(device)

# %%
ensemble1_best=final(ensemble1,cross_val_train_set,cross_val_train_label,cross_val_test_set,cross_val_test_label,4)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch: 2/500..  Training Loss: 0.010678..  Val Loss: 0.395612..  Val Accuracy: 84.15%
# Validation loss decreased (inf --> 123.431037).  Saving model ...
# Epoch: 3/500..  Training Loss: 0.014600..  Val Loss: 0.383091..  Val Accuracy: 85.40%
# Validation loss decreased (123.431037 --> 119.524308).  Saving model ...
# Epoch: 4/500..  Training Loss: 0.019412..  Val Loss: 0.130793..  Val Accuracy: 94.39%
# Validation loss decreased (119.524308 --> 40.807497).  Saving model ...
# Epoch: 5/500..  Training Loss: 0.025982..  Val Loss: 0.224339..  Val Accuracy: 91.55%
# Epoch: 6/500..  Training Loss: 0.030428..  Val Loss: 0.122812..  Val Accuracy: 94.52%
# Validation loss decreased (40.807497 --> 38.317300).  Saving model ...
# Epoch: 7/500..  Training Loss: 0.032275..  Val Loss: 0.080955..  Val Accuracy: 97.08%
# Validation loss decreased (38.317300 --> 25.257956).  Saving model ...
# Epoch: 8/500..  Training Loss: 0.032974..  Val Loss: 0.173589..  Val Accuracy: 93.52%
# Epoch: 9/500..  Training Loss: 0.036623..  Val Loss: 0.118267..  Val Accuracy: 95.50%
# Epoch: 10/500..  Training Loss: 0.035742..  Val Loss: 0.170465..  Val Accuracy: 94.00%
# Epoch: 11/500..  Training Loss: 0.037194..  Val Loss: 0.050447..  Val Accuracy: 97.99%
# Validation loss decreased (25.257956 --> 15.739591).  Saving model ...
# Epoch: 12/500..  Training Loss: 0.038248..  Val Loss: 0.051607..  Val Accuracy: 97.93%
# Epoch: 13/500..  Training Loss: 0.039445..  Val Loss: 0.042028..  Val Accuracy: 98.19%
# Validation loss decreased (15.739591 --> 13.112774).  Saving model ...
# Epoch: 14/500..  Training Loss: 0.038176..  Val Loss: 0.048581..  Val Accuracy: 97.99%
# Epoch: 15/500..  Training Loss: 0.039284..  Val Loss: 0.035925..  Val Accuracy: 98.47%
# Validation loss decreased (13.112774 --> 11.208465).  Saving model ...
# Epoch: 17/500..  Training Loss: 0.000351..  Val Loss: 0.032770..  Val Accuracy: 98.58%
# Validation loss decreased (11.208465 --> 10.224173).  Saving model ...
# Epoch: 18/500..  Training Loss: 0.002463..  Val Loss: 0.034470..  Val Accuracy: 98.62%
# Epoch: 19/500..  Training Loss: 0.005108..  Val Loss: 0.082920..  Val Accuracy: 96.90%
# Epoch: 20/500..  Training Loss: 0.006186..  Val Loss: 0.036447..  Val Accuracy: 98.52%
# Epoch: 21/500..  Training Loss: 0.008706..  Val Loss: 0.047726..  Val Accuracy: 98.11%
# Epoch: 22/500..  Training Loss: 0.010373..  Val Loss: 0.036080..  Val Accuracy: 98.39%
# Epoch: 23/500..  Training Loss: 0.011111..  Val Loss: 0.040779..  Val Accuracy: 98.50%
# Epoch: 24/500..  Training Loss: 0.014229..  Val Loss: 0.034524..  Val Accuracy: 98.57%
# Epoch: 25/500..  Training Loss: 0.014618..  Val Loss: 0.133536..  Val Accuracy: 94.97%
# Epoch: 26/500..  Training Loss: 0.015007..  Val Loss: 0.030597..  Val Accuracy: 98.73%
# Validation loss decreased (10.224173 --> 9.546133).  Saving model ...
# Epoch: 27/500..  Training Loss: 0.016115..  Val Loss: 0.039026..  Val Accuracy: 98.46%
# Epoch: 28/500..  Training Loss: 0.018311..  Val Loss: 0.039272..  Val Accuracy: 98.45%
# Epoch: 29/500..  Training Loss: 0.017762..  Val Loss: 0.026882..  Val Accuracy: 98.89%
# Validation loss decreased (9.546133 --> 8.387163).  Saving model ...
# Epoch: 30/500..  Training Loss: 0.020738..  Val Loss: 0.033363..  Val Accuracy: 98.82%
# Epoch: 31/500..  Training Loss: 0.019704..  Val Loss: 0.076721..  Val Accuracy: 97.13%
# Epoch: 33/500..  Training Loss: 0.000395..  Val Loss: 0.021655..  Val Accuracy: 99.17%
# Validation loss decreased (8.387163 --> 6.756264).  Saving model ...
# Epoch: 34/500..  Training Loss: 0.001620..  Val Loss: 0.037635..  Val Accuracy: 98.58%
# Epoch: 35/500..  Training Loss: 0.002916..  Val Loss: 0.018714..  Val Accuracy: 99.37%
# Validation loss decreased (6.756264 --> 5.838755).  Saving model ...
# Epoch: 36/500..  Training Loss: 0.003730..  Val Loss: 0.023204..  Val Accuracy: 99.09%
# Epoch: 37/500..  Training Loss: 0.006179..  Val Loss: 0.021031..  Val Accuracy: 99.32%
# Epoch: 38/500..  Training Loss: 0.006564..  Val Loss: 0.023321..  Val Accuracy: 99.04%
# Epoch: 39/500..  Training Loss: 0.007263..  Val Loss: 0.028243..  Val Accuracy: 99.07%
# Epoch: 40/500..  Training Loss: 0.008626..  Val Loss: 0.021367..  Val Accuracy: 99.28%
# Epoch: 41/500..  Training Loss: 0.009794..  Val Loss: 0.021536..  Val Accuracy: 99.25%
# Epoch: 42/500..  Training Loss: 0.011271..  Val Loss: 0.022025..  Val Accuracy: 99.21%
# Epoch: 43/500..  Training Loss: 0.011162..  Val Loss: 0.018181..  Val Accuracy: 99.26%
# Validation loss decreased (5.838755 --> 5.672438).  Saving model ...
# Epoch: 44/500..  Training Loss: 0.012248..  Val Loss: 0.020047..  Val Accuracy: 99.24%
# Epoch: 45/500..  Training Loss: 0.014011..  Val Loss: 0.024762..  Val Accuracy: 99.07%
# Epoch: 46/500..  Training Loss: 0.014419..  Val Loss: 0.020337..  Val Accuracy: 99.29%
# Epoch: 47/500..  Training Loss: 0.015586..  Val Loss: 0.017352..  Val Accuracy: 99.31%
# Validation loss decreased (5.672438 --> 5.413799).  Saving model ...
# Epoch: 49/500..  Training Loss: 0.000565..  Val Loss: 0.019434..  Val Accuracy: 99.28%
# Epoch: 50/500..  Training Loss: 0.001642..  Val Loss: 0.026202..  Val Accuracy: 99.17%
# Epoch: 51/500..  Training Loss: 0.002048..  Val Loss: 0.020440..  Val Accuracy: 99.16%
# Epoch: 52/500..  Training Loss: 0.004301..  Val Loss: 0.027194..  Val Accuracy: 99.01%
# Epoch: 53/500..  Training Loss: 0.003658..  Val Loss: 0.019201..  Val Accuracy: 99.30%
# Epoch: 54/500..  Training Loss: 0.006400..  Val Loss: 0.030998..  Val Accuracy: 98.96%
# Epoch: 55/500..  Training Loss: 0.006201..  Val Loss: 0.020718..  Val Accuracy: 99.21%
# Epoch: 56/500..  Training Loss: 0.007775..  Val Loss: 0.016835..  Val Accuracy: 99.44%
# Validation loss decreased (5.413799 --> 5.252660).  Saving model ...
# Epoch: 57/500..  Training Loss: 0.007898..  Val Loss: 0.018789..  Val Accuracy: 99.28%
# Epoch: 58/500..  Training Loss: 0.007861..  Val Loss: 0.018165..  Val Accuracy: 99.39%
# Epoch: 59/500..  Training Loss: 0.009448..  Val Loss: 0.021402..  Val Accuracy: 99.32%
# Epoch: 60/500..  Training Loss: 0.008777..  Val Loss: 0.017598..  Val Accuracy: 99.36%
# Epoch: 61/500..  Training Loss: 0.012022..  Val Loss: 0.024589..  Val Accuracy: 99.08%
# Epoch: 62/500..  Training Loss: 0.012204..  Val Loss: 0.018915..  Val Accuracy: 99.30%
# Epoch: 63/500..  Training Loss: 0.013776..  Val Loss: 0.023421..  Val Accuracy: 99.31%
# Epoch: 65/500..  Training Loss: 0.000423..  Val Loss: 0.031155..  Val Accuracy: 98.97%
# Epoch: 66/500..  Training Loss: 0.001095..  Val Loss: 0.016584..  Val Accuracy: 99.42%
# Validation loss decreased (5.252660 --> 5.174075).  Saving model ...
# Epoch: 67/500..  Training Loss: 0.001769..  Val Loss: 0.018223..  Val Accuracy: 99.26%
# Epoch: 68/500..  Training Loss: 0.002627..  Val Loss: 0.023338..  Val Accuracy: 99.18%
# Epoch: 69/500..  Training Loss: 0.004326..  Val Loss: 0.022147..  Val Accuracy: 99.20%
# Epoch: 70/500..  Training Loss: 0.004456..  Val Loss: 0.021571..  Val Accuracy: 99.33%
# Epoch: 71/500..  Training Loss: 0.004020..  Val Loss: 0.017137..  Val Accuracy: 99.39%
# Epoch: 72/500..  Training Loss: 0.005981..  Val Loss: 0.025203..  Val Accuracy: 99.01%
# Epoch: 73/500..  Training Loss: 0.006648..  Val Loss: 0.014527..  Val Accuracy: 99.51%
# Validation loss decreased (5.174075 --> 4.532272).  Saving model ...
# Epoch: 74/500..  Training Loss: 0.008271..  Val Loss: 0.018341..  Val Accuracy: 99.36%
# Epoch: 75/500..  Training Loss: 0.007491..  Val Loss: 0.026143..  Val Accuracy: 99.10%
# Epoch: 76/500..  Training Loss: 0.008848..  Val Loss: 0.024064..  Val Accuracy: 99.08%
# Epoch: 77/500..  Training Loss: 0.008868..  Val Loss: 0.015433..  Val Accuracy: 99.48%
# Epoch: 78/500..  Training Loss: 0.010263..  Val Loss: 0.021180..  Val Accuracy: 99.41%
# Epoch: 79/500..  Training Loss: 0.010754..  Val Loss: 0.016656..  Val Accuracy: 99.34%
# Epoch: 81/500..  Training Loss: 0.000449..  Val Loss: 0.015767..  Val Accuracy: 99.44%
# Epoch: 82/500..  Training Loss: 0.001177..  Val Loss: 0.022433..  Val Accuracy: 99.23%
# Epoch: 83/500..  Training Loss: 0.001966..  Val Loss: 0.014703..  Val Accuracy: 99.54%
# Epoch: 84/500..  Training Loss: 0.002447..  Val Loss: 0.016511..  Val Accuracy: 99.39%
# Epoch: 85/500..  Training Loss: 0.002620..  Val Loss: 0.017967..  Val Accuracy: 99.39%
# Epoch: 86/500..  Training Loss: 0.004053..  Val Loss: 0.024825..  Val Accuracy: 99.09%
# Epoch: 87/500..  Training Loss: 0.004582..  Val Loss: 0.017844..  Val Accuracy: 99.38%
# Epoch: 88/500..  Training Loss: 0.005354..  Val Loss: 0.016376..  Val Accuracy: 99.41%
# Epoch: 89/500..  Training Loss: 0.006540..  Val Loss: 0.016131..  Val Accuracy: 99.35%
# Epoch: 90/500..  Training Loss: 0.006848..  Val Loss: 0.018711..  Val Accuracy: 99.37%
# Epoch: 91/500..  Training Loss: 0.008081..  Val Loss: 0.016347..  Val Accuracy: 99.40%
# Epoch: 92/500..  Training Loss: 0.008670..  Val Loss: 0.014901..  Val Accuracy: 99.44%
# Epoch: 93/500..  Training Loss: 0.008402..  Val Loss: 0.016572..  Val Accuracy: 99.47%
# Epoch: 94/500..  Training Loss: 0.008513..  Val Loss: 0.018390..  Val Accuracy: 99.33%
# Epoch: 95/500..  Training Loss: 0.010152..  Val Loss: 0.017401..  Val Accuracy: 99.37%
# Epoch: 97/500..  Training Loss: 0.000622..  Val Loss: 0.030617..  Val Accuracy: 99.01%
# Epoch: 98/500..  Training Loss: 0.001650..  Val Loss: 0.017881..  Val Accuracy: 99.43%
# Epoch: 99/500..  Training Loss: 0.001385..  Val Loss: 0.017251..  Val Accuracy: 99.51%
# Epoch: 100/500..  Training Loss: 0.002457..  Val Loss: 0.016332..  Val Accuracy: 99.43%
# Epoch: 101/500..  Training Loss: 0.003353..  Val Loss: 0.015242..  Val Accuracy: 99.44%
# Epoch: 102/500..  Training Loss: 0.003547..  Val Loss: 0.016103..  Val Accuracy: 99.40%
# Epoch: 103/500..  Training Loss: 0.004320..  Val Loss: 0.016496..  Val Accuracy: 99.34%
# Epoch: 104/500..  Training Loss: 0.006179..  Val Loss: 0.023158..  Val Accuracy: 99.28%
# Epoch: 105/500..  Training Loss: 0.004935..  Val Loss: 0.015977..  Val Accuracy: 99.54%
# Epoch: 106/500..  Training Loss: 0.004700..  Val Loss: 0.018714..  Val Accuracy: 99.50%
# Epoch: 107/500..  Training Loss: 0.005749..  Val Loss: 0.019789..  Val Accuracy: 99.36%
# Epoch: 108/500..  Training Loss: 0.006541..  Val Loss: 0.016275..  Val Accuracy: 99.44%
# Epoch: 109/500..  Training Loss: 0.007378..  Val Loss: 0.014462..  Val Accuracy: 99.48%
# Validation loss decreased (4.532272 --> 4.512103).  Saving model ...
# Epoch: 110/500..  Training Loss: 0.008005..  Val Loss: 0.016929..  Val Accuracy: 99.47%
# Epoch: 111/500..  Training Loss: 0.007450..  Val Loss: 0.019742..  Val Accuracy: 99.38%
# Epoch: 113/500..  Training Loss: 0.000178..  Val Loss: 0.017056..  Val Accuracy: 99.34%
# Epoch: 114/500..  Training Loss: 0.001429..  Val Loss: 0.018340..  Val Accuracy: 99.42%
# Epoch: 115/500..  Training Loss: 0.000948..  Val Loss: 0.016330..  Val Accuracy: 99.44%
# Epoch: 116/500..  Training Loss: 0.001783..  Val Loss: 0.014483..  Val Accuracy: 99.57%
# Epoch: 117/500..  Training Loss: 0.002326..  Val Loss: 0.014182..  Val Accuracy: 99.53%
# Validation loss decreased (4.512103 --> 4.424808).  Saving model ...
# Epoch: 118/500..  Training Loss: 0.002949..  Val Loss: 0.018661..  Val Accuracy: 99.41%
# Epoch: 119/500..  Training Loss: 0.004507..  Val Loss: 0.018929..  Val Accuracy: 99.37%
# Epoch: 120/500..  Training Loss: 0.004537..  Val Loss: 0.015636..  Val Accuracy: 99.50%
# Epoch: 121/500..  Training Loss: 0.004928..  Val Loss: 0.014267..  Val Accuracy: 99.54%
# Epoch: 122/500..  Training Loss: 0.006223..  Val Loss: 0.016173..  Val Accuracy: 99.45%
# Epoch: 123/500..  Training Loss: 0.005113..  Val Loss: 0.017327..  Val Accuracy: 99.54%
# Epoch: 124/500..  Training Loss: 0.005363..  Val Loss: 0.014074..  Val Accuracy: 99.44%
# Validation loss decreased (4.424808 --> 4.391185).  Saving model ...
# Epoch: 125/500..  Training Loss: 0.006810..  Val Loss: 0.015256..  Val Accuracy: 99.47%
# Epoch: 126/500..  Training Loss: 0.006584..  Val Loss: 0.015095..  Val Accuracy: 99.57%
# Epoch: 128/500..  Training Loss: 0.000000..  Val Loss: 0.025117..  Val Accuracy: 99.33%
# Epoch: 129/500..  Training Loss: 0.000511..  Val Loss: 0.026781..  Val Accuracy: 99.11%
# Epoch: 130/500..  Training Loss: 0.000966..  Val Loss: 0.018577..  Val Accuracy: 99.41%
# Epoch: 131/500..  Training Loss: 0.001401..  Val Loss: 0.014351..  Val Accuracy: 99.50%
# Epoch: 132/500..  Training Loss: 0.002614..  Val Loss: 0.014301..  Val Accuracy: 99.53%
# Epoch: 133/500..  Training Loss: 0.002379..  Val Loss: 0.017693..  Val Accuracy: 99.44%
# Epoch: 134/500..  Training Loss: 0.003012..  Val Loss: 0.013191..  Val Accuracy: 99.57%
# Validation loss decreased (4.391185 --> 4.115626).  Saving model ...
# Epoch: 135/500..  Training Loss: 0.002692..  Val Loss: 0.015808..  Val Accuracy: 99.47%
# Epoch: 136/500..  Training Loss: 0.004097..  Val Loss: 0.018457..  Val Accuracy: 99.50%
# Epoch: 137/500..  Training Loss: 0.004000..  Val Loss: 0.020867..  Val Accuracy: 99.31%
# Epoch: 138/500..  Training Loss: 0.003695..  Val Loss: 0.014938..  Val Accuracy: 99.56%
# Epoch: 139/500..  Training Loss: 0.004941..  Val Loss: 0.015821..  Val Accuracy: 99.48%
# Epoch: 140/500..  Training Loss: 0.004808..  Val Loss: 0.017337..  Val Accuracy: 99.49%
# Epoch: 141/500..  Training Loss: 0.007122..  Val Loss: 0.011872..  Val Accuracy: 99.59%
# Validation loss decreased (4.115626 --> 3.704018).  Saving model ...
# Epoch: 142/500..  Training Loss: 0.007296..  Val Loss: 0.018004..  Val Accuracy: 99.52%
# Epoch: 144/500..  Training Loss: 0.000014..  Val Loss: 0.017754..  Val Accuracy: 99.39%
# Epoch: 145/500..  Training Loss: 0.000255..  Val Loss: 0.019716..  Val Accuracy: 99.41%
# Epoch: 146/500..  Training Loss: 0.000789..  Val Loss: 0.014469..  Val Accuracy: 99.57%
# Epoch: 147/500..  Training Loss: 0.001650..  Val Loss: 0.032426..  Val Accuracy: 99.02%
# Epoch: 148/500..  Training Loss: 0.001692..  Val Loss: 0.013588..  Val Accuracy: 99.54%
# Epoch: 149/500..  Training Loss: 0.001653..  Val Loss: 0.027007..  Val Accuracy: 99.30%
# Epoch: 150/500..  Training Loss: 0.003505..  Val Loss: 0.016012..  Val Accuracy: 99.53%
# Epoch: 151/500..  Training Loss: 0.003604..  Val Loss: 0.021352..  Val Accuracy: 99.38%
# Epoch: 152/500..  Training Loss: 0.003482..  Val Loss: 0.015096..  Val Accuracy: 99.46%
# Epoch: 153/500..  Training Loss: 0.003246..  Val Loss: 0.014457..  Val Accuracy: 99.53%
# Epoch: 154/500..  Training Loss: 0.005685..  Val Loss: 0.018039..  Val Accuracy: 99.50%
# Epoch: 155/500..  Training Loss: 0.004619..  Val Loss: 0.017027..  Val Accuracy: 99.52%
# Epoch: 156/500..  Training Loss: 0.005282..  Val Loss: 0.020846..  Val Accuracy: 99.41%
# Epoch: 157/500..  Training Loss: 0.006226..  Val Loss: 0.016942..  Val Accuracy: 99.46%
# Epoch: 158/500..  Training Loss: 0.004761..  Val Loss: 0.038079..  Val Accuracy: 98.77%
# Epoch: 160/500..  Training Loss: 0.000072..  Val Loss: 0.015583..  Val Accuracy: 99.47%
# Epoch: 161/500..  Training Loss: 0.000501..  Val Loss: 0.016513..  Val Accuracy: 99.45%
# Epoch: 162/500..  Training Loss: 0.000732..  Val Loss: 0.023700..  Val Accuracy: 99.30%
# Epoch: 163/500..  Training Loss: 0.001549..  Val Loss: 0.017436..  Val Accuracy: 99.53%
# Epoch: 164/500..  Training Loss: 0.001957..  Val Loss: 0.013896..  Val Accuracy: 99.49%
# Epoch: 165/500..  Training Loss: 0.001861..  Val Loss: 0.019260..  Val Accuracy: 99.50%
# Epoch: 166/500..  Training Loss: 0.002273..  Val Loss: 0.025982..  Val Accuracy: 99.13%
# Epoch: 167/500..  Training Loss: 0.002359..  Val Loss: 0.014336..  Val Accuracy: 99.60%
# Epoch: 168/500..  Training Loss: 0.003235..  Val Loss: 0.026976..  Val Accuracy: 99.21%
# Epoch: 169/500..  Training Loss: 0.002854..  Val Loss: 0.015991..  Val Accuracy: 99.55%
# Epoch: 170/500..  Training Loss: 0.004702..  Val Loss: 0.015754..  Val Accuracy: 99.49%
# Epoch: 171/500..  Training Loss: 0.004492..  Val Loss: 0.012546..  Val Accuracy: 99.56%
# Epoch: 172/500..  Training Loss: 0.004073..  Val Loss: 0.014871..  Val Accuracy: 99.61%
# Epoch: 173/500..  Training Loss: 0.003936..  Val Loss: 0.015727..  Val Accuracy: 99.55%
# Epoch: 174/500..  Training Loss: 0.005013..  Val Loss: 0.027024..  Val Accuracy: 99.10%
# Epoch: 176/500..  Training Loss: 0.000113..  Val Loss: 0.015818..  Val Accuracy: 99.55%
# Epoch: 177/500..  Training Loss: 0.000344..  Val Loss: 0.023479..  Val Accuracy: 99.32%
# Epoch: 178/500..  Training Loss: 0.000792..  Val Loss: 0.013196..  Val Accuracy: 99.64%
# Epoch: 179/500..  Training Loss: 0.001086..  Val Loss: 0.014910..  Val Accuracy: 99.58%
# Epoch: 180/500..  Training Loss: 0.001695..  Val Loss: 0.012398..  Val Accuracy: 99.61%
# Epoch: 181/500..  Training Loss: 0.002577..  Val Loss: 0.011043..  Val Accuracy: 99.60%
# Validation loss decreased (3.704018 --> 3.445265).  Saving model ...
# Epoch: 182/500..  Training Loss: 0.002157..  Val Loss: 0.013467..  Val Accuracy: 99.54%
# Epoch: 183/500..  Training Loss: 0.002542..  Val Loss: 0.013507..  Val Accuracy: 99.56%
# Epoch: 184/500..  Training Loss: 0.003211..  Val Loss: 0.019670..  Val Accuracy: 99.40%
# Epoch: 185/500..  Training Loss: 0.004133..  Val Loss: 0.013484..  Val Accuracy: 99.64%
# Epoch: 186/500..  Training Loss: 0.003866..  Val Loss: 0.012745..  Val Accuracy: 99.64%
# Epoch: 187/500..  Training Loss: 0.004549..  Val Loss: 0.020941..  Val Accuracy: 99.18%
# Epoch: 188/500..  Training Loss: 0.004221..  Val Loss: 0.026949..  Val Accuracy: 99.08%
# Epoch: 189/500..  Training Loss: 0.004460..  Val Loss: 0.014763..  Val Accuracy: 99.55%
# Epoch: 190/500..  Training Loss: 0.005735..  Val Loss: 0.015187..  Val Accuracy: 99.47%
# Epoch: 192/500..  Training Loss: 0.000042..  Val Loss: 0.013761..  Val Accuracy: 99.61%
# Epoch: 193/500..  Training Loss: 0.000700..  Val Loss: 0.015435..  Val Accuracy: 99.49%
# Epoch: 194/500..  Training Loss: 0.000743..  Val Loss: 0.012790..  Val Accuracy: 99.60%
# Epoch: 195/500..  Training Loss: 0.001376..  Val Loss: 0.027924..  Val Accuracy: 99.28%
# Epoch: 196/500..  Training Loss: 0.001836..  Val Loss: 0.013542..  Val Accuracy: 99.54%
# Epoch: 197/500..  Training Loss: 0.001636..  Val Loss: 0.017196..  Val Accuracy: 99.52%
# Epoch: 198/500..  Training Loss: 0.002309..  Val Loss: 0.013461..  Val Accuracy: 99.52%
# Epoch: 199/500..  Training Loss: 0.003866..  Val Loss: 0.017592..  Val Accuracy: 99.45%
# Epoch: 200/500..  Training Loss: 0.002933..  Val Loss: 0.014578..  Val Accuracy: 99.54%
# Epoch: 201/500..  Training Loss: 0.003028..  Val Loss: 0.016785..  Val Accuracy: 99.59%
# Epoch: 202/500..  Training Loss: 0.005690..  Val Loss: 0.011980..  Val Accuracy: 99.57%
# Epoch: 203/500..  Training Loss: 0.003121..  Val Loss: 0.016094..  Val Accuracy: 99.50%
# Epoch: 204/500..  Training Loss: 0.004830..  Val Loss: 0.013033..  Val Accuracy: 99.61%
# Epoch: 205/500..  Training Loss: 0.003869..  Val Loss: 0.018634..  Val Accuracy: 99.45%
# Epoch: 206/500..  Training Loss: 0.004942..  Val Loss: 0.018605..  Val Accuracy: 99.48%
# Epoch: 208/500..  Training Loss: 0.000119..  Val Loss: 0.014218..  Val Accuracy: 99.55%
# Epoch: 209/500..  Training Loss: 0.000796..  Val Loss: 0.021889..  Val Accuracy: 99.32%
# Epoch: 210/500..  Training Loss: 0.001157..  Val Loss: 0.017603..  Val Accuracy: 99.45%
# Epoch: 211/500..  Training Loss: 0.001204..  Val Loss: 0.016226..  Val Accuracy: 99.49%
# Epoch: 212/500..  Training Loss: 0.001102..  Val Loss: 0.021623..  Val Accuracy: 99.41%
# Epoch: 213/500..  Training Loss: 0.001867..  Val Loss: 0.015797..  Val Accuracy: 99.51%
# Epoch: 214/500..  Training Loss: 0.002344..  Val Loss: 0.009191..  Val Accuracy: 99.75%
# Validation loss decreased (3.445265 --> 2.867670).  Saving model ...
# Epoch: 215/500..  Training Loss: 0.001910..  Val Loss: 0.014820..  Val Accuracy: 99.58%
# Epoch: 216/500..  Training Loss: 0.002977..  Val Loss: 0.013191..  Val Accuracy: 99.59%
# Epoch: 217/500..  Training Loss: 0.001909..  Val Loss: 0.011169..  Val Accuracy: 99.56%
# Epoch: 218/500..  Training Loss: 0.003426..  Val Loss: 0.012627..  Val Accuracy: 99.59%
# Epoch: 219/500..  Training Loss: 0.004087..  Val Loss: 0.016678..  Val Accuracy: 99.52%
# Epoch: 220/500..  Training Loss: 0.003836..  Val Loss: 0.012686..  Val Accuracy: 99.63%
# Epoch: 221/500..  Training Loss: 0.004170..  Val Loss: 0.017682..  Val Accuracy: 99.41%
# Epoch: 222/500..  Training Loss: 0.004840..  Val Loss: 0.017238..  Val Accuracy: 99.43%
# Epoch: 224/500..  Training Loss: 0.000235..  Val Loss: 0.012535..  Val Accuracy: 99.58%
# Epoch: 225/500..  Training Loss: 0.000815..  Val Loss: 0.032984..  Val Accuracy: 99.26%
# Epoch: 226/500..  Training Loss: 0.001038..  Val Loss: 0.017661..  Val Accuracy: 99.52%
# Epoch: 227/500..  Training Loss: 0.001195..  Val Loss: 0.015343..  Val Accuracy: 99.47%
# Epoch: 228/500..  Training Loss: 0.001516..  Val Loss: 0.018903..  Val Accuracy: 99.57%
# Epoch: 229/500..  Training Loss: 0.001198..  Val Loss: 0.018050..  Val Accuracy: 99.52%
# Epoch: 230/500..  Training Loss: 0.001933..  Val Loss: 0.026811..  Val Accuracy: 99.35%
# Epoch: 231/500..  Training Loss: 0.002047..  Val Loss: 0.011992..  Val Accuracy: 99.68%
# Epoch: 232/500..  Training Loss: 0.001766..  Val Loss: 0.014023..  Val Accuracy: 99.64%
# Epoch: 233/500..  Training Loss: 0.004918..  Val Loss: 0.012195..  Val Accuracy: 99.59%
# Epoch: 234/500..  Training Loss: 0.003391..  Val Loss: 0.019429..  Val Accuracy: 99.44%
# Epoch: 235/500..  Training Loss: 0.002760..  Val Loss: 0.017426..  Val Accuracy: 99.49%
# Epoch: 236/500..  Training Loss: 0.002774..  Val Loss: 0.015695..  Val Accuracy: 99.58%
# Epoch: 237/500..  Training Loss: 0.004036..  Val Loss: 0.018206..  Val Accuracy: 99.56%
# Epoch: 238/500..  Training Loss: 0.006530..  Val Loss: 0.019037..  Val Accuracy: 99.44%
# Epoch: 240/500..  Training Loss: 0.000159..  Val Loss: 0.012154..  Val Accuracy: 99.66%
# Epoch: 241/500..  Training Loss: 0.000467..  Val Loss: 0.013506..  Val Accuracy: 99.60%
# Epoch: 242/500..  Training Loss: 0.000774..  Val Loss: 0.013003..  Val Accuracy: 99.60%
# Epoch: 243/500..  Training Loss: 0.001685..  Val Loss: 0.015066..  Val Accuracy: 99.47%
# Epoch: 244/500..  Training Loss: 0.000868..  Val Loss: 0.014958..  Val Accuracy: 99.54%
# Epoch: 245/500..  Training Loss: 0.002019..  Val Loss: 0.017883..  Val Accuracy: 99.47%
# Epoch: 246/500..  Training Loss: 0.002060..  Val Loss: 0.021499..  Val Accuracy: 99.47%
# Epoch: 247/500..  Training Loss: 0.002656..  Val Loss: 0.020516..  Val Accuracy: 99.37%
# Epoch: 248/500..  Training Loss: 0.001520..  Val Loss: 0.013313..  Val Accuracy: 99.65%
# Epoch: 249/500..  Training Loss: 0.003788..  Val Loss: 0.019660..  Val Accuracy: 99.47%
# Epoch: 250/500..  Training Loss: 0.003634..  Val Loss: 0.015853..  Val Accuracy: 99.54%
# Epoch: 251/500..  Training Loss: 0.002232..  Val Loss: 0.015255..  Val Accuracy: 99.57%
# Epoch: 252/500..  Training Loss: 0.004826..  Val Loss: 0.017936..  Val Accuracy: 99.49%
# Epoch: 253/500..  Training Loss: 0.005023..  Val Loss: 0.016168..  Val Accuracy: 99.51%
# Epoch: 255/500..  Training Loss: 0.000000..  Val Loss: 0.014364..  Val Accuracy: 99.62%
# Epoch: 256/500..  Training Loss: 0.000899..  Val Loss: 0.016176..  Val Accuracy: 99.47%
# Epoch: 257/500..  Training Loss: 0.000598..  Val Loss: 0.025858..  Val Accuracy: 99.43%
# Epoch: 258/500..  Training Loss: 0.000525..  Val Loss: 0.013784..  Val Accuracy: 99.65%
# Epoch: 259/500..  Training Loss: 0.000556..  Val Loss: 0.013942..  Val Accuracy: 99.57%
# Epoch: 260/500..  Training Loss: 0.001237..  Val Loss: 0.014166..  Val Accuracy: 99.51%
# Epoch: 261/500..  Training Loss: 0.001952..  Val Loss: 0.015139..  Val Accuracy: 99.57%
# Epoch: 262/500..  Training Loss: 0.002073..  Val Loss: 0.021986..  Val Accuracy: 99.46%
# Epoch: 263/500..  Training Loss: 0.002209..  Val Loss: 0.030715..  Val Accuracy: 99.32%
# Epoch: 264/500..  Training Loss: 0.002309..  Val Loss: 0.015905..  Val Accuracy: 99.53%
# Epoch: 265/500..  Training Loss: 0.002431..  Val Loss: 0.014300..  Val Accuracy: 99.58%
# Epoch: 266/500..  Training Loss: 0.002616..  Val Loss: 0.016639..  Val Accuracy: 99.56%
# Epoch: 267/500..  Training Loss: 0.003737..  Val Loss: 0.013284..  Val Accuracy: 99.58%
# Epoch: 268/500..  Training Loss: 0.003547..  Val Loss: 0.012173..  Val Accuracy: 99.66%
# Epoch: 269/500..  Training Loss: 0.003227..  Val Loss: 0.014924..  Val Accuracy: 99.63%
# Epoch: 271/500..  Training Loss: 0.000042..  Val Loss: 0.014577..  Val Accuracy: 99.59%
# Epoch: 272/500..  Training Loss: 0.000324..  Val Loss: 0.015640..  Val Accuracy: 99.54%
# Epoch: 273/500..  Training Loss: 0.001058..  Val Loss: 0.019952..  Val Accuracy: 99.38%
# Epoch: 274/500..  Training Loss: 0.000976..  Val Loss: 0.018564..  Val Accuracy: 99.44%
# Epoch: 275/500..  Training Loss: 0.000805..  Val Loss: 0.017067..  Val Accuracy: 99.54%
# Epoch: 276/500..  Training Loss: 0.000969..  Val Loss: 0.011728..  Val Accuracy: 99.65%
# Epoch: 277/500..  Training Loss: 0.002301..  Val Loss: 0.027318..  Val Accuracy: 99.36%
# Epoch: 278/500..  Training Loss: 0.002381..  Val Loss: 0.017749..  Val Accuracy: 99.57%
# Epoch: 279/500..  Training Loss: 0.002211..  Val Loss: 0.013094..  Val Accuracy: 99.60%
# Epoch: 280/500..  Training Loss: 0.002296..  Val Loss: 0.011371..  Val Accuracy: 99.67%
# Epoch: 281/500..  Training Loss: 0.002857..  Val Loss: 0.014400..  Val Accuracy: 99.61%
# Epoch: 282/500..  Training Loss: 0.003124..  Val Loss: 0.013140..  Val Accuracy: 99.58%
# Epoch: 283/500..  Training Loss: 0.002917..  Val Loss: 0.018567..  Val Accuracy: 99.48%
# Epoch: 284/500..  Training Loss: 0.004529..  Val Loss: 0.014835..  Val Accuracy: 99.54%
# Epoch: 285/500..  Training Loss: 0.003121..  Val Loss: 0.017200..  Val Accuracy: 99.54%
# Epoch: 287/500..  Training Loss: 0.000068..  Val Loss: 0.022447..  Val Accuracy: 99.32%
# Epoch: 288/500..  Training Loss: 0.000186..  Val Loss: 0.014822..  Val Accuracy: 99.54%
# Epoch: 289/500..  Training Loss: 0.000447..  Val Loss: 0.015555..  Val Accuracy: 99.60%
# Epoch: 290/500..  Training Loss: 0.000970..  Val Loss: 0.015510..  Val Accuracy: 99.54%
# Epoch: 291/500..  Training Loss: 0.000694..  Val Loss: 0.016826..  Val Accuracy: 99.51%
# Epoch: 292/500..  Training Loss: 0.001380..  Val Loss: 0.017456..  Val Accuracy: 99.46%
# Epoch: 293/500..  Training Loss: 0.000847..  Val Loss: 0.012706..  Val Accuracy: 99.62%
# Epoch: 294/500..  Training Loss: 0.001479..  Val Loss: 0.013336..  Val Accuracy: 99.66%
# Epoch: 295/500..  Training Loss: 0.003004..  Val Loss: 0.020701..  Val Accuracy: 99.45%
# Epoch: 296/500..  Training Loss: 0.001937..  Val Loss: 0.013388..  Val Accuracy: 99.66%
# Epoch: 297/500..  Training Loss: 0.003750..  Val Loss: 0.014851..  Val Accuracy: 99.58%
# Epoch: 298/500..  Training Loss: 0.002982..  Val Loss: 0.012782..  Val Accuracy: 99.61%
# Epoch: 299/500..  Training Loss: 0.003021..  Val Loss: 0.013361..  Val Accuracy: 99.61%
# Epoch: 300/500..  Training Loss: 0.003632..  Val Loss: 0.017177..  Val Accuracy: 99.54%
# Epoch: 301/500..  Training Loss: 0.003253..  Val Loss: 0.017663..  Val Accuracy: 99.47%
# Epoch: 303/500..  Training Loss: 0.000052..  Val Loss: 0.015420..  Val Accuracy: 99.54%
# Epoch: 304/500..  Training Loss: 0.000352..  Val Loss: 0.014430..  Val Accuracy: 99.59%
# Epoch: 305/500..  Training Loss: 0.000353..  Val Loss: 0.012427..  Val Accuracy: 99.60%
# Epoch: 306/500..  Training Loss: 0.000729..  Val Loss: 0.017611..  Val Accuracy: 99.50%
# Epoch: 307/500..  Training Loss: 0.000824..  Val Loss: 0.012723..  Val Accuracy: 99.62%
# Epoch: 308/500..  Training Loss: 0.001499..  Val Loss: 0.014764..  Val Accuracy: 99.59%
# Epoch: 309/500..  Training Loss: 0.001786..  Val Loss: 0.017319..  Val Accuracy: 99.56%
# Epoch: 310/500..  Training Loss: 0.001716..  Val Loss: 0.016831..  Val Accuracy: 99.59%
# Epoch: 311/500..  Training Loss: 0.002707..  Val Loss: 0.019480..  Val Accuracy: 99.52%
# Epoch: 312/500..  Training Loss: 0.003860..  Val Loss: 0.014950..  Val Accuracy: 99.66%
# Epoch: 313/500..  Training Loss: 0.001827..  Val Loss: 0.013627..  Val Accuracy: 99.66%
# Epoch: 314/500..  Training Loss: 0.003576..  Val Loss: 0.015171..  Val Accuracy: 99.63%
# Epoch: 315/500..  Training Loss: 0.003164..  Val Loss: 0.019424..  Val Accuracy: 99.50%
# Epoch: 316/500..  Training Loss: 0.002751..  Val Loss: 0.016028..  Val Accuracy: 99.61%
# Epoch: 317/500..  Training Loss: 0.003788..  Val Loss: 0.020904..  Val Accuracy: 99.38%
# Epoch: 319/500..  Training Loss: 0.000175..  Val Loss: 0.020402..  Val Accuracy: 99.50%
# Epoch: 320/500..  Training Loss: 0.000413..  Val Loss: 0.013418..  Val Accuracy: 99.60%
# Epoch: 321/500..  Training Loss: 0.000377..  Val Loss: 0.014475..  Val Accuracy: 99.61%
# Epoch: 322/500..  Training Loss: 0.000306..  Val Loss: 0.015506..  Val Accuracy: 99.54%
# Epoch: 323/500..  Training Loss: 0.001413..  Val Loss: 0.013023..  Val Accuracy: 99.62%
# Epoch: 324/500..  Training Loss: 0.001305..  Val Loss: 0.017349..  Val Accuracy: 99.53%
# Epoch: 325/500..  Training Loss: 0.001079..  Val Loss: 0.014158..  Val Accuracy: 99.61%
# Epoch: 326/500..  Training Loss: 0.001109..  Val Loss: 0.017413..  Val Accuracy: 99.51%
# Epoch: 327/500..  Training Loss: 0.001546..  Val Loss: 0.016232..  Val Accuracy: 99.56%
# Epoch: 328/500..  Training Loss: 0.003071..  Val Loss: 0.012684..  Val Accuracy: 99.61%
# Epoch: 329/500..  Training Loss: 0.003213..  Val Loss: 0.016761..  Val Accuracy: 99.56%
# Epoch: 330/500..  Training Loss: 0.003111..  Val Loss: 0.013282..  Val Accuracy: 99.59%
# Epoch: 331/500..  Training Loss: 0.002475..  Val Loss: 0.012044..  Val Accuracy: 99.59%
# Epoch: 332/500..  Training Loss: 0.002623..  Val Loss: 0.016010..  Val Accuracy: 99.50%
# Epoch: 333/500..  Training Loss: 0.003228..  Val Loss: 0.019000..  Val Accuracy: 99.43%
# Epoch: 335/500..  Training Loss: 0.000053..  Val Loss: 0.015072..  Val Accuracy: 99.60%
# Epoch: 336/500..  Training Loss: 0.000363..  Val Loss: 0.015036..  Val Accuracy: 99.53%
# Epoch: 337/500..  Training Loss: 0.000495..  Val Loss: 0.014426..  Val Accuracy: 99.60%
# Epoch: 338/500..  Training Loss: 0.000675..  Val Loss: 0.013694..  Val Accuracy: 99.66%
# Epoch: 339/500..  Training Loss: 0.001063..  Val Loss: 0.011069..  Val Accuracy: 99.60%
# Epoch: 340/500..  Training Loss: 0.001513..  Val Loss: 0.016452..  Val Accuracy: 99.53%
# Epoch: 341/500..  Training Loss: 0.001988..  Val Loss: 0.012113..  Val Accuracy: 99.63%
# Epoch: 342/500..  Training Loss: 0.001783..  Val Loss: 0.020150..  Val Accuracy: 99.48%
# Epoch: 343/500..  Training Loss: 0.002231..  Val Loss: 0.012191..  Val Accuracy: 99.68%
# Epoch: 344/500..  Training Loss: 0.002496..  Val Loss: 0.013977..  Val Accuracy: 99.60%
# Epoch: 345/500..  Training Loss: 0.003772..  Val Loss: 0.013079..  Val Accuracy: 99.57%
# Epoch: 346/500..  Training Loss: 0.002705..  Val Loss: 0.012110..  Val Accuracy: 99.58%
# Epoch: 347/500..  Training Loss: 0.002337..  Val Loss: 0.014611..  Val Accuracy: 99.53%
# Epoch: 348/500..  Training Loss: 0.001781..  Val Loss: 0.018116..  Val Accuracy: 99.49%
# Epoch: 349/500..  Training Loss: 0.003112..  Val Loss: 0.017612..  Val Accuracy: 99.58%
# Epoch: 351/500..  Training Loss: 0.000531..  Val Loss: 0.013306..  Val Accuracy: 99.51%
# Epoch: 352/500..  Training Loss: 0.000282..  Val Loss: 0.017688..  Val Accuracy: 99.58%
# Epoch: 353/500..  Training Loss: 0.000893..  Val Loss: 0.018734..  Val Accuracy: 99.46%
# Epoch: 354/500..  Training Loss: 0.000480..  Val Loss: 0.015884..  Val Accuracy: 99.55%
# Epoch: 355/500..  Training Loss: 0.001428..  Val Loss: 0.012165..  Val Accuracy: 99.63%
# Epoch: 356/500..  Training Loss: 0.001499..  Val Loss: 0.013724..  Val Accuracy: 99.60%
# Epoch: 357/500..  Training Loss: 0.001630..  Val Loss: 0.013981..  Val Accuracy: 99.64%
# Epoch: 358/500..  Training Loss: 0.002224..  Val Loss: 0.017076..  Val Accuracy: 99.59%
# Epoch: 359/500..  Training Loss: 0.001634..  Val Loss: 0.013451..  Val Accuracy: 99.62%
# Epoch: 360/500..  Training Loss: 0.001683..  Val Loss: 0.013515..  Val Accuracy: 99.60%
# Epoch: 361/500..  Training Loss: 0.002103..  Val Loss: 0.015726..  Val Accuracy: 99.62%
# Epoch: 362/500..  Training Loss: 0.003053..  Val Loss: 0.013437..  Val Accuracy: 99.54%
# Epoch: 363/500..  Training Loss: 0.003300..  Val Loss: 0.017766..  Val Accuracy: 99.56%
# Epoch: 364/500..  Training Loss: 0.002966..  Val Loss: 0.013094..  Val Accuracy: 99.61%
# Epoch: 365/500..  Training Loss: 0.002748..  Val Loss: 0.017899..  Val Accuracy: 99.57%
# Epoch: 367/500..  Training Loss: 0.000359..  Val Loss: 0.018872..  Val Accuracy: 99.52%
# Epoch: 368/500..  Training Loss: 0.000335..  Val Loss: 0.013749..  Val Accuracy: 99.56%
# Epoch: 369/500..  Training Loss: 0.000755..  Val Loss: 0.014724..  Val Accuracy: 99.57%
# Epoch: 370/500..  Training Loss: 0.000876..  Val Loss: 0.018393..  Val Accuracy: 99.54%
# Epoch: 371/500..  Training Loss: 0.000714..  Val Loss: 0.020700..  Val Accuracy: 99.50%
# Epoch: 372/500..  Training Loss: 0.001161..  Val Loss: 0.027878..  Val Accuracy: 99.24%
# Epoch: 373/500..  Training Loss: 0.001582..  Val Loss: 0.022122..  Val Accuracy: 99.51%
# Epoch: 374/500..  Training Loss: 0.001516..  Val Loss: 0.016561..  Val Accuracy: 99.57%
# Epoch: 375/500..  Training Loss: 0.002439..  Val Loss: 0.025324..  Val Accuracy: 99.35%
# Epoch: 376/500..  Training Loss: 0.001682..  Val Loss: 0.017314..  Val Accuracy: 99.53%
# Epoch: 377/500..  Training Loss: 0.001551..  Val Loss: 0.014058..  Val Accuracy: 99.65%
# Epoch: 378/500..  Training Loss: 0.002582..  Val Loss: 0.010739..  Val Accuracy: 99.64%
# Epoch: 379/500..  Training Loss: 0.003138..  Val Loss: 0.012954..  Val Accuracy: 99.59%
# Epoch: 380/500..  Training Loss: 0.002917..  Val Loss: 0.014551..  Val Accuracy: 99.57%
# Epoch: 382/500..  Training Loss: 0.000001..  Val Loss: 0.012776..  Val Accuracy: 99.61%
# Epoch: 383/500..  Training Loss: 0.000211..  Val Loss: 0.014360..  Val Accuracy: 99.54%
# Epoch: 384/500..  Training Loss: 0.000380..  Val Loss: 0.018452..  Val Accuracy: 99.55%
# Epoch: 385/500..  Training Loss: 0.001063..  Val Loss: 0.017347..  Val Accuracy: 99.49%
# Epoch: 386/500..  Training Loss: 0.000561..  Val Loss: 0.016237..  Val Accuracy: 99.61%
# Epoch: 387/500..  Training Loss: 0.001240..  Val Loss: 0.011391..  Val Accuracy: 99.70%
# Epoch: 388/500..  Training Loss: 0.001124..  Val Loss: 0.017134..  Val Accuracy: 99.55%
# Epoch: 389/500..  Training Loss: 0.001648..  Val Loss: 0.018140..  Val Accuracy: 99.50%
# Epoch: 390/500..  Training Loss: 0.001327..  Val Loss: 0.016949..  Val Accuracy: 99.58%
# Epoch: 391/500..  Training Loss: 0.001047..  Val Loss: 0.017724..  Val Accuracy: 99.56%
# Epoch: 392/500..  Training Loss: 0.002095..  Val Loss: 0.015291..  Val Accuracy: 99.58%
# Epoch: 393/500..  Training Loss: 0.001467..  Val Loss: 0.013710..  Val Accuracy: 99.66%
# Epoch: 394/500..  Training Loss: 0.003868..  Val Loss: 0.015607..  Val Accuracy: 99.62%
# Epoch: 395/500..  Training Loss: 0.002632..  Val Loss: 0.017794..  Val Accuracy: 99.46%
# Epoch: 396/500..  Training Loss: 0.003110..  Val Loss: 0.013846..  Val Accuracy: 99.62%
# Epoch: 398/500..  Training Loss: 0.000009..  Val Loss: 0.013504..  Val Accuracy: 99.55%
# Epoch: 399/500..  Training Loss: 0.000118..  Val Loss: 0.013563..  Val Accuracy: 99.58%
# Epoch: 400/500..  Training Loss: 0.000373..  Val Loss: 0.013714..  Val Accuracy: 99.54%
# Epoch: 401/500..  Training Loss: 0.000184..  Val Loss: 0.013437..  Val Accuracy: 99.61%
# Epoch: 402/500..  Training Loss: 0.000803..  Val Loss: 0.012372..  Val Accuracy: 99.70%
# Epoch: 403/500..  Training Loss: 0.001312..  Val Loss: 0.012252..  Val Accuracy: 99.64%
# Epoch: 404/500..  Training Loss: 0.001468..  Val Loss: 0.011986..  Val Accuracy: 99.69%
# Epoch: 405/500..  Training Loss: 0.001221..  Val Loss: 0.014930..  Val Accuracy: 99.63%
# Epoch: 406/500..  Training Loss: 0.001223..  Val Loss: 0.018200..  Val Accuracy: 99.54%
# Epoch: 407/500..  Training Loss: 0.001663..  Val Loss: 0.015996..  Val Accuracy: 99.59%
# Epoch: 408/500..  Training Loss: 0.003154..  Val Loss: 0.017555..  Val Accuracy: 99.51%
# Epoch: 409/500..  Training Loss: 0.003049..  Val Loss: 0.015841..  Val Accuracy: 99.58%
# Epoch: 410/500..  Training Loss: 0.002227..  Val Loss: 0.015512..  Val Accuracy: 99.64%
# Epoch: 411/500..  Training Loss: 0.001578..  Val Loss: 0.015267..  Val Accuracy: 99.58%
# Epoch: 412/500..  Training Loss: 0.002682..  Val Loss: 0.014987..  Val Accuracy: 99.61%
# Epoch: 414/500..  Training Loss: 0.000025..  Val Loss: 0.021823..  Val Accuracy: 99.48%
# Epoch: 415/500..  Training Loss: 0.000218..  Val Loss: 0.014279..  Val Accuracy: 99.56%
# Epoch: 416/500..  Training Loss: 0.000476..  Val Loss: 0.011881..  Val Accuracy: 99.62%
# Epoch: 417/500..  Training Loss: 0.000674..  Val Loss: 0.017031..  Val Accuracy: 99.40%
# Epoch: 418/500..  Training Loss: 0.001212..  Val Loss: 0.011616..  Val Accuracy: 99.65%
# Epoch: 419/500..  Training Loss: 0.000678..  Val Loss: 0.012370..  Val Accuracy: 99.63%
# Epoch: 420/500..  Training Loss: 0.001427..  Val Loss: 0.014168..  Val Accuracy: 99.59%
# Epoch: 421/500..  Training Loss: 0.000909..  Val Loss: 0.015873..  Val Accuracy: 99.61%
# Epoch: 422/500..  Training Loss: 0.001266..  Val Loss: 0.014593..  Val Accuracy: 99.54%
# Epoch: 423/500..  Training Loss: 0.001905..  Val Loss: 0.012068..  Val Accuracy: 99.70%
# Epoch: 424/500..  Training Loss: 0.002287..  Val Loss: 0.018728..  Val Accuracy: 99.50%
# Epoch: 425/500..  Training Loss: 0.001918..  Val Loss: 0.012742..  Val Accuracy: 99.72%
# Epoch: 426/500..  Training Loss: 0.001695..  Val Loss: 0.012370..  Val Accuracy: 99.65%
# Epoch: 427/500..  Training Loss: 0.001896..  Val Loss: 0.021519..  Val Accuracy: 99.48%
# Epoch: 428/500..  Training Loss: 0.002945..  Val Loss: 0.012402..  Val Accuracy: 99.66%
# Epoch: 430/500..  Training Loss: 0.000078..  Val Loss: 0.024697..  Val Accuracy: 99.46%
# Epoch: 431/500..  Training Loss: 0.000129..  Val Loss: 0.017168..  Val Accuracy: 99.57%
# Epoch: 432/500..  Training Loss: 0.000669..  Val Loss: 0.017528..  Val Accuracy: 99.56%
# Epoch: 433/500..  Training Loss: 0.000624..  Val Loss: 0.012584..  Val Accuracy: 99.69%
# Epoch: 434/500..  Training Loss: 0.000661..  Val Loss: 0.012850..  Val Accuracy: 99.60%
# Epoch: 435/500..  Training Loss: 0.001003..  Val Loss: 0.011086..  Val Accuracy: 99.69%
# Epoch: 436/500..  Training Loss: 0.000713..  Val Loss: 0.015657..  Val Accuracy: 99.56%
# Epoch: 437/500..  Training Loss: 0.001030..  Val Loss: 0.013942..  Val Accuracy: 99.57%
# Epoch: 438/500..  Training Loss: 0.000872..  Val Loss: 0.016895..  Val Accuracy: 99.46%
# Epoch: 439/500..  Training Loss: 0.002854..  Val Loss: 0.015220..  Val Accuracy: 99.61%
# Epoch: 440/500..  Training Loss: 0.001698..  Val Loss: 0.013177..  Val Accuracy: 99.63%
# Epoch: 441/500..  Training Loss: 0.002645..  Val Loss: 0.013298..  Val Accuracy: 99.63%
# Epoch: 442/500..  Training Loss: 0.001320..  Val Loss: 0.013299..  Val Accuracy: 99.63%
# Epoch: 443/500..  Training Loss: 0.002850..  Val Loss: 0.013116..  Val Accuracy: 99.64%
# Epoch: 444/500..  Training Loss: 0.002720..  Val Loss: 0.015637..  Val Accuracy: 99.62%
# Epoch: 446/500..  Training Loss: 0.000010..  Val Loss: 0.014814..  Val Accuracy: 99.49%
# Epoch: 447/500..  Training Loss: 0.000441..  Val Loss: 0.012556..  Val Accuracy: 99.62%
# Epoch: 448/500..  Training Loss: 0.000471..  Val Loss: 0.022627..  Val Accuracy: 99.45%
# Epoch: 449/500..  Training Loss: 0.000603..  Val Loss: 0.025148..  Val Accuracy: 99.41%
# Epoch: 450/500..  Training Loss: 0.001373..  Val Loss: 0.023600..  Val Accuracy: 99.43%
# Epoch: 451/500..  Training Loss: 0.000922..  Val Loss: 0.018996..  Val Accuracy: 99.37%
# Epoch: 452/500..  Training Loss: 0.001203..  Val Loss: 0.017757..  Val Accuracy: 99.62%
# Epoch: 453/500..  Training Loss: 0.000853..  Val Loss: 0.013778..  Val Accuracy: 99.65%
# Epoch: 454/500..  Training Loss: 0.001199..  Val Loss: 0.013690..  Val Accuracy: 99.58%
# Epoch: 455/500..  Training Loss: 0.002446..  Val Loss: 0.015566..  Val Accuracy: 99.57%
# Epoch: 456/500..  Training Loss: 0.001736..  Val Loss: 0.011838..  Val Accuracy: 99.67%
# Epoch: 457/500..  Training Loss: 0.001877..  Val Loss: 0.015173..  Val Accuracy: 99.55%
# Epoch: 458/500..  Training Loss: 0.001608..  Val Loss: 0.016707..  Val Accuracy: 99.58%
# Epoch: 459/500..  Training Loss: 0.002086..  Val Loss: 0.014606..  Val Accuracy: 99.56%
# Epoch: 460/500..  Training Loss: 0.003219..  Val Loss: 0.011985..  Val Accuracy: 99.61%
# Epoch: 462/500..  Training Loss: 0.000112..  Val Loss: 0.015192..  Val Accuracy: 99.60%
# Epoch: 463/500..  Training Loss: 0.000319..  Val Loss: 0.014364..  Val Accuracy: 99.66%
# Epoch: 464/500..  Training Loss: 0.000787..  Val Loss: 0.018336..  Val Accuracy: 99.54%
# Epoch: 465/500..  Training Loss: 0.000317..  Val Loss: 0.012826..  Val Accuracy: 99.67%
# Epoch: 466/500..  Training Loss: 0.000418..  Val Loss: 0.015843..  Val Accuracy: 99.58%
# Epoch: 467/500..  Training Loss: 0.001000..  Val Loss: 0.015755..  Val Accuracy: 99.61%
# Epoch: 468/500..  Training Loss: 0.001486..  Val Loss: 0.022723..  Val Accuracy: 99.47%
# Epoch: 469/500..  Training Loss: 0.001005..  Val Loss: 0.012666..  Val Accuracy: 99.68%
# Epoch: 470/500..  Training Loss: 0.001945..  Val Loss: 0.014682..  Val Accuracy: 99.51%
# Epoch: 471/500..  Training Loss: 0.001511..  Val Loss: 0.017752..  Val Accuracy: 99.58%
# Epoch: 472/500..  Training Loss: 0.001234..  Val Loss: 0.016823..  Val Accuracy: 99.54%
# Epoch: 473/500..  Training Loss: 0.002023..  Val Loss: 0.015750..  Val Accuracy: 99.65%
# Epoch: 474/500..  Training Loss: 0.002178..  Val Loss: 0.014368..  Val Accuracy: 99.66%
# Epoch: 475/500..  Training Loss: 0.002794..  Val Loss: 0.024350..  Val Accuracy: 99.40%
# Epoch: 476/500..  Training Loss: 0.002836..  Val Loss: 0.014220..  Val Accuracy: 99.63%
# Epoch: 478/500..  Training Loss: 0.000117..  Val Loss: 0.015397..  Val Accuracy: 99.58%
# Epoch: 479/500..  Training Loss: 0.000210..  Val Loss: 0.014355..  Val Accuracy: 99.57%
# Epoch: 480/500..  Training Loss: 0.000548..  Val Loss: 0.015773..  Val Accuracy: 99.57%
# Epoch: 481/500..  Training Loss: 0.000929..  Val Loss: 0.021475..  Val Accuracy: 99.47%
# Epoch: 482/500..  Training Loss: 0.001080..  Val Loss: 0.014734..  Val Accuracy: 99.63%
# Epoch: 483/500..  Training Loss: 0.000419..  Val Loss: 0.015070..  Val Accuracy: 99.57%
# Epoch: 484/500..  Training Loss: 0.001303..  Val Loss: 0.024753..  Val Accuracy: 99.37%
# Epoch: 485/500..  Training Loss: 0.001156..  Val Loss: 0.019938..  Val Accuracy: 99.31%
# Epoch: 486/500..  Training Loss: 0.001570..  Val Loss: 0.021425..  Val Accuracy: 99.48%
# Epoch: 487/500..  Training Loss: 0.002258..  Val Loss: 0.016741..  Val Accuracy: 99.48%
# Epoch: 488/500..  Training Loss: 0.002289..  Val Loss: 0.013526..  Val Accuracy: 99.62%
# Epoch: 489/500..  Training Loss: 0.001448..  Val Loss: 0.015638..  Val Accuracy: 99.61%
# Epoch: 490/500..  Training Loss: 0.002113..  Val Loss: 0.018322..  Val Accuracy: 99.52%
# Epoch: 491/500..  Training Loss: 0.002794..  Val Loss: 0.012290..  Val Accuracy: 99.64%
# Epoch: 492/500..  Training Loss: 0.002725..  Val Loss: 0.018478..  Val Accuracy: 99.53%
# Epoch: 494/500..  Training Loss: 0.000117..  Val Loss: 0.026809..  Val Accuracy: 99.33%
# Epoch: 495/500..  Training Loss: 0.000103..  Val Loss: 0.015165..  Val Accuracy: 99.66%
# Epoch: 496/500..  Training Loss: 0.000577..  Val Loss: 0.015984..  Val Accuracy: 99.60%
# Epoch: 497/500..  Training Loss: 0.000444..  Val Loss: 0.014277..  Val Accuracy: 99.67%
# Epoch: 498/500..  Training Loss: 0.001012..  Val Loss: 0.016583..  Val Accuracy: 99.54%
# Epoch: 499/500..  Training Loss: 0.000689..  Val Loss: 0.014599..  Val Accuracy: 99.64%
# Epoch: 500/500..  Training Loss: 0.000966..  Val Loss: 0.016980..  Val Accuracy: 99.61%

# %% [markdown]
# ### 테스트

# %%
from sklearn.metrics import confusion_matrix

# %%
def test(classifier1,classifier2,classifier3,classifier4,classifier5, dataloader):
    # setup the network
    predlist=[]
    real=[]    

    classifier.eval()
    correct = 0.0
    
    max_tr_score = 0
    max_val_score = 0
    for batch_idx, (data) in enumerate(dataloader):
    
        signal1,label = data
        signal1,label = Variable(signal1.cuda()),Variable(label.cuda().long())
        
        
        out1,_ = classifier1(signal1)
        out2,_ = classifier2(signal1) 
        out3,_ = classifier3(signal1)
        out4,_ = classifier4(signal1)
        out5,_ = classifier5(signal1)

        
        out=(out1+out2+out3+out4+out5)/5
        
        pred = out.data.max(1, keepdim= True)[1]
        predlist.append(pred.cpu().detach().numpy().squeeze())
        real.append(label)        
        correct += pred.eq(label.data.view_as(pred)).cpu().sum()

        # predlist.append(pred)
    print('\nAccuracy: {}/{} ({:.4f}%)\n'.format(
        correct, len(dataloader.dataset), 100. * float(correct) / len(dataloader.dataset)))
    acc=100. * float(correct) / len(dataloader.dataset)
    return acc,predlist,real

# %% [markdown]
# #### 1번

# %%
train_loader,valid_loader,test_loader=loaders(cross_val_train_set_1,cross_val_train_label_1,cross_val_test_set_1,cross_val_test_label_1,1004)

# %%
acc,predlist,realist=test(ensemble1_best,ensemble2_best,ensemble3_best,ensemble4_best,ensemble5_best,test_loader)

# %%
confusionmatrix(predlist, realist)

# %% [markdown]
# ### Extra

# %%
def fail_index(pred, real, cross_val_num):
    failed=[]
    with open('test_fold_index.pickle', 'rb') as f:
        test_fold_index = pickle.load(f)
    
    for i in range(len(pred)):
        if pred[i].item()!=real[i].detach().cpu().item():
            failed.append(test_fold_index[cross_val_num-1][i])
    
    return failed

# %%
failed_index=fail_index(predlist,realist,1)

# %%
failed_index
# Out:
# [65,
#  186,
#  412,
#  440,
#  508,
#  516,
#  573,
#  579,
#  583,
#  655,
#  656,
#  795,
#  908,
#  951,
#  994,
#  1003,
#  1054,
#  1060,
#  1168,
#  1241,
#  1261,
#  1269,
#  1314,
#  1550,
#  1608,
#  1774,
#  1874,
#  1883,
#  1891,
#  2021,
#  2128,
#  2183,
#  2305,
#  2376,
#  2429,
#  2463,
#  2472,
#  2555,
#  2638,
#  2736,
#  2870,
#  2927,
#  2938,
#  3151,
#  3395,
#  3559,
#  3565,
#  3754,
#  3846,
#  3902,
#  3992,
#  4148,
#  4249,
#  4263,
#  4485,
#  4498,
#  4536,
#  4599,
#  4625,
#  4731,
#  5028,
#  5080,
#  5099,
#  5185,
#  5265,
#  5333,
#  5369,
#  5534,
#  5596,
#  5641,
#  5680,
#  6041,
#  6171,
#  6174,
#  6343,
#  6480,
#  6526,
#  6621,
#  6722,
#  6759,
#  6760,
#  7044,
#  7083,
#  7256,
#  7303,
#  7372,
#  7435,
#  7447,
#  7509,
#  7587,
#  7816,
#  7901,
#  8016,
#  8034,
#  8229,
#  8282,
#  8506,
#  8531,
#  8574,
#  8666,
#  8669,
#  8673,
#  8680,
#  8710,
#  8745,
#  8768,
#  8803,
#  8806,
#  8938,
#  9126,
#  9163,
#  9265,
#  9384,
#  9387,
#  9414,
#  9424,
#  9482,
#  9525,
#  9778,
#  9920,
#  10064,
#  10092,
#  10144,
#  10189,
#  10211,
#  10471,
#  10500,
#  10519,
#  10535,
#  10633,
#  10808,
#  10866,
#  10869,
#  10879,
#  10882,
#  11017,
#  11143,
#  11204,
#  11256,
#  11286,
#  11361,
#  11365,
#  11376,
#  11454,
#  11498,
#  11537,
#  11679,
#  11797,
#  11934,
#  12040,
#  12131,
#  12350,
#  12395,
#  12444,
#  12456,
#  12752,
#  12843,
#  12929,
#  12946,
#  13030,
#  13230,
#  13244,
#  13265,
#  13346,
#  13462,
#  13609,
#  13833,
#  13838,
#  13904,
#  14187,
#  14198,
#  14512,
#  14542,
#  14701,
#  14764,
#  14772,
#  14773,
#  14893,
#  14902,
#  14951,
#  15118,
#  15171,
#  15259,
#  15305,
#  15338,
#  15348,
#  15824,
#  16123,
#  16135,
#  16186,
#  16255,
#  16339,
#  16390,
#  16417,
#  16423,
#  16437,
#  16606,
#  16712,
#  16783,
#  16810,
#  16835,
#  16836,
#  17043,
#  17262,
#  17269,
#  17352,
#  17403,
#  17438,
#  17449,
#  17471,
#  17484,
#  17615,
#  17641,
#  17797,
#  17887,
#  17901,
#  17949,
#  18053,
#  18105,
#  18223,
#  18229,
#  18343,
#  18420,
#  18484,
#  18488,
#  18621,
#  18703,
#  18740,
#  18860,
#  18861,
#  19022,
#  19117,
#  19249,
#  19320,
#  19382,
#  19410,
#  19467,
#  19489,
#  19610,
#  19727,
#  19742,
#  19788,
#  19895,
#  19910,
#  20093,
#  20106]
